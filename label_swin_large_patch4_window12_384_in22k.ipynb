# %%
import os
import cv2
import time
import random
import logging
import easydict
import numpy as np
import pandas as pd
from tqdm import tqdm
from os.path import join as opj
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from PIL import Image
from natsort import natsorted

import timm
import torch
import torch.nn as nn
import torch_optimizer as optim
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, grad_scaler
from torchvision import transforms
from torch import Tensor
from torchvision.transforms import functional as F
import torch.cuda.amp as amp
from adamp import AdamP, SGDP

import warnings
warnings.filterwarnings('ignore')

# %%
args = easydict.EasyDict(
    {'exp_num':'0',
     
     # Path settings
     'data_path':'./open',
     'Kfold':5,
     'model_path':'label_results_swin_large_patch4_window12_384_in22k/',
     'image_type':'train_1024', 
     'class_num' : 88,

     # Model parameter settings
     'model_name':'swin_large_patch4_window12_384_in22k',
     'drop_path_rate':0.2,
     
     # Training parameter settings
     ## Base Parameter
     'img_size':384,
     'batch_size':16,
     'epochs':100,
     'optimizer':'Lamb',
     'initial_lr':5e-4,
     'weight_decay':1e-3,

     ## Augmentation
     'aug_ver':2,

     ## Scheduler (OnecycleLR)
     'scheduler':'Reduce',
     'warm_epoch':5,
     'max_lr':1e-3,

     ### Cosine Annealing
     'min_lr':5e-5,
     'tmax':145,

     ## etc.
     'patience': 5,
     'clipping':None,

     # Hardware settings
     'amp':True,
     'multi_gpu':True,
     'logging':False,
     'num_workers':4,
     'seed':42
     
     
    })

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "0,1,2,3"  # Set the GPUs 2 and 3 to use

# %% [markdown]
# # 증강된 데이터 셋 불러오기

# %%
DATA_DIR = './open'

train_df = pd.read_csv(os.path.join(DATA_DIR, 'train_df_add_data.csv'))
test_df = pd.read_csv(os.path.join(DATA_DIR, 'test_df.csv'))

print(train_df.head())
print(test_df.head())
print(train_df.shape)
print(test_df.shape)
# Out:
#    Unnamed: 0  file_name       class state            label  encoder_label
# 0           0  10000.png  transistor  good  transistor-good             72
# 1           1  10001.png     capsule  good     capsule-good             15
# 2           2  10002.png  transistor  good  transistor-good             72
# 3           3  10003.png        wood  good        wood-good             76
# 4           4  10004.png      bottle  good      bottle-good              3
#    index  file_name
# 0      0  20000.png
# 1      1  20001.png
# 2      2  20002.png
# 3      3  20003.png
# 4      4  20004.png
# (13997, 6)
# (2154, 2)

# %%
train_df['label'].unique()
# Out:
# array(['transistor-good', 'capsule-good', 'wood-good', 'bottle-good',
#        'screw-good', 'cable-bent_wire', 'carpet-hole', 'hazelnut-good',
#        'pill-pill_type', 'cable-good', 'metal_nut-scratch', 'pill-good',
#        'screw-thread_side', 'zipper-fabric_border', 'leather-good',
#        'pill-scratch', 'toothbrush-good', 'hazelnut-crack',
#        'screw-manipulated_front', 'zipper-good', 'tile-good',
#        'carpet-good', 'metal_nut-good', 'bottle-contamination',
#        'grid-good', 'zipper-split_teeth', 'pill-crack', 'wood-combined',
#        'pill-color', 'screw-thread_top', 'cable-missing_cable',
#        'capsule-squeeze', 'zipper-rough', 'capsule-crack', 'capsule-poke',
#        'metal_nut-flip', 'carpet-metal_contamination', 'metal_nut-color',
#        'transistor-bent_lead', 'zipper-fabric_interior', 'leather-fold',
#        'tile-glue_strip', 'screw-scratch_neck', 'screw-scratch_head',
#        'hazelnut-cut', 'bottle-broken_large', 'bottle-broken_small',
#        'leather-cut', 'cable-cut_outer_insulation',
#        'zipper-squeezed_teeth', 'toothbrush-defective',
#        'cable-cut_inner_insulation', 'pill-contamination',
#        'cable-missing_wire', 'carpet-thread', 'grid-broken',
#        'pill-faulty_imprint', 'hazelnut-hole', 'leather-glue',
#        'leather-poke', 'transistor-damaged_case', 'wood-scratch',
#        'tile-gray_stroke', 'capsule-faulty_imprint', 'grid-glue',
#        'zipper-combined', 'carpet-color', 'grid-bent', 'pill-combined',
#        'hazelnut-print', 'cable-combined', 'capsule-scratch',
#        'metal_nut-bent', 'zipper-broken_teeth', 'tile-oil',
#        'transistor-misplaced', 'grid-thread', 'grid-metal_contamination',
#        'carpet-cut', 'wood-color', 'cable-cable_swap', 'tile-crack',
#        'leather-color', 'cable-poke_insulation', 'transistor-cut_lead',
#        'wood-hole', 'tile-rough', 'wood-liquid'], dtype=object)

# %%
class_num = len(train_df.encoder_label.unique())
class_num
# Out:
# 88

# %%
# Warmup Learning rate scheduler
from torch.optim.lr_scheduler import _LRScheduler
class WarmUpLR(_LRScheduler):
    """warmup_training learning rate scheduler
    Args:
        optimizer: optimzier(e.g. SGD)
        total_iters: totoal_iters of warmup phase
    """
    def __init__(self, optimizer, total_iters, last_epoch=-1):
        
        self.total_iters = total_iters
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        """we will use the first m batches, and set the learning
        rate to base_lr * m / total_iters
        """
        return [base_lr * self.last_epoch / (self.total_iters + 1e-8) for base_lr in self.base_lrs]

# Logging
def get_root_logger(logger_name='basicsr',
                    log_level=logging.INFO,
                    log_file=None):

    logger = logging.getLogger(logger_name)
    # if the logger has been initialized, just return it
    if logger.hasHandlers():
        return logger

    format_str = '%(asctime)s %(levelname)s: %(message)s'
    logging.basicConfig(format=format_str, level=log_level)

    if log_file is not None:
        file_handler = logging.FileHandler(log_file, 'w')
        file_handler.setFormatter(logging.Formatter(format_str))
        file_handler.setLevel(log_level)
        logger.addHandler(file_handler)

    return logger

class AvgMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
        self.losses = []

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        self.losses.append(val)

# %%
class RandomRotation(transforms.RandomRotation):
    def __init__(self, p: float, degrees: int):
        super(RandomRotation, self).__init__(degrees)
        self.p = p

    def forward(self, img):
        if torch.rand(1) < self.p:
            fill = self.fill
            if isinstance(img, Tensor):
                if isinstance(fill, (int, float)):
                    fill = [float(fill)] * F.get_image_num_channels(img)
                else:
                    fill = [float(f) for f in fill]
            angle = self.get_params(self.degrees)

            img = F.rotate(img, angle, self.resample, self.expand, self.center, fill)
        return img

# %%
class Train_Dataset(Dataset):
    def __init__(self, df, transform=None):
        self.img_path = df['file_name'].values
        self.target = df['encoder_label'].values 
        self.transform = transform

        print(f'Dataset size:{len(self.img_path)}')

    def __getitem__(self, idx):
        
        image = Image.open(opj('./open/train_add_data/', self.img_path[idx])).convert('RGB')
        image = self.transform(image)
        target = self.target[idx]

        return image, target

    def __len__(self):
        return len(self.img_path)

class Test_dataset(Dataset):
    def __init__(self, df, transform=None):
        self.img_path = df['file_name'].values
        self.transform = transform

        print(f'Test Dataset size:{len(self.img_path)}')

    def __getitem__(self, idx):

        image = Image.open(opj('./open/test/', self.img_path[idx])).convert('RGB')
        image = self.transform(image)

        return image

    def __len__(self):
        return len(self.img_path)

def get_loader(df, phase: str, batch_size, shuffle,
               num_workers, transform):
    if phase == 'test':
        dataset = Test_dataset(df, transform)
        data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory=True)
    else:
        dataset = Train_Dataset(df, transform)
        data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, 
                                 pin_memory=True,
                                 drop_last=False)
    return data_loader

def get_train_augmentation(img_size, ver):
    if ver==1: # for validset
        transform = transforms.Compose([
                transforms.Resize((img_size, img_size)),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])

    if ver == 2:

        transform = transforms.Compose([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
                transforms.RandomAffine((-20,20)),
                RandomRotation(0.5, degrees=5),
                transforms.Resize((img_size, img_size)),
                transforms.ToTensor(), 
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])
    
    
    return transform

# %%
class Network(nn.Module):
    def __init__(self, args):
        super().__init__()
        self.model_ft = timm.create_model(args.model_name, pretrained=True, num_classes=88)

    def forward(self, x):
        out = self.model_ft(x)
        return out

class Network_test(nn.Module):
    def __init__(self, encoder_name):
        super().__init__()
        self.model_ft = timm.create_model(args.model_name, pretrained=True, num_classes=88)

    def forward(self, x):
        out = self.model_ft(x)
        return out

# %%
# # weighted crossentropy loss를 위한 weight 계산 함수

class_num = train_df.groupby(["encoder_label"])["encoder_label"].count().tolist()
class_weight = torch.tensor(np.max(class_num) / class_num).to("cuda", dtype=torch.float)
print(f"class_weight: {class_weight}")
# Out:
# class_weight: tensor([2.4437, 2.2216, 2.2216, 1.8708, 3.4911, 4.0729, 4.0729, 3.4911, 4.8875,
#         1.7455, 4.0729, 4.8875, 4.8875, 2.0365, 2.2216, 1.7854, 2.2216, 2.0365,
#         2.4437, 2.4437, 2.7153, 1.3964, 2.7153, 2.7153, 2.4437, 4.0729, 4.0729,
#         4.0729, 1.4811, 4.0729, 4.0729, 2.7153, 2.7153, 1.0000, 2.7153, 2.7153,
#         2.4437, 2.4437, 2.7153, 2.4437, 1.5959, 2.7153, 1.8798, 2.2216, 2.0365,
#         1.7773, 2.0365, 1.8798, 2.7153, 2.2216, 1.8798, 2.4437, 1.4644, 4.8875,
#         2.0365, 1.2219, 2.0365, 2.0365, 1.8798, 2.0365, 2.0365, 2.7153, 2.7153,
#         1.7000, 3.0547, 2.7153, 3.0547, 1.6292, 6.5167, 4.8875, 4.8875, 4.8875,
#         1.8357, 4.8875, 6.1094, 4.0729, 1.5830, 4.8875, 4.8875, 2.2216, 2.4437,
#         3.0547, 2.7153, 3.0547, 1.6292, 2.7153, 2.7153, 3.0547],
#        device='cuda:0')

# %%
class FocalLoss(nn.Module):
    """
    https://dacon.io/competitions/official/235585/codeshare/1796
    """

    def __init__(self, gamma=2.0, eps=1e-7):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        # print(self.gamma)
        self.eps = eps
        self.ce = nn.CrossEntropyLoss(reduction="none")

    def forward(self, input, target):
        logp = self.ce(input, target)
        p = torch.exp(-logp)
        loss = (1 - p) ** self.gamma * logp
        return loss.mean()

# %%
class Trainer():
    def __init__(self, args, save_path):
        '''
        args: arguments
        save_path: Model 가중치 저장 경로
        '''
        super(Trainer, self).__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Logging
        log_file = os.path.join(save_path, 'log.log')
        self.logger = get_root_logger(logger_name='IR', log_level=logging.INFO, log_file=log_file)
        self.logger.info(args)
        # self.logger.info(args.tag)

        # Train, Valid Set load
        ############################################################################
        if args.step == 0 :
            df_train = pd.read_csv(opj(args.data_path, 'train_df_add_data.csv'))
        else :
            df_train = pd.read_csv(opj(args.data_path, f'train_{args.step}step.csv'))

#         if args.image_type is not None:
#             df_train['img_path'] = df_train['img_path'].apply(lambda x:x.replace('train_imgs', args.image_type))
#             df_train['img_path'] = df_train['img_path'].apply(lambda x:x.replace('test_imgs', 'test_1024'))

        kf = StratifiedKFold(n_splits=args.Kfold, shuffle=True, random_state=args.seed)
        for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(df_train)), y=df_train['encoder_label'])):
            df_train.loc[val_idx, 'fold'] = fold
        val_idx = list(df_train[df_train['fold'] == int(args.fold)].index)

        df_val = df_train[df_train['fold'] == args.fold].reset_index(drop=True)
        df_train = df_train[df_train['fold'] != args.fold].reset_index(drop=True)

        # Augmentation
        self.train_transform = get_train_augmentation(img_size=args.img_size, ver=args.aug_ver)
        self.test_transform = get_train_augmentation(img_size=args.img_size, ver=1)

        # TrainLoader
        self.train_loader = get_loader(df_train, phase='train', batch_size=args.batch_size, shuffle=True,
                                       num_workers=args.num_workers, transform=self.train_transform)
        self.val_loader = get_loader(df_val, phase='train', batch_size=args.batch_size, shuffle=False,
                                       num_workers=args.num_workers, transform=self.test_transform)

        # Network
        self.model = Network(args).to(self.device)

        # Loss
#         self.criterion = nn.CrossEntropyLoss(weight=class_weight)
        self.criterion = FocalLoss()
#         self.criterion = CutMixCrossEntropyLoss(True)
        
        # Optimizer & Scheduler
#         self.optimizer = Lookahead(torch.optim.Adam(self.model.parameters(), lr=args.initial_lr), k=5, alpha=0.5)
        self.optimizer = optim.Lamb(self.model.parameters(), lr=args.initial_lr)
        
        iter_per_epoch = len(self.train_loader)
        self.warmup_scheduler = WarmUpLR(self.optimizer, iter_per_epoch * args.warm_epoch)

        if args.scheduler == 'step':
            self.scheduler = torch.optim.lr_scheduler.MultiStepLR(self.optimizer, milestones=args.milestone, gamma=args.lr_factor, verbose=True)
        elif args.scheduler == 'cos':
            tmax = args.tmax # half-cycle 
            self.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max = tmax, eta_min=args.min_lr, verbose=True)
        elif args.scheduler == 'cycle':
            self.scheduler = torch.optim.lr_scheduler.OneCycleLR(self.optimizer, max_lr=args.max_lr, steps_per_epoch=iter_per_epoch, epochs=args.epochs)
        else:
            self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, patience=5, factor=0.5, mode="max", verbose=True)
            
        if args.multi_gpu:
            self.model = nn.DataParallel(self.model).to(self.device)

        # Train / Validate
        best_loss = np.inf
        best_acc = 0
        best_epoch = 0
        early_stopping = 0
        start = time.time()
        for epoch in range(1, args.epochs+1):
            self.epoch = epoch

            if args.scheduler == 'cos':
                if epoch > args.warm_epoch:
                    self.scheduler.step()

            # Training
            train_loss, train_acc, train_f1 = self.training(args)

            # Model weight in Multi_GPU or Single GPU
            state_dict= self.model.module.state_dict() if args.multi_gpu else self.model.state_dict()

            # Validation
            val_loss, val_acc, val_f1 = self.validate(args, phase='val')

            # Save models
            if val_loss < best_loss:
                early_stopping = 0
                best_epoch = epoch
                best_loss = val_loss
                best_acc = val_acc
                best_f1 = val_f1

                torch.save({'epoch':epoch,
                            'state_dict':state_dict,
                            'optimizer': self.optimizer.state_dict(),
                            'scheduler': self.scheduler.state_dict(),
                    }, os.path.join(save_path, 'best_model.pth'))
                self.logger.info(f'-----------------SAVE:{best_epoch}epoch----------------')
            else:
                early_stopping += 1

            # Early Stopping
            if early_stopping == args.patience:
                break

        self.logger.info(f'\nBest Val Epoch:{best_epoch} | Val Loss:{best_loss:.4f} | Val Acc:{best_acc:.4f} | Val F1:{best_f1:.4f}')
        end = time.time()
        self.logger.info(f'Total Process time:{(end - start) / 60:.3f}Minute')

    # Training
    def training(self, args):
        self.model.train()
        train_loss = AvgMeter()
        train_acc = 0
        preds_list = []
        targets_list = []

        scaler = grad_scaler.GradScaler()
        
        for i, (images, targets) in enumerate(tqdm(self.train_loader)):
            images = torch.tensor(images, device=self.device, dtype=torch.float32)
            targets = torch.tensor(targets, device=self.device, dtype=torch.long)
            
            if self.epoch <= args.warm_epoch:
                self.warmup_scheduler.step()

            self.model.zero_grad(set_to_none=True)
    
            if args.amp:
                with autocast():
                    preds = self.model(images)
                    loss = self.criterion(preds, targets)
                    
                scaler.scale(loss).backward()

                # Gradient Clipping
                if args.clipping is not None:
                    scaler.unscale_(self.optimizer)
                    torch.nn.utils.clip_grad_norm_(self.model.parameters(), args.clipping)

                scaler.step(self.optimizer)
                scaler.update()

            else:
                preds = self.model(images)
                loss = self.criterion(preds, targets)
                loss.backward()
                nn.utils.clip_grad_norm_(self.model.parameters(), args.clipping)
                self.optimizer.step()

            if args.scheduler == 'cycle':
                if self.epoch > args.warm_epoch:
                    self.scheduler.step()

            # Metric
            train_acc += (preds.argmax(dim=1) == targets).sum().item()
            preds_list.extend(preds.argmax(dim=1).cpu().detach().numpy())
            targets_list.extend(targets.cpu().detach().numpy())
            # log
            train_loss.update(loss.item(), n=images.size(0))

        train_acc /= len(self.train_loader.dataset)
        train_f1 = f1_score(np.array(targets_list), np.array(preds_list), average='macro')

        self.logger.info(f'Epoch:[{self.epoch:03d}/{args.epochs:03d}]')
        self.logger.info(f'Train Loss:{train_loss.avg:.3f} | Acc:{train_acc:.4f} | F1:{train_f1:.4f}')
        return train_loss.avg, train_acc, train_f1
            
    # Validation or Dev
    def validate(self, args, phase='val'):
        self.model.eval()
        with torch.no_grad():
            val_loss = AvgMeter()
            val_acc = 0
            preds_list = []
            targets_list = []

            for i, (images, targets) in enumerate(self.val_loader):
                images = torch.tensor(images, device=self.device, dtype=torch.float32)
                targets = torch.tensor(targets, device=self.device, dtype=torch.long)

                preds = self.model(images)
                loss = self.criterion(preds, targets)

                # Metric
                val_acc += (preds.argmax(dim=1) == targets).sum().item()
                preds_list.extend(preds.argmax(dim=1).cpu().detach().numpy())
                targets_list.extend(targets.cpu().detach().numpy())

                # log
                val_loss.update(loss.item(), n=images.size(0))
            val_acc /= len(self.val_loader.dataset)
            val_f1 = f1_score(np.array(targets_list), np.array(preds_list), average='macro')

            self.logger.info(f'{phase} Loss:{val_loss.avg:.3f} | Acc:{val_acc:.4f} | F1:{val_f1:.4f}')
        return val_loss.avg, val_acc, val_f1

# %%
def main(args):
    print('<---- Training Params ---->')
    
    # Random Seed
    seed = args.seed
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = True

    save_path = os.path.join(args.model_path, (args.exp_num).zfill(3))
    
    # Create model directory
    os.makedirs(save_path, exist_ok=True)
    Trainer(args, save_path)

    return save_path

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())
# Out:
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 4

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
sub = pd.read_csv('./open/sample_submission.csv')
df_train = pd.read_csv('./open/train_df_add_data.csv')
df_test = pd.read_csv('./open/test_df.csv')

# %%
import ttach as tta

def predict(encoder_name, test_loader, device, model_path):
    model = Network_test(encoder_name).to(device)
    model.load_state_dict(torch.load(opj(model_path, 'best_model.pth'))['state_dict'])
#     model.eval()
    tta_model = tta.ClassificationTTAWrapper(model, tta.aliases.d4_transform())
    tta_model.eval()
    
    preds_list = []
    with torch.no_grad():
        for images in tqdm(test_loader):
            images = torch.as_tensor(images, device=device, dtype=torch.float32)
            preds = tta_model(images)
            preds = torch.softmax(preds, dim=1)
            preds_list.extend(preds.cpu().tolist())

    return np.array(preds_list)

def ensemble_5fold(model_path_list, test_loader, device):
    predict_list = []
    for model_path in model_path_list:
        prediction = predict(encoder_name= 'swin_large_patch4_window12_384_in22k', test_loader = test_loader, device = device, model_path = model_path)
        predict_list.append(prediction)
    ensemble = (predict_list[0] + predict_list[1] + predict_list[2] + predict_list[3] + predict_list[4])/len(predict_list)

    return ensemble

# %%
args.step = 0
models_path = []
for s_fold in range(5): # 5fold
    args.fold = s_fold
    args.exp_num = str(s_fold)
    save_path = main(args)
    models_path.append(save_path)
# Out:
# 2022-05-05 23:32:58,442 INFO: {'exp_num': '0', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_swin_large_patch4_window12_384_in22k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'swin_large_patch4_window12_384_in22k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 0}
# <---- Training Params ---->
# Dataset size:11197
# Dataset size:2800
# 2022-05-05 23:33:01,474 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# Downloading: "https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth" to /root/.cache/torch/hub/checkpoints/swin_large_patch4_window12_384_22k.pth
# 100%|██████████| 700/700 [09:10<00:00,  1.27it/s]
# 2022-05-05 23:45:04,218 INFO: Epoch:[001/100]
# 2022-05-05 23:45:04,219 INFO: Train Loss:3.641 | Acc:0.1478 | F1:0.1009
# 2022-05-05 23:45:55,782 INFO: val Loss:1.851 | Acc:0.3554 | F1:0.2064
# 2022-05-05 23:45:59,151 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [08:37<00:00,  1.35it/s]
# 2022-05-05 23:54:36,263 INFO: Epoch:[002/100]
# 2022-05-05 23:54:36,263 INFO: Train Loss:0.984 | Acc:0.5769 | F1:0.5393
# 2022-05-05 23:55:26,455 INFO: val Loss:0.382 | Acc:0.8004 | F1:0.7628
# 2022-05-05 23:55:31,317 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [08:42<00:00,  1.34it/s]
# 2022-05-06 00:04:13,962 INFO: Epoch:[003/100]
# 2022-05-06 00:04:13,963 INFO: Train Loss:0.241 | Acc:0.8676 | F1:0.8604
# 2022-05-06 00:05:04,282 INFO: val Loss:0.081 | Acc:0.9479 | F1:0.9422
# 2022-05-06 00:05:09,134 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [08:44<00:00,  1.33it/s]
# 2022-05-06 00:13:53,875 INFO: Epoch:[004/100]
# 2022-05-06 00:13:53,876 INFO: Train Loss:0.080 | Acc:0.9477 | F1:0.9451
# 2022-05-06 00:14:45,695 INFO: val Loss:0.060 | Acc:0.9621 | F1:0.9586
# 2022-05-06 00:14:50,879 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [08:34<00:00,  1.36it/s]
# 2022-05-06 00:23:25,368 INFO: Epoch:[005/100]
# 2022-05-06 00:23:25,369 INFO: Train Loss:0.061 | Acc:0.9597 | F1:0.9586
# 2022-05-06 00:24:19,601 INFO: val Loss:0.014 | Acc:0.9879 | F1:0.9891
# 2022-05-06 00:24:24,774 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [08:47<00:00,  1.33it/s]
# 2022-05-06 00:33:12,523 INFO: Epoch:[006/100]
# 2022-05-06 00:33:12,524 INFO: Train Loss:0.047 | Acc:0.9677 | F1:0.9660
# 2022-05-06 00:34:02,720 INFO: val Loss:0.042 | Acc:0.9636 | F1:0.9687
# 100%|██████████| 700/700 [08:39<00:00,  1.35it/s]
# 2022-05-06 00:42:41,881 INFO: Epoch:[007/100]
# 2022-05-06 00:42:41,882 INFO: Train Loss:0.040 | Acc:0.9751 | F1:0.9758
# 2022-05-06 00:43:39,352 INFO: val Loss:0.015 | Acc:0.9875 | F1:0.9877
# 100%|██████████| 700/700 [08:33<00:00,  1.36it/s]
# 2022-05-06 00:52:13,309 INFO: Epoch:[008/100]
# 2022-05-06 00:52:13,310 INFO: Train Loss:0.029 | Acc:0.9804 | F1:0.9798
# 2022-05-06 00:53:03,021 INFO: val Loss:0.010 | Acc:0.9939 | F1:0.9936
# 2022-05-06 00:53:08,161 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [08:47<00:00,  1.33it/s]
# 2022-05-06 01:01:56,082 INFO: Epoch:[009/100]
# 2022-05-06 01:01:56,083 INFO: Train Loss:0.027 | Acc:0.9815 | F1:0.9823
# 2022-05-06 01:02:45,614 INFO: val Loss:0.005 | Acc:0.9964 | F1:0.9967
# 2022-05-06 01:02:50,648 INFO: -----------------SAVE:9epoch----------------
# 100%|██████████| 700/700 [08:31<00:00,  1.37it/s]
# 2022-05-06 01:11:22,462 INFO: Epoch:[010/100]
# 2022-05-06 01:11:22,463 INFO: Train Loss:0.025 | Acc:0.9860 | F1:0.9863
# 2022-05-06 01:12:13,488 INFO: val Loss:0.010 | Acc:0.9914 | F1:0.9931
# 100%|██████████| 700/700 [09:10<00:00,  1.27it/s]
# 2022-05-06 01:21:24,262 INFO: Epoch:[011/100]
# 2022-05-06 01:21:24,262 INFO: Train Loss:0.019 | Acc:0.9869 | F1:0.9871
# 2022-05-06 01:22:29,073 INFO: val Loss:0.019 | Acc:0.9889 | F1:0.9897
# 100%|██████████| 700/700 [10:05<00:00,  1.16it/s]
# 2022-05-06 01:32:34,685 INFO: Epoch:[012/100]
# 2022-05-06 01:32:34,686 INFO: Train Loss:0.022 | Acc:0.9869 | F1:0.9871
# 2022-05-06 01:33:38,209 INFO: val Loss:0.010 | Acc:0.9925 | F1:0.9926
# 100%|██████████| 700/700 [10:08<00:00,  1.15it/s]
# 2022-05-06 01:43:46,312 INFO: Epoch:[013/100]
# 2022-05-06 01:43:46,313 INFO: Train Loss:0.019 | Acc:0.9899 | F1:0.9899
# 2022-05-06 01:44:51,188 INFO: val Loss:0.015 | Acc:0.9914 | F1:0.9931
# 100%|██████████| 700/700 [10:06<00:00,  1.15it/s]
# 2022-05-06 01:54:57,962 INFO: Epoch:[014/100]
# 2022-05-06 01:54:57,963 INFO: Train Loss:0.016 | Acc:0.9901 | F1:0.9911
# 2022-05-06 01:56:01,009 INFO: val Loss:0.008 | Acc:0.9950 | F1:0.9952
# 2022-05-06 01:56:01,011 INFO:
# Best Val Epoch:9 | Val Loss:0.0055 | Val Acc:0.9964 | Val F1:0.9967
# 2022-05-06 01:56:01,012 INFO: Total Process time:140.120Minute
# 2022-05-06 01:56:01,025 INFO: {'exp_num': '1', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_swin_large_patch4_window12_384_in22k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'swin_large_patch4_window12_384_in22k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 1}
# <---- Training Params ---->
# Dataset size:11197
# Dataset size:2800
# 2022-05-06 01:56:03,817 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 700/700 [10:11<00:00,  1.15it/s]
# 2022-05-06 02:06:15,861 INFO: Epoch:[001/100]
# 2022-05-06 02:06:15,861 INFO: Train Loss:3.623 | Acc:0.1483 | F1:0.1026
# 2022-05-06 02:07:19,849 INFO: val Loss:1.851 | Acc:0.3664 | F1:0.2274
# 2022-05-06 02:07:23,113 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [07:42<00:00,  1.52it/s]
# 2022-05-06 02:15:05,176 INFO: Epoch:[002/100]
# 2022-05-06 02:15:05,176 INFO: Train Loss:0.971 | Acc:0.5811 | F1:0.5442
# 2022-05-06 02:15:45,949 INFO: val Loss:0.359 | Acc:0.7946 | F1:0.7593
# 2022-05-06 02:15:50,823 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-06 02:23:08,855 INFO: Epoch:[003/100]
# 2022-05-06 02:23:08,856 INFO: Train Loss:0.235 | Acc:0.8703 | F1:0.8652
# 2022-05-06 02:23:49,768 INFO: val Loss:0.083 | Acc:0.9389 | F1:0.9344
# 2022-05-06 02:23:54,715 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [07:28<00:00,  1.56it/s]
# 2022-05-06 02:31:23,078 INFO: Epoch:[004/100]
# 2022-05-06 02:31:23,079 INFO: Train Loss:0.074 | Acc:0.9514 | F1:0.9497
# 2022-05-06 02:32:03,700 INFO: val Loss:0.024 | Acc:0.9836 | F1:0.9828
# 2022-05-06 02:32:08,771 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-06 02:39:34,108 INFO: Epoch:[005/100]
# 2022-05-06 02:39:34,109 INFO: Train Loss:0.058 | Acc:0.9628 | F1:0.9605
# 2022-05-06 02:40:15,787 INFO: val Loss:0.066 | Acc:0.9693 | F1:0.9607
# 100%|██████████| 700/700 [07:17<00:00,  1.60it/s]
# 2022-05-06 02:47:33,141 INFO: Epoch:[006/100]
# 2022-05-06 02:47:33,142 INFO: Train Loss:0.050 | Acc:0.9688 | F1:0.9702
# 2022-05-06 02:48:13,850 INFO: val Loss:0.035 | Acc:0.9782 | F1:0.9788
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-06 02:55:36,902 INFO: Epoch:[007/100]
# 2022-05-06 02:55:36,903 INFO: Train Loss:0.035 | Acc:0.9774 | F1:0.9765
# 2022-05-06 02:56:17,545 INFO: val Loss:0.012 | Acc:0.9936 | F1:0.9939
# 2022-05-06 02:56:22,308 INFO: -----------------SAVE:7epoch----------------
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-06 03:03:41,137 INFO: Epoch:[008/100]
# 2022-05-06 03:03:41,138 INFO: Train Loss:0.028 | Acc:0.9820 | F1:0.9822
# 2022-05-06 03:04:22,386 INFO: val Loss:0.041 | Acc:0.9757 | F1:0.9785
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-06 03:11:45,731 INFO: Epoch:[009/100]
# 2022-05-06 03:11:45,732 INFO: Train Loss:0.025 | Acc:0.9849 | F1:0.9862
# 2022-05-06 03:12:25,942 INFO: val Loss:0.102 | Acc:0.9686 | F1:0.9626
# 100%|██████████| 700/700 [07:24<00:00,  1.57it/s]
# 2022-05-06 03:19:50,422 INFO: Epoch:[010/100]
# 2022-05-06 03:19:50,423 INFO: Train Loss:0.022 | Acc:0.9862 | F1:0.9866
# 2022-05-06 03:20:31,301 INFO: val Loss:0.024 | Acc:0.9864 | F1:0.9884
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-06 03:27:49,458 INFO: Epoch:[011/100]
# 2022-05-06 03:27:49,459 INFO: Train Loss:0.022 | Acc:0.9881 | F1:0.9881
# 2022-05-06 03:28:30,355 INFO: val Loss:0.008 | Acc:0.9950 | F1:0.9955
# 2022-05-06 03:28:35,629 INFO: -----------------SAVE:11epoch----------------
# 100%|██████████| 700/700 [07:26<00:00,  1.57it/s]
# 2022-05-06 03:36:02,249 INFO: Epoch:[012/100]
# 2022-05-06 03:36:02,250 INFO: Train Loss:0.019 | Acc:0.9886 | F1:0.9881
# 2022-05-06 03:36:42,986 INFO: val Loss:0.013 | Acc:0.9904 | F1:0.9891
# 100%|██████████| 700/700 [07:15<00:00,  1.61it/s]
# 2022-05-06 03:43:58,640 INFO: Epoch:[013/100]
# 2022-05-06 03:43:58,641 INFO: Train Loss:0.015 | Acc:0.9899 | F1:0.9896
# 2022-05-06 03:44:38,466 INFO: val Loss:0.005 | Acc:0.9954 | F1:0.9958
# 2022-05-06 03:44:43,288 INFO: -----------------SAVE:13epoch----------------
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-06 03:52:08,324 INFO: Epoch:[014/100]
# 2022-05-06 03:52:08,325 INFO: Train Loss:0.017 | Acc:0.9903 | F1:0.9914
# 2022-05-06 03:52:49,488 INFO: val Loss:0.006 | Acc:0.9939 | F1:0.9946
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-06 04:00:07,815 INFO: Epoch:[015/100]
# 2022-05-06 04:00:07,815 INFO: Train Loss:0.018 | Acc:0.9912 | F1:0.9913
# 2022-05-06 04:00:57,724 INFO: val Loss:0.013 | Acc:0.9918 | F1:0.9927
# 100%|██████████| 700/700 [07:16<00:00,  1.60it/s]
# 2022-05-06 04:08:14,598 INFO: Epoch:[016/100]
# 2022-05-06 04:08:14,599 INFO: Train Loss:0.014 | Acc:0.9908 | F1:0.9910
# 2022-05-06 04:08:54,226 INFO: val Loss:0.021 | Acc:0.9914 | F1:0.9914
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-06 04:16:18,208 INFO: Epoch:[017/100]
# 2022-05-06 04:16:18,209 INFO: Train Loss:0.019 | Acc:0.9907 | F1:0.9903
# 2022-05-06 04:16:59,049 INFO: val Loss:0.010 | Acc:0.9932 | F1:0.9940
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-06 04:24:17,608 INFO: Epoch:[018/100]
# 2022-05-06 04:24:17,609 INFO: Train Loss:0.013 | Acc:0.9912 | F1:0.9912
# 2022-05-06 04:24:58,667 INFO: val Loss:0.013 | Acc:0.9943 | F1:0.9948
# 2022-05-06 04:24:58,669 INFO:
# Best Val Epoch:13 | Val Loss:0.0054 | Val Acc:0.9954 | Val F1:0.9958
# 2022-05-06 04:24:58,670 INFO: Total Process time:148.900Minute
# 2022-05-06 04:24:58,687 INFO: {'exp_num': '2', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_swin_large_patch4_window12_384_in22k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'swin_large_patch4_window12_384_in22k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 2}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-06 04:25:01,746 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 700/700 [07:27<00:00,  1.57it/s]
# 2022-05-06 04:32:29,721 INFO: Epoch:[001/100]
# 2022-05-06 04:32:29,721 INFO: Train Loss:3.639 | Acc:0.1440 | F1:0.1020
# 2022-05-06 04:33:11,253 INFO: val Loss:1.824 | Acc:0.3673 | F1:0.2290
# 2022-05-06 04:33:14,874 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-06 04:40:33,274 INFO: Epoch:[002/100]
# 2022-05-06 04:40:33,275 INFO: Train Loss:0.975 | Acc:0.5820 | F1:0.5432
# 2022-05-06 04:41:14,238 INFO: val Loss:0.369 | Acc:0.8010 | F1:0.7723
# 2022-05-06 04:41:19,420 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [07:26<00:00,  1.57it/s]
# 2022-05-06 04:48:46,366 INFO: Epoch:[003/100]
# 2022-05-06 04:48:46,367 INFO: Train Loss:0.233 | Acc:0.8767 | F1:0.8695
# 2022-05-06 04:49:27,000 INFO: val Loss:0.081 | Acc:0.9428 | F1:0.9376
# 2022-05-06 04:49:32,255 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-06 04:56:57,817 INFO: Epoch:[004/100]
# 2022-05-06 04:56:57,818 INFO: Train Loss:0.080 | Acc:0.9495 | F1:0.9473
# 2022-05-06 04:57:38,800 INFO: val Loss:0.043 | Acc:0.9689 | F1:0.9615
# 2022-05-06 04:57:43,999 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [07:22<00:00,  1.58it/s]
# 2022-05-06 05:05:06,581 INFO: Epoch:[005/100]
# 2022-05-06 05:05:06,582 INFO: Train Loss:0.050 | Acc:0.9649 | F1:0.9642
# 2022-05-06 05:05:47,872 INFO: val Loss:0.031 | Acc:0.9761 | F1:0.9781
# 2022-05-06 05:05:53,056 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-06 05:13:16,292 INFO: Epoch:[006/100]
# 2022-05-06 05:13:16,292 INFO: Train Loss:0.041 | Acc:0.9729 | F1:0.9725
# 2022-05-06 05:13:56,743 INFO: val Loss:0.032 | Acc:0.9768 | F1:0.9749
# 100%|██████████| 700/700 [07:20<00:00,  1.59it/s]
# 2022-05-06 05:21:17,588 INFO: Epoch:[007/100]
# 2022-05-06 05:21:17,588 INFO: Train Loss:0.037 | Acc:0.9748 | F1:0.9746
# 2022-05-06 05:21:59,164 INFO: val Loss:0.021 | Acc:0.9854 | F1:0.9863
# 2022-05-06 05:22:04,270 INFO: -----------------SAVE:7epoch----------------
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-06 05:29:29,312 INFO: Epoch:[008/100]
# 2022-05-06 05:29:29,313 INFO: Train Loss:0.031 | Acc:0.9811 | F1:0.9813
# 2022-05-06 05:30:09,632 INFO: val Loss:0.014 | Acc:0.9889 | F1:0.9874
# 2022-05-06 05:30:14,224 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [07:21<00:00,  1.58it/s]
# 2022-05-06 05:37:35,894 INFO: Epoch:[009/100]
# 2022-05-06 05:37:35,895 INFO: Train Loss:0.023 | Acc:0.9844 | F1:0.9850
# 2022-05-06 05:38:15,936 INFO: val Loss:0.018 | Acc:0.9882 | F1:0.9829
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-06 05:45:34,468 INFO: Epoch:[010/100]
# 2022-05-06 05:45:34,469 INFO: Train Loss:0.022 | Acc:0.9869 | F1:0.9873
# 2022-05-06 05:46:14,962 INFO: val Loss:0.019 | Acc:0.9900 | F1:0.9926
# 100%|██████████| 700/700 [07:27<00:00,  1.56it/s]
# 2022-05-06 05:53:42,934 INFO: Epoch:[011/100]
# 2022-05-06 05:53:42,935 INFO: Train Loss:0.020 | Acc:0.9872 | F1:0.9869
# 2022-05-06 05:54:24,743 INFO: val Loss:0.009 | Acc:0.9918 | F1:0.9926
# 2022-05-06 05:54:29,877 INFO: -----------------SAVE:11epoch----------------
# 100%|██████████| 700/700 [07:19<00:00,  1.59it/s]
# 2022-05-06 06:01:49,424 INFO: Epoch:[012/100]
# 2022-05-06 06:01:49,425 INFO: Train Loss:0.021 | Acc:0.9879 | F1:0.9882
# 2022-05-06 06:02:29,895 INFO: val Loss:0.018 | Acc:0.9882 | F1:0.9876
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-06 06:09:53,458 INFO: Epoch:[013/100]
# 2022-05-06 06:09:53,459 INFO: Train Loss:0.020 | Acc:0.9876 | F1:0.9871
# 2022-05-06 06:10:33,645 INFO: val Loss:0.016 | Acc:0.9904 | F1:0.9916
# 100%|██████████| 700/700 [07:27<00:00,  1.56it/s]
# 2022-05-06 06:18:01,088 INFO: Epoch:[014/100]
# 2022-05-06 06:18:01,089 INFO: Train Loss:0.015 | Acc:0.9911 | F1:0.9920
# 2022-05-06 06:18:43,099 INFO: val Loss:0.007 | Acc:0.9968 | F1:0.9973
# 2022-05-06 06:18:48,553 INFO: -----------------SAVE:14epoch----------------
# 100%|██████████| 700/700 [07:19<00:00,  1.59it/s]
# 2022-05-06 06:26:07,863 INFO: Epoch:[015/100]
# 2022-05-06 06:26:07,865 INFO: Train Loss:0.015 | Acc:0.9912 | F1:0.9914
# 2022-05-06 06:26:48,656 INFO: val Loss:0.017 | Acc:0.9850 | F1:0.9863
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-06 06:34:12,478 INFO: Epoch:[016/100]
# 2022-05-06 06:34:12,479 INFO: Train Loss:0.014 | Acc:0.9915 | F1:0.9923
# 2022-05-06 06:34:53,036 INFO: val Loss:0.011 | Acc:0.9936 | F1:0.9934
# 100%|██████████| 700/700 [07:21<00:00,  1.59it/s]
# 2022-05-06 06:42:14,202 INFO: Epoch:[017/100]
# 2022-05-06 06:42:14,203 INFO: Train Loss:0.014 | Acc:0.9919 | F1:0.9922
# 2022-05-06 06:42:55,725 INFO: val Loss:0.011 | Acc:0.9921 | F1:0.9924
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-06 06:50:19,003 INFO: Epoch:[018/100]
# 2022-05-06 06:50:19,004 INFO: Train Loss:0.014 | Acc:0.9925 | F1:0.9930
# 2022-05-06 06:50:59,807 INFO: val Loss:0.009 | Acc:0.9946 | F1:0.9949
# 100%|██████████| 700/700 [07:21<00:00,  1.58it/s]
# 2022-05-06 06:58:21,590 INFO: Epoch:[019/100]
# 2022-05-06 06:58:21,591 INFO: Train Loss:0.012 | Acc:0.9924 | F1:0.9932
# 2022-05-06 06:59:08,059 INFO: val Loss:0.005 | Acc:0.9971 | F1:0.9974
# 2022-05-06 06:59:13,353 INFO: -----------------SAVE:19epoch----------------
# 100%|██████████| 700/700 [07:20<00:00,  1.59it/s]
# 2022-05-06 07:06:33,568 INFO: Epoch:[020/100]
# 2022-05-06 07:06:33,569 INFO: Train Loss:0.014 | Acc:0.9930 | F1:0.9929
# 2022-05-06 07:07:14,171 INFO: val Loss:0.003 | Acc:0.9968 | F1:0.9973
# 2022-05-06 07:07:19,270 INFO: -----------------SAVE:20epoch----------------
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-06 07:14:45,255 INFO: Epoch:[021/100]
# 2022-05-06 07:14:45,255 INFO: Train Loss:0.014 | Acc:0.9934 | F1:0.9928
# 2022-05-06 07:15:25,479 INFO: val Loss:0.006 | Acc:0.9961 | F1:0.9960
# 100%|██████████| 700/700 [07:17<00:00,  1.60it/s]
# 2022-05-06 07:22:42,639 INFO: Epoch:[022/100]
# 2022-05-06 07:22:42,639 INFO: Train Loss:0.013 | Acc:0.9929 | F1:0.9930
# 2022-05-06 07:23:22,852 INFO: val Loss:0.005 | Acc:0.9957 | F1:0.9959
# 100%|██████████| 700/700 [07:24<00:00,  1.58it/s]
# 2022-05-06 07:30:47,294 INFO: Epoch:[023/100]
# 2022-05-06 07:30:47,295 INFO: Train Loss:0.011 | Acc:0.9946 | F1:0.9950
# 2022-05-06 07:31:28,293 INFO: val Loss:0.009 | Acc:0.9961 | F1:0.9968
# 100%|██████████| 700/700 [07:19<00:00,  1.59it/s]
# 2022-05-06 07:38:47,672 INFO: Epoch:[024/100]
# 2022-05-06 07:38:47,673 INFO: Train Loss:0.012 | Acc:0.9930 | F1:0.9935
# 2022-05-06 07:39:27,473 INFO: val Loss:0.019 | Acc:0.9929 | F1:0.9939
# 100%|██████████| 700/700 [07:27<00:00,  1.56it/s]
# 2022-05-06 07:46:54,997 INFO: Epoch:[025/100]
# 2022-05-06 07:46:54,998 INFO: Train Loss:0.013 | Acc:0.9934 | F1:0.9942
# 2022-05-06 07:47:35,573 INFO: val Loss:0.006 | Acc:0.9957 | F1:0.9968
# 2022-05-06 07:47:35,575 INFO:
# Best Val Epoch:20 | Val Loss:0.0031 | Val Acc:0.9968 | Val F1:0.9973
# 2022-05-06 07:47:35,575 INFO: Total Process time:202.549Minute
# 2022-05-06 07:47:35,591 INFO: {'exp_num': '3', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_swin_large_patch4_window12_384_in22k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'swin_large_patch4_window12_384_in22k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 3}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-06 07:47:38,572 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-06 07:55:05,350 INFO: Epoch:[001/100]
# 2022-05-06 07:55:05,351 INFO: Train Loss:3.645 | Acc:0.1451 | F1:0.0972
# 2022-05-06 07:55:46,508 INFO: val Loss:1.876 | Acc:0.3508 | F1:0.2144
# 2022-05-06 07:55:49,812 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [07:19<00:00,  1.59it/s]
# 2022-05-06 08:03:09,093 INFO: Epoch:[002/100]
# 2022-05-06 08:03:09,094 INFO: Train Loss:0.981 | Acc:0.5734 | F1:0.5348
# 2022-05-06 08:03:50,326 INFO: val Loss:0.366 | Acc:0.8042 | F1:0.7646
# 2022-05-06 08:03:55,289 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [07:28<00:00,  1.56it/s]
# 2022-05-06 08:11:23,582 INFO: Epoch:[003/100]
# 2022-05-06 08:11:23,583 INFO: Train Loss:0.240 | Acc:0.8668 | F1:0.8588
# 2022-05-06 08:12:04,110 INFO: val Loss:0.076 | Acc:0.9475 | F1:0.9443
# 2022-05-06 08:12:08,921 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [07:19<00:00,  1.59it/s]
# 2022-05-06 08:19:28,815 INFO: Epoch:[004/100]
# 2022-05-06 08:19:28,816 INFO: Train Loss:0.077 | Acc:0.9489 | F1:0.9467
# 2022-05-06 08:20:09,484 INFO: val Loss:0.058 | Acc:0.9657 | F1:0.9604
# 2022-05-06 08:20:14,588 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [07:26<00:00,  1.57it/s]
# 2022-05-06 08:27:40,843 INFO: Epoch:[005/100]
# 2022-05-06 08:27:40,844 INFO: Train Loss:0.058 | Acc:0.9599 | F1:0.9582
# 2022-05-06 08:28:21,383 INFO: val Loss:0.034 | Acc:0.9721 | F1:0.9698
# 2022-05-06 08:28:26,434 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-06 08:35:51,559 INFO: Epoch:[006/100]
# 2022-05-06 08:35:51,560 INFO: Train Loss:0.048 | Acc:0.9670 | F1:0.9666
# 2022-05-06 08:36:31,726 INFO: val Loss:0.010 | Acc:0.9911 | F1:0.9915
# 2022-05-06 08:36:36,671 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [07:20<00:00,  1.59it/s]
# 2022-05-06 08:43:56,974 INFO: Epoch:[007/100]
# 2022-05-06 08:43:56,975 INFO: Train Loss:0.030 | Acc:0.9813 | F1:0.9808
# 2022-05-06 08:44:38,649 INFO: val Loss:0.006 | Acc:0.9936 | F1:0.9928
# 2022-05-06 08:44:43,722 INFO: -----------------SAVE:7epoch----------------
# 100%|██████████| 700/700 [07:28<00:00,  1.56it/s]
# 2022-05-06 08:52:12,362 INFO: Epoch:[008/100]
# 2022-05-06 08:52:12,362 INFO: Train Loss:0.027 | Acc:0.9827 | F1:0.9823
# 2022-05-06 08:52:51,742 INFO: val Loss:0.048 | Acc:0.9593 | F1:0.9618
# 100%|██████████| 700/700 [07:17<00:00,  1.60it/s]
# 2022-05-06 09:00:09,143 INFO: Epoch:[009/100]
# 2022-05-06 09:00:09,143 INFO: Train Loss:0.030 | Acc:0.9817 | F1:0.9824
# 2022-05-06 09:00:50,049 INFO: val Loss:0.007 | Acc:0.9932 | F1:0.9934
# 100%|██████████| 700/700 [09:19<00:00,  1.25it/s]
# 2022-05-06 09:10:09,815 INFO: Epoch:[010/100]
# 2022-05-06 09:10:09,816 INFO: Train Loss:0.023 | Acc:0.9860 | F1:0.9859
# 2022-05-06 09:11:01,538 INFO: val Loss:0.013 | Acc:0.9911 | F1:0.9925
# 100%|██████████| 700/700 [10:40<00:00,  1.09it/s]
# 2022-05-06 09:21:41,850 INFO: Epoch:[011/100]
# 2022-05-06 09:21:41,850 INFO: Train Loss:0.020 | Acc:0.9867 | F1:0.9872
# 2022-05-06 09:22:32,821 INFO: val Loss:0.012 | Acc:0.9861 | F1:0.9878
# 100%|██████████| 700/700 [10:47<00:00,  1.08it/s]
# 2022-05-06 09:33:20,690 INFO: Epoch:[012/100]
# 2022-05-06 09:33:20,691 INFO: Train Loss:0.021 | Acc:0.9871 | F1:0.9874
# 2022-05-06 09:34:14,861 INFO: val Loss:0.008 | Acc:0.9932 | F1:0.9935
# 2022-05-06 09:34:14,864 INFO:
# Best Val Epoch:7 | Val Loss:0.0062 | Val Acc:0.9936 | Val F1:0.9928
# 2022-05-06 09:34:14,864 INFO: Total Process time:106.591Minute
# 2022-05-06 09:34:14,880 INFO: {'exp_num': '4', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_swin_large_patch4_window12_384_in22k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'swin_large_patch4_window12_384_in22k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 4}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-06 09:34:18,105 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 700/700 [10:27<00:00,  1.12it/s]
# 2022-05-06 09:44:46,231 INFO: Epoch:[001/100]
# 2022-05-06 09:44:46,232 INFO: Train Loss:3.634 | Acc:0.1461 | F1:0.1042
# 2022-05-06 09:45:37,807 INFO: val Loss:1.806 | Acc:0.3448 | F1:0.2094
# 2022-05-06 09:45:41,235 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [10:43<00:00,  1.09it/s]
# 2022-05-06 09:56:24,420 INFO: Epoch:[002/100]
# 2022-05-06 09:56:24,421 INFO: Train Loss:0.969 | Acc:0.5888 | F1:0.5520
# 2022-05-06 09:57:16,469 INFO: val Loss:0.386 | Acc:0.7921 | F1:0.7563
# 2022-05-06 09:57:21,606 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [10:44<00:00,  1.09it/s]
# 2022-05-06 10:08:05,923 INFO: Epoch:[003/100]
# 2022-05-06 10:08:05,923 INFO: Train Loss:0.237 | Acc:0.8702 | F1:0.8615
# 2022-05-06 10:08:56,977 INFO: val Loss:0.045 | Acc:0.9650 | F1:0.9611
# 2022-05-06 10:09:01,892 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [10:47<00:00,  1.08it/s]
# 2022-05-06 10:19:49,510 INFO: Epoch:[004/100]
# 2022-05-06 10:19:49,511 INFO: Train Loss:0.077 | Acc:0.9468 | F1:0.9436
# 2022-05-06 10:20:40,561 INFO: val Loss:0.044 | Acc:0.9714 | F1:0.9710
# 2022-05-06 10:20:45,770 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [10:36<00:00,  1.10it/s]
# 2022-05-06 10:31:22,047 INFO: Epoch:[005/100]
# 2022-05-06 10:31:22,047 INFO: Train Loss:0.053 | Acc:0.9643 | F1:0.9630
# 2022-05-06 10:32:13,354 INFO: val Loss:0.034 | Acc:0.9703 | F1:0.9690
# 2022-05-06 10:32:20,441 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [10:44<00:00,  1.09it/s]
# 2022-05-06 10:43:04,582 INFO: Epoch:[006/100]
# 2022-05-06 10:43:04,583 INFO: Train Loss:0.044 | Acc:0.9715 | F1:0.9708
# 2022-05-06 10:43:56,620 INFO: val Loss:0.011 | Acc:0.9914 | F1:0.9909
# 2022-05-06 10:44:01,697 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [10:45<00:00,  1.08it/s]
# 2022-05-06 10:54:47,014 INFO: Epoch:[007/100]
# 2022-05-06 10:54:47,014 INFO: Train Loss:0.032 | Acc:0.9789 | F1:0.9799
# 2022-05-06 10:55:42,920 INFO: val Loss:0.015 | Acc:0.9907 | F1:0.9908
# 100%|██████████| 700/700 [10:38<00:00,  1.10it/s]
# 2022-05-06 11:06:21,311 INFO: Epoch:[008/100]
# 2022-05-06 11:06:21,311 INFO: Train Loss:0.032 | Acc:0.9815 | F1:0.9822
# 2022-05-06 11:07:12,579 INFO: val Loss:0.013 | Acc:0.9889 | F1:0.9890
# 100%|██████████| 700/700 [10:47<00:00,  1.08it/s]
# 2022-05-06 11:18:00,526 INFO: Epoch:[009/100]
# 2022-05-06 11:18:00,527 INFO: Train Loss:0.025 | Acc:0.9849 | F1:0.9846
# 2022-05-06 11:18:51,973 INFO: val Loss:0.030 | Acc:0.9825 | F1:0.9804
# 100%|██████████| 700/700 [10:39<00:00,  1.10it/s]
# 2022-05-06 11:29:31,191 INFO: Epoch:[010/100]
# 2022-05-06 11:29:31,192 INFO: Train Loss:0.020 | Acc:0.9849 | F1:0.9860
# 2022-05-06 11:30:23,478 INFO: val Loss:0.062 | Acc:0.9736 | F1:0.9763
# 100%|██████████| 700/700 [10:50<00:00,  1.08it/s]
# 2022-05-06 11:41:14,336 INFO: Epoch:[011/100]
# 2022-05-06 11:41:14,337 INFO: Train Loss:0.023 | Acc:0.9879 | F1:0.9880
# 2022-05-06 11:42:06,200 INFO: val Loss:0.036 | Acc:0.9857 | F1:0.9883
# 2022-05-06 11:42:06,202 INFO:
# Best Val Epoch:6 | Val Loss:0.0115 | Val Acc:0.9914 | Val F1:0.9909
# 2022-05-06 11:42:06,202 INFO: Total Process time:127.787Minute

# %%
img_size = 384

test_transform = get_train_augmentation(img_size=img_size, ver=1)
test_dataset = Test_dataset(df_test, test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0)
# Out:
# Test Dataset size:2154

# %%
# models_path = ['./label_results/000', './label_results/001', './label_results/002', './label_results/003', './label_results/004']

# %%
ensemble = ensemble_5fold(models_path, test_loader, device)
# Out:
# 2022-05-06 11:42:09,524 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 34/34 [10:40<00:00, 18.82s/it]
# 2022-05-06 11:52:54,997 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 34/34 [10:21<00:00, 18.29s/it]
# 2022-05-06 12:03:22,271 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 34/34 [10:19<00:00, 18.23s/it]
# 2022-05-06 12:13:47,634 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 34/34 [10:37<00:00, 18.76s/it]
# 2022-05-06 12:24:30,600 INFO: Loading pretrained weights from url (https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_large_patch4_window12_384_22k.pth)
# 100%|██████████| 34/34 [10:20<00:00, 18.26s/it]

# %%
f_pred = ensemble.argmax(axis=1).tolist()
f_pred
# Out:
# [62,
#  28,
#  72,
#  64,
#  63,
#  50,
#  14,
#  32,
#  40,
#  39,
#  0,
#  76,
#  85,
#  59,
#  62,
#  2,
#  25,
#  20,
#  21,
#  47,
#  66,
#  84,
#  0,
#  58,
#  54,
#  55,
#  51,
#  60,
#  40,
#  78,
#  55,
#  9,
#  59,
#  83,
#  84,
#  82,
#  40,
#  9,
#  37,
#  44,
#  45,
#  10,
#  60,
#  14,
#  44,
#  63,
#  68,
#  13,
#  84,
#  55,
#  9,
#  72,
#  31,
#  35,
#  84,
#  46,
#  20,
#  21,
#  38,
#  15,
#  72,
#  48,
#  18,
#  80,
#  13,
#  36,
#  72,
#  13,
#  53,
#  43,
#  25,
#  77,
#  32,
#  61,
#  41,
#  84,
#  9,
#  40,
#  9,
#  9,
#  50,
#  79,
#  57,
#  75,
#  72,
#  0,
#  84,
#  21,
#  40,
#  83,
#  36,
#  84,
#  9,
#  42,
#  55,
#  65,
#  72,
#  72,
#  45,
#  45,
#  9,
#  21,
#  52,
#  17,
#  76,
#  2,
#  85,
#  49,
#  72,
#  34,
#  36,
#  58,
#  73,
#  72,
#  84,
#  15,
#  28,
#  52,
#  13,
#  41,
#  55,
#  19,
#  45,
#  72,
#  77,
#  70,
#  61,
#  72,
#  54,
#  55,
#  28,
#  46,
#  50,
#  42,
#  15,
#  25,
#  57,
#  2,
#  52,
#  78,
#  73,
#  33,
#  7,
#  9,
#  84,
#  35,
#  23,
#  84,
#  85,
#  76,
#  84,
#  79,
#  72,
#  52,
#  83,
#  63,
#  67,
#  63,
#  33,
#  45,
#  57,
#  60,
#  57,
#  11,
#  21,
#  38,
#  49,
#  79,
#  83,
#  10,
#  21,
#  24,
#  56,
#  39,
#  9,
#  52,
#  55,
#  86,
#  15,
#  84,
#  40,
#  27,
#  3,
#  11,
#  51,
#  20,
#  62,
#  45,
#  79,
#  70,
#  54,
#  18,
#  84,
#  32,
#  52,
#  57,
#  83,
#  85,
#  84,
#  33,
#  72,
#  12,
#  59,
#  1,
#  52,
#  40,
#  52,
#  52,
#  33,
#  25,
#  41,
#  15,
#  55,
#  79,
#  48,
#  20,
#  18,
#  49,
#  72,
#  1,
#  65,
#  28,
#  63,
#  1,
#  13,
#  43,
#  51,
#  36,
#  9,
#  72,
#  52,
#  55,
#  83,
#  49,
#  80,
#  17,
#  72,
#  45,
#  31,
#  14,
#  45,
#  34,
#  85,
#  59,
#  74,
#  41,
#  63,
#  64,
#  79,
#  9,
#  72,
#  64,
#  4,
#  15,
#  44,
#  45,
#  45,
#  13,
#  87,
#  33,
#  31,
#  55,
#  33,
#  32,
#  41,
#  40,
#  76,
#  55,
#  44,
#  9,
#  21,
#  55,
#  77,
#  73,
#  9,
#  15,
#  47,
#  15,
#  72,
#  87,
#  48,
#  36,
#  72,
#  53,
#  52,
#  55,
#  30,
#  63,
#  63,
#  0,
#  22,
#  1,
#  38,
#  37,
#  9,
#  87,
#  63,
#  72,
#  72,
#  72,
#  58,
#  41,
#  80,
#  72,
#  57,
#  51,
#  68,
#  28,
#  36,
#  56,
#  55,
#  72,
#  3,
#  46,
#  76,
#  72,
#  59,
#  76,
#  76,
#  63,
#  9,
#  58,
#  46,
#  7,
#  40,
#  15,
#  55,
#  56,
#  50,
#  72,
#  58,
#  15,
#  55,
#  21,
#  19,
#  3,
#  63,
#  43,
#  58,
#  4,
#  76,
#  55,
#  42,
#  63,
#  55,
#  39,
#  44,
#  42,
#  33,
#  53,
#  24,
#  5,
#  9,
#  17,
#  21,
#  16,
#  9,
#  52,
#  3,
#  67,
#  70,
#  13,
#  38,
#  19,
#  72,
#  85,
#  26,
#  7,
#  9,
#  37,
#  33,
#  55,
#  9,
#  3,
#  33,
#  72,
#  77,
#  56,
#  14,
#  28,
#  46,
#  55,
#  74,
#  62,
#  15,
#  28,
#  42,
#  14,
#  32,
#  55,
#  40,
#  43,
#  1,
#  37,
#  16,
#  72,
#  9,
#  2,
#  35,
#  63,
#  78,
#  64,
#  72,
#  81,
#  2,
#  63,
#  50,
#  17,
#  40,
#  51,
#  9,
#  16,
#  52,
#  9,
#  0,
#  72,
#  40,
#  72,
#  32,
#  69,
#  46,
#  84,
#  42,
#  21,
#  19,
#  50,
#  83,
#  84,
#  39,
#  71,
#  1,
#  84,
#  9,
#  1,
#  63,
#  31,
#  79,
#  51,
#  21,
#  29,
#  47,
#  65,
#  72,
#  56,
#  72,
#  70,
#  24,
#  80,
#  62,
#  38,
#  77,
#  84,
#  1,
#  21,
#  63,
#  33,
#  59,
#  33,
#  22,
#  44,
#  9,
#  21,
#  60,
#  41,
#  24,
#  14,
#  13,
#  44,
#  59,
#  45,
#  53,
#  42,
#  63,
#  3,
#  56,
#  9,
#  76,
#  72,
#  60,
#  60,
#  50,
#  59,
#  22,
#  9,
#  55,
#  55,
#  9,
#  28,
#  34,
#  51,
#  20,
#  12,
#  7,
#  55,
#  33,
#  18,
#  70,
#  67,
#  7,
#  86,
#  56,
#  65,
#  46,
#  72,
#  4,
#  63,
#  38,
#  78,
#  68,
#  41,
#  16,
#  56,
#  72,
#  72,
#  72,
#  84,
#  9,
#  46,
#  40,
#  9,
#  64,
#  53,
#  76,
#  45,
#  52,
#  81,
#  11,
#  76,
#  13,
#  20,
#  15,
#  34,
#  33,
#  34,
#  28,
#  55,
#  86,
#  79,
#  49,
#  67,
#  9,
#  76,
#  29,
#  55,
#  28,
#  80,
#  72,
#  63,
#  33,
#  54,
#  9,
#  13,
#  47,
#  52,
#  81,
#  62,
#  55,
#  15,
#  80,
#  56,
#  39,
#  14,
#  40,
#  23,
#  9,
#  33,
#  28,
#  28,
#  33,
#  59,
#  33,
#  79,
#  33,
#  52,
#  11,
#  77,
#  86,
#  21,
#  27,
#  82,
#  49,
#  42,
#  63,
#  22,
#  72,
#  72,
#  72,
#  21,
#  40,
#  72,
#  55,
#  32,
#  9,
#  87,
#  84,
#  42,
#  23,
#  63,
#  80,
#  33,
#  40,
#  33,
#  34,
#  7,
#  50,
#  9,
#  52,
#  9,
#  70,
#  51,
#  42,
#  27,
#  9,
#  19,
#  33,
#  16,
#  52,
#  86,
#  24,
#  4,
#  9,
#  8,
#  87,
#  62,
#  0,
#  22,
#  42,
#  68,
#  33,
#  1,
#  40,
#  67,
#  55,
#  58,
#  80,
#  40,
#  11,
#  15,
#  23,
#  41,
#  52,
#  38,
#  72,
#  0,
#  21,
#  83,
#  9,
#  37,
#  15,
#  86,
#  77,
#  35,
#  21,
#  55,
#  29,
#  79,
#  58,
#  13,
#  18,
#  40,
#  72,
#  8,
#  21,
#  72,
#  15,
#  28,
#  70,
#  33,
#  66,
#  9,
#  33,
#  50,
#  3,
#  54,
#  51,
#  0,
#  76,
#  54,
#  9,
#  63,
#  40,
#  38,
#  65,
#  52,
#  8,
#  63,
#  63,
#  33,
#  28,
#  40,
#  43,
#  10,
#  56,
#  47,
#  28,
#  5,
#  33,
#  85,
#  63,
#  2,
#  10,
#  41,
#  32,
#  58,
#  1,
#  19,
#  55,
#  71,
#  8,
#  76,
#  50,
#  52,
#  58,
#  30,
#  23,
#  79,
#  19,
#  41,
#  33,
#  84,
#  15,
#  72,
#  56,
#  72,
#  82,
#  72,
#  50,
#  33,
#  52,
#  4,
#  33,
#  3,
#  54,
#  52,
#  33,
#  42,
#  21,
#  52,
#  14,
#  79,
#  33,
#  24,
#  48,
#  52,
#  63,
#  21,
#  3,
#  50,
#  48,
#  13,
#  45,
#  9,
#  44,
#  72,
#  17,
#  65,
#  84,
#  3,
#  52,
#  13,
#  55,
#  34,
#  10,
#  54,
#  3,
#  15,
#  25,
#  82,
#  45,
#  47,
#  74,
#  23,
#  75,
#  83,
#  34,
#  59,
#  48,
#  55,
#  0,
#  13,
#  72,
#  36,
#  55,
#  75,
#  9,
#  40,
#  67,
#  68,
#  57,
#  8,
#  85,
#  21,
#  67,
#  67,
#  84,
#  31,
#  72,
#  85,
#  55,
#  52,
#  87,
#  31,
#  66,
#  43,
#  64,
#  76,
#  52,
#  0,
#  39,
#  86,
#  9,
#  14,
#  17,
#  25,
#  68,
#  76,
#  55,
#  2,
#  61,
#  55,
#  54,
#  35,
#  9,
#  45,
#  55,
#  9,
#  15,
#  9,
#  31,
#  72,
#  19,
#  25,
#  9,
#  14,
#  84,
#  63,
#  16,
#  57,
#  21,
#  50,
#  34,
#  0,
#  55,
#  56,
#  61,
#  72,
#  36,
#  2,
#  65,
#  15,
#  65,
#  78,
#  55,
#  14,
#  72,
#  16,
#  84,
#  32,
#  72,
#  85,
#  5,
#  33,
#  45,
#  55,
#  20,
#  72,
#  67,
#  8,
#  84,
#  9,
#  21,
#  39,
#  52,
#  51,
#  52,
#  21,
#  60,
#  77,
#  40,
#  40,
#  33,
#  25,
#  15,
#  16,
#  72,
#  63,
#  57,
#  48,
#  40,
#  44,
#  72,
#  84,
#  40,
#  12,
#  37,
#  55,
#  54,
#  55,
#  12,
#  21,
#  71,
#  40,
#  55,
#  52,
#  14,
#  85,
#  38,
#  13,
#  58,
#  46,
#  62,
#  52,
#  80,
#  18,
#  39,
#  60,
#  44,
#  60,
#  65,
#  70,
#  33,
#  55,
#  66,
#  84,
#  44,
#  39,
#  4,
#  68,
#  9,
#  68,
#  63,
#  5,
#  18,
#  42,
#  16,
#  52,
#  65,
#  37,
#  19,
#  40,
#  24,
#  38,
#  58,
#  56,
#  2,
#  40,
#  39,
#  14,
#  87,
#  34,
#  17,
#  46,
#  63,
#  30,
#  56,
#  24,
#  15,
#  72,
#  15,
#  77,
#  84,
#  58,
#  50,
#  33,
#  33,
#  11,
#  58,
#  35,
#  9,
#  33,
#  21,
#  19,
#  0,
#  9,
#  33,
#  61,
#  53,
#  40,
#  57,
#  55,
#  40,
#  21,
#  59,
#  72,
#  54,
#  18,
#  28,
#  45,
#  55,
#  55,
#  47,
#  58,
#  15,
#  11,
#  9,
#  3,
#  82,
#  3,
#  38,
#  55,
#  ...]

# %%
train_y = pd.read_csv("./open/train_df_add_data.csv")

train_labels = train_y["label"]

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}

# %%
label_decoder = {val:key for key, val in label_unique.items()}

f_result = [label_decoder[result] for result in f_pred]

# %%
f_result
# Out:
# ['tile-glue_strip',
#  'grid-good',
#  'transistor-good',
#  'tile-gray_stroke',
#  'tile-good',
#  'pill-crack',
#  'capsule-faulty_imprint',
#  'hazelnut-cut',
#  'leather-good',
#  'leather-glue',
#  'bottle-broken_large',
#  'wood-good',
#  'zipper-rough',
#  'screw-thread_side',
#  'tile-glue_strip',
#  'bottle-contamination',
#  'grid-bent',
#  'carpet-cut',
#  'carpet-good',
#  'pill-color',
#  'tile-rough',
#  'zipper-good',
#  'bottle-broken_large',
#  'screw-scratch_neck',
#  'pill-scratch',
#  'screw-good',
#  'pill-faulty_imprint',
#  'screw-thread_top',
#  'leather-good',
#  'wood-liquid',
#  'screw-good',
#  'cable-good',
#  'screw-thread_side',
#  'zipper-fabric_interior',
#  'zipper-good',
#  'zipper-fabric_border',
#  'leather-good',
#  'cable-good',
#  'leather-cut',
#  'metal_nut-flip',
#  'metal_nut-good',
#  'cable-missing_cable',
#  'screw-thread_top',
#  'capsule-faulty_imprint',
#  'metal_nut-flip',
#  'tile-good',
#  'toothbrush-good',
#  'capsule-crack',
#  'zipper-good',
#  'screw-good',
#  'cable-good',
#  'transistor-good',
#  'hazelnut-crack',
#  'hazelnut-print',
#  'zipper-good',
#  'metal_nut-scratch',
#  'carpet-cut',
#  'carpet-good',
#  'leather-fold',
#  'capsule-good',
#  'transistor-good',
#  'pill-combined',
#  'capsule-squeeze',
#  'zipper-broken_teeth',
#  'capsule-crack',
#  'leather-color',
#  'transistor-good',
#  'capsule-crack',
#  'pill-pill_type',
#  'metal_nut-color',
#  'grid-bent',
#  'wood-hole',
#  'hazelnut-cut',
#  'tile-crack',
#  'leather-poke',
#  'zipper-good',
#  'cable-good',
#  'leather-good',
#  'cable-good',
#  'cable-good',
#  'pill-crack',
#  'wood-scratch',
#  'screw-scratch_head',
#  'wood-combined',
#  'transistor-good',
#  'bottle-broken_large',
#  'zipper-good',
#  'carpet-good',
#  'leather-good',
#  'zipper-fabric_interior',
#  'leather-color',
#  'zipper-good',
#  'cable-good',
#  'metal_nut-bent',
#  'screw-good',
#  'tile-oil',
#  'transistor-good',
#  'transistor-good',
#  'metal_nut-good',
#  'metal_nut-good',
#  'cable-good',
#  'carpet-good',
#  'pill-good',
#  'capsule-scratch',
#  'wood-good',
#  'bottle-contamination',
#  'zipper-rough',
#  'pill-contamination',
#  'transistor-good',
#  'hazelnut-hole',
#  'leather-color',
#  'screw-scratch_neck',
#  'transistor-misplaced',
#  'transistor-good',
#  'zipper-good',
#  'capsule-good',
#  'grid-good',
#  'pill-good',
#  'capsule-crack',
#  'leather-poke',
#  'screw-good',
#  'carpet-color',
#  'metal_nut-good',
#  'transistor-good',
#  'wood-hole',
#  'transistor-cut_lead',
#  'tile-crack',
#  'transistor-good',
#  'pill-scratch',
#  'screw-good',
#  'grid-good',
#  'metal_nut-scratch',
#  'pill-crack',
#  'metal_nut-bent',
#  'capsule-good',
#  'grid-bent',
#  'screw-scratch_head',
#  'bottle-contamination',
#  'pill-good',
#  'wood-liquid',
#  'transistor-misplaced',
#  'hazelnut-good',
#  'cable-cut_inner_insulation',
#  'cable-good',
#  'zipper-good',
#  'hazelnut-print',
#  'carpet-metal_contamination',
#  'zipper-good',
#  'zipper-rough',
#  'wood-good',
#  'zipper-good',
#  'wood-scratch',
#  'transistor-good',
#  'pill-good',
#  'zipper-fabric_interior',
#  'tile-good',
#  'toothbrush-defective',
#  'tile-good',
#  'hazelnut-good',
#  'metal_nut-good',
#  'screw-scratch_head',
#  'screw-thread_top',
#  'screw-scratch_head',
#  'cable-missing_wire',
#  'carpet-good',
#  'leather-fold',
#  'pill-contamination',
#  'wood-scratch',
#  'zipper-fabric_interior',
#  'cable-missing_cable',
#  'carpet-good',
#  'carpet-thread',
#  'screw-manipulated_front',
#  'leather-glue',
#  'cable-good',
#  'pill-good',
#  'screw-good',
#  'zipper-split_teeth',
#  'capsule-good',
#  'zipper-good',
#  'leather-good',
#  'grid-glue',
#  'bottle-good',
#  'cable-missing_wire',
#  'pill-faulty_imprint',
#  'carpet-cut',
#  'tile-glue_strip',
#  'metal_nut-good',
#  'wood-scratch',
#  'transistor-cut_lead',
#  'pill-scratch',
#  'capsule-squeeze',
#  'zipper-good',
#  'hazelnut-cut',
#  'pill-good',
#  'screw-scratch_head',
#  'zipper-fabric_interior',
#  'zipper-rough',
#  'zipper-good',
#  'hazelnut-good',
#  'transistor-good',
#  'cable-poke_insulation',
#  'screw-thread_side',
#  'bottle-broken_small',
#  'pill-good',
#  'leather-good',
#  'pill-good',
#  'pill-good',
#  'hazelnut-good',
#  'grid-bent',
#  'leather-poke',
#  'capsule-good',
#  'screw-good',
#  'wood-scratch',
#  'pill-combined',
#  'carpet-cut',
#  'capsule-squeeze',
#  'pill-contamination',
#  'transistor-good',
#  'bottle-broken_small',
#  'tile-oil',
#  'grid-good',
#  'tile-good',
#  'bottle-broken_small',
#  'capsule-crack',
#  'metal_nut-color',
#  'pill-faulty_imprint',
#  'leather-color',
#  'cable-good',
#  'transistor-good',
#  'pill-good',
#  'screw-good',
#  'zipper-fabric_interior',
#  'pill-contamination',
#  'zipper-broken_teeth',
#  'capsule-scratch',
#  'transistor-good',
#  'metal_nut-good',
#  'hazelnut-crack',
#  'capsule-faulty_imprint',
#  'metal_nut-good',
#  'hazelnut-hole',
#  'zipper-rough',
#  'screw-thread_side',
#  'wood-color',
#  'leather-poke',
#  'tile-good',
#  'tile-gray_stroke',
#  'wood-scratch',
#  'cable-good',
#  'transistor-good',
#  'tile-gray_stroke',
#  'cable-bent_wire',
#  'capsule-good',
#  'metal_nut-flip',
#  'metal_nut-good',
#  'metal_nut-good',
#  'capsule-crack',
#  'zipper-squeezed_teeth',
#  'hazelnut-good',
#  'hazelnut-crack',
#  'screw-good',
#  'hazelnut-good',
#  'hazelnut-cut',
#  'leather-poke',
#  'leather-good',
#  'wood-good',
#  'screw-good',
#  'metal_nut-flip',
#  'cable-good',
#  'carpet-good',
#  'screw-good',
#  'wood-hole',
#  'transistor-misplaced',
#  'cable-good',
#  'capsule-good',
#  'pill-color',
#  'capsule-good',
#  'transistor-good',
#  'zipper-squeezed_teeth',
#  'pill-combined',
#  'leather-color',
#  'transistor-good',
#  'pill-pill_type',
#  'pill-good',
#  'screw-good',
#  'grid-thread',
#  'tile-good',
#  'tile-good',
#  'bottle-broken_large',
#  'carpet-hole',
#  'bottle-broken_small',
#  'leather-fold',
#  'leather-cut',
#  'cable-good',
#  'zipper-squeezed_teeth',
#  'tile-good',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'screw-scratch_neck',
#  'leather-poke',
#  'zipper-broken_teeth',
#  'transistor-good',
#  'screw-scratch_head',
#  'pill-faulty_imprint',
#  'toothbrush-good',
#  'grid-good',
#  'leather-color',
#  'screw-manipulated_front',
#  'screw-good',
#  'transistor-good',
#  'bottle-good',
#  'metal_nut-scratch',
#  'wood-good',
#  'transistor-good',
#  'screw-thread_side',
#  'wood-good',
#  'wood-good',
#  'tile-good',
#  'cable-good',
#  'screw-scratch_neck',
#  'metal_nut-scratch',
#  'cable-cut_inner_insulation',
#  'leather-good',
#  'capsule-good',
#  'screw-good',
#  'screw-manipulated_front',
#  'pill-crack',
#  'transistor-good',
#  'screw-scratch_neck',
#  'capsule-good',
#  'screw-good',
#  'carpet-good',
#  'carpet-color',
#  'bottle-good',
#  'tile-good',
#  'metal_nut-color',
#  'screw-scratch_neck',
#  'cable-bent_wire',
#  'wood-good',
#  'screw-good',
#  'metal_nut-bent',
#  'tile-good',
#  'screw-good',
#  'leather-glue',
#  'metal_nut-flip',
#  'metal_nut-bent',
#  'hazelnut-good',
#  'pill-pill_type',
#  'carpet-thread',
#  'cable-cable_swap',
#  'cable-good',
#  'capsule-scratch',
#  'carpet-good',
#  'capsule-poke',
#  'cable-good',
#  'pill-good',
#  'bottle-good',
#  'toothbrush-defective',
#  'transistor-cut_lead',
#  'capsule-crack',
#  'leather-fold',
#  'carpet-color',
#  'transistor-good',
#  'zipper-rough',
#  'grid-broken',
#  'cable-cut_inner_insulation',
#  'cable-good',
#  'leather-cut',
#  'hazelnut-good',
#  'screw-good',
#  'cable-good',
#  'bottle-good',
#  'hazelnut-good',
#  'transistor-good',
#  'wood-hole',
#  'screw-manipulated_front',
#  'capsule-faulty_imprint',
#  'grid-good',
#  'metal_nut-scratch',
#  'screw-good',
#  'wood-color',
#  'tile-glue_strip',
#  'capsule-good',
#  'grid-good',
#  'metal_nut-bent',
#  'capsule-faulty_imprint',
#  'hazelnut-cut',
#  'screw-good',
#  'leather-good',
#  'metal_nut-color',
#  'bottle-broken_small',
#  'leather-cut',
#  'capsule-poke',
#  'transistor-good',
#  'cable-good',
#  'bottle-contamination',
#  'hazelnut-print',
#  'tile-good',
#  'wood-liquid',
#  'tile-gray_stroke',
#  'transistor-good',
#  'zipper-combined',
#  'bottle-contamination',
#  'tile-good',
#  'pill-crack',
#  'capsule-scratch',
#  'leather-good',
#  'pill-faulty_imprint',
#  'cable-good',
#  'capsule-poke',
#  'pill-good',
#  'cable-good',
#  'bottle-broken_large',
#  'transistor-good',
#  'leather-good',
#  'transistor-good',
#  'hazelnut-cut',
#  'transistor-bent_lead',
#  'metal_nut-scratch',
#  'zipper-good',
#  'metal_nut-bent',
#  'carpet-good',
#  'carpet-color',
#  'pill-crack',
#  'zipper-fabric_interior',
#  'zipper-good',
#  'leather-glue',
#  'transistor-damaged_case',
#  'bottle-broken_small',
#  'zipper-good',
#  'cable-good',
#  'bottle-broken_small',
#  'tile-good',
#  'hazelnut-crack',
#  'wood-scratch',
#  'pill-faulty_imprint',
#  'carpet-good',
#  'grid-metal_contamination',
#  'pill-color',
#  'tile-oil',
#  'transistor-good',
#  'screw-manipulated_front',
#  'transistor-good',
#  'transistor-cut_lead',
#  'carpet-thread',
#  'zipper-broken_teeth',
#  'tile-glue_strip',
#  'leather-fold',
#  'wood-hole',
#  'zipper-good',
#  'bottle-broken_small',
#  'carpet-good',
#  'tile-good',
#  'hazelnut-good',
#  'screw-thread_side',
#  'hazelnut-good',
#  'carpet-hole',
#  'metal_nut-flip',
#  'cable-good',
#  'carpet-good',
#  'screw-thread_top',
#  'leather-poke',
#  'carpet-thread',
#  'capsule-faulty_imprint',
#  'capsule-crack',
#  'metal_nut-flip',
#  'screw-thread_side',
#  'metal_nut-good',
#  'pill-pill_type',
#  'metal_nut-bent',
#  'tile-good',
#  'bottle-good',
#  'screw-manipulated_front',
#  'cable-good',
#  'wood-good',
#  'transistor-good',
#  'screw-thread_top',
#  'screw-thread_top',
#  'pill-crack',
#  'screw-thread_side',
#  'carpet-hole',
#  'cable-good',
#  'screw-good',
#  'screw-good',
#  'cable-good',
#  'grid-good',
#  'hazelnut-hole',
#  'pill-faulty_imprint',
#  'carpet-cut',
#  'cable-poke_insulation',
#  'cable-cut_inner_insulation',
#  'screw-good',
#  'hazelnut-good',
#  'capsule-squeeze',
#  'transistor-cut_lead',
#  'toothbrush-defective',
#  'cable-cut_inner_insulation',
#  'zipper-split_teeth',
#  'screw-manipulated_front',
#  'tile-oil',
#  'metal_nut-scratch',
#  'transistor-good',
#  'cable-bent_wire',
#  'tile-good',
#  'leather-fold',
#  'wood-liquid',
#  'toothbrush-good',
#  'leather-poke',
#  'capsule-poke',
#  'screw-manipulated_front',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'zipper-good',
#  'cable-good',
#  'metal_nut-scratch',
#  'leather-good',
#  'cable-good',
#  'tile-gray_stroke',
#  'pill-pill_type',
#  'wood-good',
#  'metal_nut-good',
#  'pill-good',
#  'zipper-combined',
#  'cable-missing_wire',
#  'wood-good',
#  'capsule-crack',
#  'carpet-cut',
#  'capsule-good',
#  'hazelnut-hole',
#  'hazelnut-good',
#  'hazelnut-hole',
#  'grid-good',
#  'screw-good',
#  'zipper-split_teeth',
#  'wood-scratch',
#  'pill-contamination',
#  'toothbrush-defective',
#  'cable-good',
#  'wood-good',
#  'grid-metal_contamination',
#  'screw-good',
#  'grid-good',
#  'zipper-broken_teeth',
#  'transistor-good',
#  'tile-good',
#  'hazelnut-good',
#  'pill-scratch',
#  'cable-good',
#  'capsule-crack',
#  'pill-color',
#  'pill-good',
#  'zipper-combined',
#  'tile-glue_strip',
#  'screw-good',
#  'capsule-good',
#  'zipper-broken_teeth',
#  'screw-manipulated_front',
#  'leather-glue',
#  'capsule-faulty_imprint',
#  'leather-good',
#  'carpet-metal_contamination',
#  'cable-good',
#  'hazelnut-good',
#  'grid-good',
#  'grid-good',
#  'hazelnut-good',
#  'screw-thread_side',
#  'hazelnut-good',
#  'wood-scratch',
#  'hazelnut-good',
#  'pill-good',
#  'cable-missing_wire',
#  'wood-hole',
#  'zipper-split_teeth',
#  'carpet-good',
#  'grid-glue',
#  'zipper-fabric_border',
#  'pill-contamination',
#  'metal_nut-bent',
#  'tile-good',
#  'carpet-hole',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'carpet-good',
#  'leather-good',
#  'transistor-good',
#  'screw-good',
#  'hazelnut-cut',
#  'cable-good',
#  'zipper-squeezed_teeth',
#  'zipper-good',
#  'metal_nut-bent',
#  'carpet-metal_contamination',
#  'tile-good',
#  'zipper-broken_teeth',
#  'hazelnut-good',
#  'leather-good',
#  'hazelnut-good',
#  'hazelnut-hole',
#  'cable-cut_inner_insulation',
#  'pill-crack',
#  'cable-good',
#  'pill-good',
#  'cable-good',
#  'transistor-cut_lead',
#  'pill-faulty_imprint',
#  'metal_nut-bent',
#  'grid-glue',
#  'cable-good',
#  'carpet-color',
#  'hazelnut-good',
#  'capsule-poke',
#  'pill-good',
#  'zipper-split_teeth',
#  'carpet-thread',
#  'cable-bent_wire',
#  'cable-good',
#  'cable-cut_outer_insulation',
#  'zipper-squeezed_teeth',
#  'tile-glue_strip',
#  'bottle-broken_large',
#  'carpet-hole',
#  'metal_nut-bent',
#  'toothbrush-good',
#  'hazelnut-good',
#  'bottle-broken_small',
#  'leather-good',
#  'toothbrush-defective',
#  'screw-good',
#  'screw-scratch_neck',
#  'zipper-broken_teeth',
#  'leather-good',
#  'cable-missing_wire',
#  'capsule-good',
#  'carpet-metal_contamination',
#  'leather-poke',
#  'pill-good',
#  'leather-fold',
#  'transistor-good',
#  'bottle-broken_large',
#  'carpet-good',
#  'zipper-fabric_interior',
#  'cable-good',
#  'leather-cut',
#  'capsule-good',
#  'zipper-split_teeth',
#  'wood-hole',
#  'hazelnut-print',
#  'carpet-good',
#  'screw-good',
#  'grid-metal_contamination',
#  'wood-scratch',
#  'screw-scratch_neck',
#  'capsule-crack',
#  'capsule-squeeze',
#  'leather-good',
#  'transistor-good',
#  'cable-cut_outer_insulation',
#  'carpet-good',
#  'transistor-good',
#  'capsule-good',
#  'grid-good',
#  'transistor-cut_lead',
#  'hazelnut-good',
#  'tile-rough',
#  'cable-good',
#  'hazelnut-good',
#  'pill-crack',
#  'bottle-good',
#  'pill-scratch',
#  'pill-faulty_imprint',
#  'bottle-broken_large',
#  'wood-good',
#  'pill-scratch',
#  'cable-good',
#  'tile-good',
#  'leather-good',
#  'leather-fold',
#  'tile-oil',
#  'pill-good',
#  'cable-cut_outer_insulation',
#  'tile-good',
#  'tile-good',
#  'hazelnut-good',
#  'grid-good',
#  'leather-good',
#  'metal_nut-color',
#  'cable-missing_cable',
#  'screw-manipulated_front',
#  'pill-color',
#  'grid-good',
#  'cable-cable_swap',
#  'hazelnut-good',
#  'zipper-rough',
#  'tile-good',
#  'bottle-contamination',
#  'cable-missing_cable',
#  'leather-poke',
#  'hazelnut-cut',
#  'screw-scratch_neck',
#  'bottle-broken_small',
#  'carpet-color',
#  'screw-good',
#  'transistor-damaged_case',
#  'cable-cut_outer_insulation',
#  'wood-good',
#  'pill-crack',
#  'pill-good',
#  'screw-scratch_neck',
#  'grid-thread',
#  'carpet-metal_contamination',
#  'wood-scratch',
#  'carpet-color',
#  'leather-poke',
#  'hazelnut-good',
#  'zipper-good',
#  'capsule-good',
#  'transistor-good',
#  'screw-manipulated_front',
#  'transistor-good',
#  'zipper-fabric_border',
#  'transistor-good',
#  'pill-crack',
#  'hazelnut-good',
#  'pill-good',
#  'cable-bent_wire',
#  'hazelnut-good',
#  'bottle-good',
#  'pill-scratch',
#  'pill-good',
#  'hazelnut-good',
#  'metal_nut-bent',
#  'carpet-good',
#  'pill-good',
#  'capsule-faulty_imprint',
#  'wood-scratch',
#  'hazelnut-good',
#  'carpet-thread',
#  'pill-combined',
#  'pill-good',
#  'tile-good',
#  'carpet-good',
#  'bottle-good',
#  'pill-crack',
#  'pill-combined',
#  'capsule-crack',
#  'metal_nut-good',
#  'cable-good',
#  'metal_nut-flip',
#  'transistor-good',
#  'capsule-scratch',
#  'tile-oil',
#  'zipper-good',
#  'bottle-good',
#  'pill-good',
#  'capsule-crack',
#  'screw-good',
#  'hazelnut-hole',
#  'cable-missing_cable',
#  'pill-scratch',
#  'bottle-good',
#  'capsule-good',
#  'grid-bent',
#  'zipper-fabric_border',
#  'metal_nut-good',
#  'pill-color',
#  'wood-color',
#  'carpet-metal_contamination',
#  'wood-combined',
#  'zipper-fabric_interior',
#  'hazelnut-hole',
#  'screw-thread_side',
#  'pill-combined',
#  'screw-good',
#  'bottle-broken_large',
#  'capsule-crack',
#  'transistor-good',
#  'leather-color',
#  'screw-good',
#  'wood-combined',
#  'cable-good',
#  'leather-good',
#  'toothbrush-defective',
#  'toothbrush-good',
#  'screw-scratch_head',
#  'cable-cut_outer_insulation',
#  'zipper-rough',
#  'carpet-good',
#  'toothbrush-defective',
#  'toothbrush-defective',
#  'zipper-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'zipper-rough',
#  'screw-good',
#  'pill-good',
#  'zipper-squeezed_teeth',
#  'hazelnut-crack',
#  'tile-rough',
#  'metal_nut-color',
#  'tile-gray_stroke',
#  'wood-good',
#  'pill-good',
#  'bottle-broken_large',
#  'leather-glue',
#  'zipper-split_teeth',
#  'cable-good',
#  'capsule-faulty_imprint',
#  'capsule-scratch',
#  'grid-bent',
#  'toothbrush-good',
#  'wood-good',
#  'screw-good',
#  'bottle-contamination',
#  'tile-crack',
#  'screw-good',
#  'pill-scratch',
#  'hazelnut-print',
#  'cable-good',
#  'metal_nut-good',
#  'screw-good',
#  'cable-good',
#  'capsule-good',
#  'cable-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'carpet-color',
#  'grid-bent',
#  'cable-good',
#  'capsule-faulty_imprint',
#  'zipper-good',
#  'tile-good',
#  'capsule-poke',
#  'screw-scratch_head',
#  'carpet-good',
#  'pill-crack',
#  'hazelnut-hole',
#  'bottle-broken_large',
#  'screw-good',
#  'screw-manipulated_front',
#  'tile-crack',
#  'transistor-good',
#  'leather-color',
#  'bottle-contamination',
#  'tile-oil',
#  'capsule-good',
#  'tile-oil',
#  'wood-liquid',
#  'screw-good',
#  'capsule-faulty_imprint',
#  'transistor-good',
#  'capsule-poke',
#  'zipper-good',
#  'hazelnut-cut',
#  'transistor-good',
#  'zipper-rough',
#  'cable-cable_swap',
#  'hazelnut-good',
#  'metal_nut-good',
#  'screw-good',
#  'carpet-cut',
#  'transistor-good',
#  'toothbrush-defective',
#  'cable-cut_outer_insulation',
#  'zipper-good',
#  'cable-good',
#  'carpet-good',
#  'leather-glue',
#  'pill-good',
#  'pill-faulty_imprint',
#  'pill-good',
#  'carpet-good',
#  'screw-thread_top',
#  'wood-hole',
#  'leather-good',
#  'leather-good',
#  'hazelnut-good',
#  'grid-bent',
#  'capsule-good',
#  'capsule-poke',
#  'transistor-good',
#  'tile-good',
#  'screw-scratch_head',
#  'pill-combined',
#  'leather-good',
#  'metal_nut-flip',
#  'transistor-good',
#  'zipper-good',
#  'leather-good',
#  'cable-poke_insulation',
#  'leather-cut',
#  'screw-good',
#  'pill-scratch',
#  'screw-good',
#  'cable-poke_insulation',
#  'carpet-good',
#  'transistor-damaged_case',
#  'leather-good',
#  'screw-good',
#  'pill-good',
#  'capsule-faulty_imprint',
#  'zipper-rough',
#  'leather-fold',
#  'capsule-crack',
#  'screw-scratch_neck',
#  'metal_nut-scratch',
#  'tile-glue_strip',
#  'pill-good',
#  'zipper-broken_teeth',
#  'capsule-squeeze',
#  'leather-glue',
#  'screw-thread_top',
#  'metal_nut-flip',
#  'screw-thread_top',
#  'tile-oil',
#  'transistor-cut_lead',
#  'hazelnut-good',
#  'screw-good',
#  'tile-rough',
#  'zipper-good',
#  'metal_nut-flip',
#  'leather-glue',
#  'cable-bent_wire',
#  'toothbrush-good',
#  'cable-good',
#  'toothbrush-good',
#  'tile-good',
#  'cable-cable_swap',
#  'capsule-squeeze',
#  'metal_nut-bent',
#  'capsule-poke',
#  'pill-good',
#  'tile-oil',
#  'leather-cut',
#  'carpet-color',
#  'leather-good',
#  'carpet-thread',
#  'leather-fold',
#  'screw-scratch_neck',
#  'screw-manipulated_front',
#  'bottle-contamination',
#  'leather-good',
#  'leather-glue',
#  'capsule-faulty_imprint',
#  'zipper-squeezed_teeth',
#  'hazelnut-hole',
#  'capsule-scratch',
#  'metal_nut-scratch',
#  'tile-good',
#  'grid-thread',
#  'screw-manipulated_front',
#  'carpet-thread',
#  'capsule-good',
#  'transistor-good',
#  'capsule-good',
#  'wood-hole',
#  'zipper-good',
#  'screw-scratch_neck',
#  'pill-crack',
#  'hazelnut-good',
#  'hazelnut-good',
#  'cable-missing_wire',
#  'screw-scratch_neck',
#  'hazelnut-print',
#  'cable-good',
#  'hazelnut-good',
#  'carpet-good',
#  'carpet-color',
#  'bottle-broken_large',
#  'cable-good',
#  'hazelnut-good',
#  'tile-crack',
#  'pill-pill_type',
#  'leather-good',
#  'screw-scratch_head',
#  'screw-good',
#  'leather-good',
#  'carpet-good',
#  'screw-thread_side',
#  'transistor-good',
#  'pill-scratch',
#  'capsule-squeeze',
#  'grid-good',
#  'metal_nut-good',
#  'screw-good',
#  'screw-good',
#  'pill-color',
#  'screw-scratch_neck',
#  'capsule-good',
#  'cable-missing_wire',
#  'cable-good',
#  'bottle-good',
#  'zipper-fabric_border',
#  'bottle-good',
#  'leather-fold',
#  'screw-good',
#  ...]

# %%
submission = pd.read_csv("./open/sample_submission.csv")

submission["label"] = f_result

submission
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1         grid-good
# 2         2   transistor-good
# 3         3  tile-gray_stroke
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]

# %%
submission.to_csv("./submission/label_result_add_0505_label_swin_large_patch4_window12_384_in22k.csv", index = False)
