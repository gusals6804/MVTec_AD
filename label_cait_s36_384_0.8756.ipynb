# %%
import os
import cv2
import time
import random
import logging
import easydict
import numpy as np
import pandas as pd
from tqdm import tqdm
from os.path import join as opj
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from PIL import Image
from natsort import natsorted

import timm
import torch
import torch.nn as nn
import torch_optimizer as optim
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, grad_scaler
from torchvision import transforms
from torch import Tensor
from torchvision.transforms import functional as F
import torch.cuda.amp as amp
from adamp import AdamP, SGDP

import warnings
warnings.filterwarnings('ignore')

# %%
args = easydict.EasyDict(
    {'exp_num':'0',
     
     # Path settings
     'data_path':'./open',
     'Kfold':5,
     'model_path':'label_results_cait_s36_384/',
     'image_type':'train_1024', 
     'class_num' : 88,

     # Model parameter settings
     'model_name':'cait_s36_384',
     'drop_path_rate':0.2,
     
     # Training parameter settings
     ## Base Parameter
     'img_size':384,
     'batch_size':16,
     'epochs':100,
     'optimizer':'Lamb',
     'initial_lr':5e-4,
     'weight_decay':1e-3,

     ## Augmentation
     'aug_ver':2,

     ## Scheduler (OnecycleLR)
     'scheduler':'Reduce',
     'warm_epoch':5,
     'max_lr':1e-3,

     ### Cosine Annealing
     'min_lr':5e-5,
     'tmax':145,

     ## etc.
     'patience': 5,
     'clipping':None,

     # Hardware settings
     'amp':True,
     'multi_gpu':True,
     'logging':False,
     'num_workers':4,
     'seed':42
     
     
    })

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "0,1,2,3"  # Set the GPUs 2 and 3 to use

# %% [markdown]
# # 증강된 데이터 셋 불러오기

# %%
DATA_DIR = './open'

train_df = pd.read_csv(os.path.join(DATA_DIR, 'train_df_add_data.csv'))
test_df = pd.read_csv(os.path.join(DATA_DIR, 'test_df.csv'))

print(train_df.head())
print(test_df.head())
print(train_df.shape)
print(test_df.shape)
# Out:
#    Unnamed: 0  file_name       class state            label  encoder_label
# 0           0  10000.png  transistor  good  transistor-good             72
# 1           1  10001.png     capsule  good     capsule-good             15
# 2           2  10002.png  transistor  good  transistor-good             72
# 3           3  10003.png        wood  good        wood-good             76
# 4           4  10004.png      bottle  good      bottle-good              3
#    index  file_name
# 0      0  20000.png
# 1      1  20001.png
# 2      2  20002.png
# 3      3  20003.png
# 4      4  20004.png
# (13997, 6)
# (2154, 2)

# %%
train_df['label'].unique()
# Out:
# array(['transistor-good', 'capsule-good', 'wood-good', 'bottle-good',
#        'screw-good', 'cable-bent_wire', 'carpet-hole', 'hazelnut-good',
#        'pill-pill_type', 'cable-good', 'metal_nut-scratch', 'pill-good',
#        'screw-thread_side', 'zipper-fabric_border', 'leather-good',
#        'pill-scratch', 'toothbrush-good', 'hazelnut-crack',
#        'screw-manipulated_front', 'zipper-good', 'tile-good',
#        'carpet-good', 'metal_nut-good', 'bottle-contamination',
#        'grid-good', 'zipper-split_teeth', 'pill-crack', 'wood-combined',
#        'pill-color', 'screw-thread_top', 'cable-missing_cable',
#        'capsule-squeeze', 'zipper-rough', 'capsule-crack', 'capsule-poke',
#        'metal_nut-flip', 'carpet-metal_contamination', 'metal_nut-color',
#        'transistor-bent_lead', 'zipper-fabric_interior', 'leather-fold',
#        'tile-glue_strip', 'screw-scratch_neck', 'screw-scratch_head',
#        'hazelnut-cut', 'bottle-broken_large', 'bottle-broken_small',
#        'leather-cut', 'cable-cut_outer_insulation',
#        'zipper-squeezed_teeth', 'toothbrush-defective',
#        'cable-cut_inner_insulation', 'pill-contamination',
#        'cable-missing_wire', 'carpet-thread', 'grid-broken',
#        'pill-faulty_imprint', 'hazelnut-hole', 'leather-glue',
#        'leather-poke', 'transistor-damaged_case', 'wood-scratch',
#        'tile-gray_stroke', 'capsule-faulty_imprint', 'grid-glue',
#        'zipper-combined', 'carpet-color', 'grid-bent', 'pill-combined',
#        'hazelnut-print', 'cable-combined', 'capsule-scratch',
#        'metal_nut-bent', 'zipper-broken_teeth', 'tile-oil',
#        'transistor-misplaced', 'grid-thread', 'grid-metal_contamination',
#        'carpet-cut', 'wood-color', 'cable-cable_swap', 'tile-crack',
#        'leather-color', 'cable-poke_insulation', 'transistor-cut_lead',
#        'wood-hole', 'tile-rough', 'wood-liquid'], dtype=object)

# %%
class_num = len(train_df.encoder_label.unique())
class_num
# Out:
# 88

# %%
# Warmup Learning rate scheduler
from torch.optim.lr_scheduler import _LRScheduler
class WarmUpLR(_LRScheduler):
    """warmup_training learning rate scheduler
    Args:
        optimizer: optimzier(e.g. SGD)
        total_iters: totoal_iters of warmup phase
    """
    def __init__(self, optimizer, total_iters, last_epoch=-1):
        
        self.total_iters = total_iters
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        """we will use the first m batches, and set the learning
        rate to base_lr * m / total_iters
        """
        return [base_lr * self.last_epoch / (self.total_iters + 1e-8) for base_lr in self.base_lrs]

# Logging
def get_root_logger(logger_name='basicsr',
                    log_level=logging.INFO,
                    log_file=None):

    logger = logging.getLogger(logger_name)
    # if the logger has been initialized, just return it
    if logger.hasHandlers():
        return logger

    format_str = '%(asctime)s %(levelname)s: %(message)s'
    logging.basicConfig(format=format_str, level=log_level)

    if log_file is not None:
        file_handler = logging.FileHandler(log_file, 'w')
        file_handler.setFormatter(logging.Formatter(format_str))
        file_handler.setLevel(log_level)
        logger.addHandler(file_handler)

    return logger

class AvgMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
        self.losses = []

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        self.losses.append(val)

# %%
class RandomRotation(transforms.RandomRotation):
    def __init__(self, p: float, degrees: int):
        super(RandomRotation, self).__init__(degrees)
        self.p = p

    def forward(self, img):
        if torch.rand(1) < self.p:
            fill = self.fill
            if isinstance(img, Tensor):
                if isinstance(fill, (int, float)):
                    fill = [float(fill)] * F.get_image_num_channels(img)
                else:
                    fill = [float(f) for f in fill]
            angle = self.get_params(self.degrees)

            img = F.rotate(img, angle, self.resample, self.expand, self.center, fill)
        return img

# %%
class Train_Dataset(Dataset):
    def __init__(self, df, transform=None):
        self.img_path = df['file_name'].values
        self.target = df['encoder_label'].values 
        self.transform = transform

        print(f'Dataset size:{len(self.img_path)}')

    def __getitem__(self, idx):
        
        image = Image.open(opj('./open/train_add_data/', self.img_path[idx])).convert('RGB')
        image = self.transform(image)
        target = self.target[idx]

        return image, target

    def __len__(self):
        return len(self.img_path)

class Test_dataset(Dataset):
    def __init__(self, df, transform=None):
        self.img_path = df['file_name'].values
        self.transform = transform

        print(f'Test Dataset size:{len(self.img_path)}')

    def __getitem__(self, idx):

        image = Image.open(opj('./open/test/', self.img_path[idx])).convert('RGB')
        image = self.transform(image)

        return image

    def __len__(self):
        return len(self.img_path)

def get_loader(df, phase: str, batch_size, shuffle,
               num_workers, transform):
    if phase == 'test':
        dataset = Test_dataset(df, transform)
        data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory=True)
    else:
        dataset = Train_Dataset(df, transform)
        data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, 
                                 pin_memory=True,
                                 drop_last=False)
    return data_loader

def get_train_augmentation(img_size, ver):
    if ver==1: # for validset
        transform = transforms.Compose([
                transforms.Resize((img_size, img_size)),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])

    if ver == 2:

        transform = transforms.Compose([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
                transforms.RandomAffine((-20,20)),
                RandomRotation(0.5, degrees=5),
                transforms.Resize((img_size, img_size)),
                transforms.ToTensor(), 
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])
    
    
    return transform

# %%
class Network(nn.Module):
    def __init__(self, args):
        super().__init__()
        self.model_ft = timm.create_model(args.model_name, pretrained=True, num_classes=88)

    def forward(self, x):
        out = self.model_ft(x)
        return out

class Network_test(nn.Module):
    def __init__(self, encoder_name):
        super().__init__()
        self.model_ft = timm.create_model(args.model_name, pretrained=True, num_classes=88)

    def forward(self, x):
        out = self.model_ft(x)
        return out

# %%
# # weighted crossentropy loss를 위한 weight 계산 함수

class_num = train_df.groupby(["encoder_label"])["encoder_label"].count().tolist()
class_weight = torch.tensor(np.max(class_num) / class_num).to("cuda", dtype=torch.float)
print(f"class_weight: {class_weight}")
# Out:
# class_weight: tensor([2.4437, 2.2216, 2.2216, 1.8708, 3.4911, 4.0729, 4.0729, 3.4911, 4.8875,
#         1.7455, 4.0729, 4.8875, 4.8875, 2.0365, 2.2216, 1.7854, 2.2216, 2.0365,
#         2.4437, 2.4437, 2.7153, 1.3964, 2.7153, 2.7153, 2.4437, 4.0729, 4.0729,
#         4.0729, 1.4811, 4.0729, 4.0729, 2.7153, 2.7153, 1.0000, 2.7153, 2.7153,
#         2.4437, 2.4437, 2.7153, 2.4437, 1.5959, 2.7153, 1.8798, 2.2216, 2.0365,
#         1.7773, 2.0365, 1.8798, 2.7153, 2.2216, 1.8798, 2.4437, 1.4644, 4.8875,
#         2.0365, 1.2219, 2.0365, 2.0365, 1.8798, 2.0365, 2.0365, 2.7153, 2.7153,
#         1.7000, 3.0547, 2.7153, 3.0547, 1.6292, 6.5167, 4.8875, 4.8875, 4.8875,
#         1.8357, 4.8875, 6.1094, 4.0729, 1.5830, 4.8875, 4.8875, 2.2216, 2.4437,
#         3.0547, 2.7153, 3.0547, 1.6292, 2.7153, 2.7153, 3.0547],
#        device='cuda:0')

# %%
class FocalLoss(nn.Module):
    """
    https://dacon.io/competitions/official/235585/codeshare/1796
    """

    def __init__(self, gamma=2.0, eps=1e-7):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        # print(self.gamma)
        self.eps = eps
        self.ce = nn.CrossEntropyLoss(reduction="none")

    def forward(self, input, target):
        logp = self.ce(input, target)
        p = torch.exp(-logp)
        loss = (1 - p) ** self.gamma * logp
        return loss.mean()

# %%
class Trainer():
    def __init__(self, args, save_path):
        '''
        args: arguments
        save_path: Model 가중치 저장 경로
        '''
        super(Trainer, self).__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Logging
        log_file = os.path.join(save_path, 'log.log')
        self.logger = get_root_logger(logger_name='IR', log_level=logging.INFO, log_file=log_file)
        self.logger.info(args)
        # self.logger.info(args.tag)

        # Train, Valid Set load
        ############################################################################
        if args.step == 0 :
            df_train = pd.read_csv(opj(args.data_path, 'train_df_add_data.csv'))
        else :
            df_train = pd.read_csv(opj(args.data_path, f'train_{args.step}step.csv'))

#         if args.image_type is not None:
#             df_train['img_path'] = df_train['img_path'].apply(lambda x:x.replace('train_imgs', args.image_type))
#             df_train['img_path'] = df_train['img_path'].apply(lambda x:x.replace('test_imgs', 'test_1024'))

        kf = StratifiedKFold(n_splits=args.Kfold, shuffle=True, random_state=args.seed)
        for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(df_train)), y=df_train['encoder_label'])):
            df_train.loc[val_idx, 'fold'] = fold
        val_idx = list(df_train[df_train['fold'] == int(args.fold)].index)

        df_val = df_train[df_train['fold'] == args.fold].reset_index(drop=True)
        df_train = df_train[df_train['fold'] != args.fold].reset_index(drop=True)

        # Augmentation
        self.train_transform = get_train_augmentation(img_size=args.img_size, ver=args.aug_ver)
        self.test_transform = get_train_augmentation(img_size=args.img_size, ver=1)

        # TrainLoader
        self.train_loader = get_loader(df_train, phase='train', batch_size=args.batch_size, shuffle=True,
                                       num_workers=args.num_workers, transform=self.train_transform)
        self.val_loader = get_loader(df_val, phase='train', batch_size=args.batch_size, shuffle=False,
                                       num_workers=args.num_workers, transform=self.test_transform)

        # Network
        self.model = Network(args).to(self.device)

        # Loss
#         self.criterion = nn.CrossEntropyLoss(weight=class_weight)
        self.criterion = FocalLoss()
#         self.criterion = CutMixCrossEntropyLoss(True)
        
        # Optimizer & Scheduler
#         self.optimizer = Lookahead(torch.optim.Adam(self.model.parameters(), lr=args.initial_lr), k=5, alpha=0.5)
        self.optimizer = optim.Lamb(self.model.parameters(), lr=args.initial_lr)
        
        iter_per_epoch = len(self.train_loader)
        self.warmup_scheduler = WarmUpLR(self.optimizer, iter_per_epoch * args.warm_epoch)

        if args.scheduler == 'step':
            self.scheduler = torch.optim.lr_scheduler.MultiStepLR(self.optimizer, milestones=args.milestone, gamma=args.lr_factor, verbose=True)
        elif args.scheduler == 'cos':
            tmax = args.tmax # half-cycle 
            self.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max = tmax, eta_min=args.min_lr, verbose=True)
        elif args.scheduler == 'cycle':
            self.scheduler = torch.optim.lr_scheduler.OneCycleLR(self.optimizer, max_lr=args.max_lr, steps_per_epoch=iter_per_epoch, epochs=args.epochs)
        else:
            self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, patience=5, factor=0.5, mode="max", verbose=True)
            
        if args.multi_gpu:
            self.model = nn.DataParallel(self.model).to(self.device)

        # Train / Validate
        best_loss = np.inf
        best_acc = 0
        best_epoch = 0
        early_stopping = 0
        start = time.time()
        for epoch in range(1, args.epochs+1):
            self.epoch = epoch

            if args.scheduler == 'cos':
                if epoch > args.warm_epoch:
                    self.scheduler.step()

            # Training
            train_loss, train_acc, train_f1 = self.training(args)

            # Model weight in Multi_GPU or Single GPU
            state_dict= self.model.module.state_dict() if args.multi_gpu else self.model.state_dict()

            # Validation
            val_loss, val_acc, val_f1 = self.validate(args, phase='val')

            # Save models
            if val_loss < best_loss:
                early_stopping = 0
                best_epoch = epoch
                best_loss = val_loss
                best_acc = val_acc
                best_f1 = val_f1

                torch.save({'epoch':epoch,
                            'state_dict':state_dict,
                            'optimizer': self.optimizer.state_dict(),
                            'scheduler': self.scheduler.state_dict(),
                    }, os.path.join(save_path, 'best_model.pth'))
                self.logger.info(f'-----------------SAVE:{best_epoch}epoch----------------')
            else:
                early_stopping += 1

            # Early Stopping
            if early_stopping == args.patience:
                break

        self.logger.info(f'\nBest Val Epoch:{best_epoch} | Val Loss:{best_loss:.4f} | Val Acc:{best_acc:.4f} | Val F1:{best_f1:.4f}')
        end = time.time()
        self.logger.info(f'Total Process time:{(end - start) / 60:.3f}Minute')

    # Training
    def training(self, args):
        self.model.train()
        train_loss = AvgMeter()
        train_acc = 0
        preds_list = []
        targets_list = []

        scaler = grad_scaler.GradScaler()
        
        for i, (images, targets) in enumerate(tqdm(self.train_loader)):
            images = torch.tensor(images, device=self.device, dtype=torch.float32)
            targets = torch.tensor(targets, device=self.device, dtype=torch.long)
            
            if self.epoch <= args.warm_epoch:
                self.warmup_scheduler.step()

            self.model.zero_grad(set_to_none=True)
    
            if args.amp:
                with autocast():
                    preds = self.model(images)
                    loss = self.criterion(preds, targets)
                    
                scaler.scale(loss).backward()

                # Gradient Clipping
                if args.clipping is not None:
                    scaler.unscale_(self.optimizer)
                    torch.nn.utils.clip_grad_norm_(self.model.parameters(), args.clipping)

                scaler.step(self.optimizer)
                scaler.update()

            else:
                preds = self.model(images)
                loss = self.criterion(preds, targets)
                loss.backward()
                nn.utils.clip_grad_norm_(self.model.parameters(), args.clipping)
                self.optimizer.step()

            if args.scheduler == 'cycle':
                if self.epoch > args.warm_epoch:
                    self.scheduler.step()

            # Metric
            train_acc += (preds.argmax(dim=1) == targets).sum().item()
            preds_list.extend(preds.argmax(dim=1).cpu().detach().numpy())
            targets_list.extend(targets.cpu().detach().numpy())
            # log
            train_loss.update(loss.item(), n=images.size(0))

        train_acc /= len(self.train_loader.dataset)
        train_f1 = f1_score(np.array(targets_list), np.array(preds_list), average='macro')

        self.logger.info(f'Epoch:[{self.epoch:03d}/{args.epochs:03d}]')
        self.logger.info(f'Train Loss:{train_loss.avg:.3f} | Acc:{train_acc:.4f} | F1:{train_f1:.4f}')
        return train_loss.avg, train_acc, train_f1
            
    # Validation or Dev
    def validate(self, args, phase='val'):
        self.model.eval()
        with torch.no_grad():
            val_loss = AvgMeter()
            val_acc = 0
            preds_list = []
            targets_list = []

            for i, (images, targets) in enumerate(self.val_loader):
                images = torch.tensor(images, device=self.device, dtype=torch.float32)
                targets = torch.tensor(targets, device=self.device, dtype=torch.long)

                preds = self.model(images)
                loss = self.criterion(preds, targets)

                # Metric
                val_acc += (preds.argmax(dim=1) == targets).sum().item()
                preds_list.extend(preds.argmax(dim=1).cpu().detach().numpy())
                targets_list.extend(targets.cpu().detach().numpy())

                # log
                val_loss.update(loss.item(), n=images.size(0))
            val_acc /= len(self.val_loader.dataset)
            val_f1 = f1_score(np.array(targets_list), np.array(preds_list), average='macro')

            self.logger.info(f'{phase} Loss:{val_loss.avg:.3f} | Acc:{val_acc:.4f} | F1:{val_f1:.4f}')
        return val_loss.avg, val_acc, val_f1

# %%
def main(args):
    print('<---- Training Params ---->')
    
    # Random Seed
    seed = args.seed
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = True

    save_path = os.path.join(args.model_path, (args.exp_num).zfill(3))
    
    # Create model directory
    os.makedirs(save_path, exist_ok=True)
    Trainer(args, save_path)

    return save_path

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())
# Out:
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 4

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
sub = pd.read_csv('./open/sample_submission.csv')
df_train = pd.read_csv('./open/train_df_add_data.csv')
df_test = pd.read_csv('./open/test_df.csv')

# %%
import ttach as tta

def predict(encoder_name, test_loader, device, model_path):
    model = Network_test(encoder_name).to(device)
    model.load_state_dict(torch.load(opj(model_path, 'best_model.pth'))['state_dict'])
#     model.eval()
    tta_model = tta.ClassificationTTAWrapper(model, tta.aliases.d4_transform())
    tta_model.eval()
    
    preds_list = []
    with torch.no_grad():
        for images in tqdm(test_loader):
            images = torch.as_tensor(images, device=device, dtype=torch.float32)
            preds = tta_model(images)
            preds = torch.softmax(preds, dim=1)
            preds_list.extend(preds.cpu().tolist())

    return np.array(preds_list)

def ensemble_5fold(model_path_list, test_loader, device):
    predict_list = []
    for model_path in model_path_list:
        prediction = predict(encoder_name= 'cait_s36_384', test_loader = test_loader, device = device, model_path = model_path)
        predict_list.append(prediction)
    ensemble = (predict_list[0] + predict_list[1] + predict_list[2] + predict_list[3] + predict_list[4])/len(predict_list)

    return ensemble

# %%
args.step = 0
models_path = []
for s_fold in range(5): # 5fold
    args.fold = s_fold
    args.exp_num = str(s_fold)
    save_path = main(args)
    models_path.append(save_path)
# Out:
# 2022-05-05 23:31:37,933 INFO: {'exp_num': '0', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_cait_s36_384/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'cait_s36_384', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 0}
# <---- Training Params ---->
# Dataset size:11197
# Dataset size:2800
# 2022-05-05 23:31:39,228 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 700/700 [11:36<00:00,  1.00it/s]
# 2022-05-05 23:43:16,476 INFO: Epoch:[001/100]
# 2022-05-05 23:43:16,477 INFO: Train Loss:3.228 | Acc:0.2241 | F1:0.1625
# 2022-05-05 23:44:20,146 INFO: val Loss:1.527 | Acc:0.5075 | F1:0.3982
# 2022-05-05 23:44:21,549 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [13:36<00:00,  1.17s/it]
# 2022-05-05 23:57:57,979 INFO: Epoch:[002/100]
# 2022-05-05 23:57:57,980 INFO: Train Loss:0.586 | Acc:0.7858 | F1:0.7818
# 2022-05-05 23:59:02,349 INFO: val Loss:0.157 | Acc:0.9271 | F1:0.9211
# 2022-05-05 23:59:04,597 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [13:38<00:00,  1.17s/it]
# 2022-05-06 00:12:43,104 INFO: Epoch:[003/100]
# 2022-05-06 00:12:43,105 INFO: Train Loss:0.082 | Acc:0.9543 | F1:0.9568
# 2022-05-06 00:13:48,822 INFO: val Loss:0.073 | Acc:0.9621 | F1:0.9617
# 2022-05-06 00:13:50,918 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [13:42<00:00,  1.18s/it]
# 2022-05-06 00:27:33,913 INFO: Epoch:[004/100]
# 2022-05-06 00:27:33,914 INFO: Train Loss:0.060 | Acc:0.9615 | F1:0.9614
# 2022-05-06 00:28:39,529 INFO: val Loss:0.041 | Acc:0.9771 | F1:0.9762
# 2022-05-06 00:28:41,514 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [13:41<00:00,  1.17s/it]
# 2022-05-06 00:42:23,035 INFO: Epoch:[005/100]
# 2022-05-06 00:42:23,036 INFO: Train Loss:0.052 | Acc:0.9695 | F1:0.9707
# 2022-05-06 00:43:34,341 INFO: val Loss:0.027 | Acc:0.9818 | F1:0.9838
# 2022-05-06 00:43:36,312 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [13:31<00:00,  1.16s/it]
# 2022-05-06 00:57:07,694 INFO: Epoch:[006/100]
# 2022-05-06 00:57:07,694 INFO: Train Loss:0.042 | Acc:0.9767 | F1:0.9781
# 2022-05-06 00:58:12,409 INFO: val Loss:0.033 | Acc:0.9811 | F1:0.9790
# 100%|██████████| 700/700 [13:51<00:00,  1.19s/it]
# 2022-05-06 01:12:03,923 INFO: Epoch:[007/100]
# 2022-05-06 01:12:03,924 INFO: Train Loss:0.035 | Acc:0.9798 | F1:0.9802
# 2022-05-06 01:13:09,862 INFO: val Loss:0.007 | Acc:0.9954 | F1:0.9952
# 2022-05-06 01:13:11,886 INFO: -----------------SAVE:7epoch----------------
# 100%|██████████| 700/700 [13:33<00:00,  1.16s/it]
# 2022-05-06 01:26:45,355 INFO: Epoch:[008/100]
# 2022-05-06 01:26:45,356 INFO: Train Loss:0.031 | Acc:0.9831 | F1:0.9834
# 2022-05-06 01:28:02,453 INFO: val Loss:0.046 | Acc:0.9818 | F1:0.9805
# 100%|██████████| 700/700 [13:17<00:00,  1.14s/it]
# 2022-05-06 01:41:20,103 INFO: Epoch:[009/100]
# 2022-05-06 01:41:20,103 INFO: Train Loss:0.023 | Acc:0.9855 | F1:0.9864
# 2022-05-06 01:42:36,202 INFO: val Loss:0.021 | Acc:0.9911 | F1:0.9863
# 100%|██████████| 700/700 [13:28<00:00,  1.15s/it]
# 2022-05-06 01:56:04,508 INFO: Epoch:[010/100]
# 2022-05-06 01:56:04,509 INFO: Train Loss:0.022 | Acc:0.9878 | F1:0.9888
# 2022-05-06 01:57:21,148 INFO: val Loss:0.016 | Acc:0.9879 | F1:0.9905
# 100%|██████████| 700/700 [13:13<00:00,  1.13s/it]
# 2022-05-06 02:10:34,626 INFO: Epoch:[011/100]
# 2022-05-06 02:10:34,627 INFO: Train Loss:0.022 | Acc:0.9872 | F1:0.9882
# 2022-05-06 02:11:26,396 INFO: val Loss:0.016 | Acc:0.9918 | F1:0.9930
# 100%|██████████| 700/700 [12:49<00:00,  1.10s/it]
# 2022-05-06 02:24:15,479 INFO: Epoch:[012/100]
# 2022-05-06 02:24:15,480 INFO: Train Loss:0.026 | Acc:0.9879 | F1:0.9877
# 2022-05-06 02:25:08,032 INFO: val Loss:0.008 | Acc:0.9954 | F1:0.9952
# 2022-05-06 02:25:08,034 INFO:
# Best Val Epoch:7 | Val Loss:0.0070 | Val Acc:0.9954 | Val F1:0.9952
# 2022-05-06 02:25:08,035 INFO: Total Process time:173.473Minute
# 2022-05-06 02:25:08,053 INFO: {'exp_num': '1', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_cait_s36_384/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'cait_s36_384', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 1}
# <---- Training Params ---->
# Dataset size:11197
# Dataset size:2800
# 2022-05-06 02:25:09,204 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 700/700 [12:45<00:00,  1.09s/it]
# 2022-05-06 02:37:55,292 INFO: Epoch:[001/100]
# 2022-05-06 02:37:55,292 INFO: Train Loss:3.235 | Acc:0.2230 | F1:0.1600
# 2022-05-06 02:38:47,197 INFO: val Loss:1.508 | Acc:0.5071 | F1:0.4013
# 2022-05-06 02:38:48,614 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [12:50<00:00,  1.10s/it]
# 2022-05-06 02:51:39,097 INFO: Epoch:[002/100]
# 2022-05-06 02:51:39,098 INFO: Train Loss:0.590 | Acc:0.7854 | F1:0.7798
# 2022-05-06 02:52:30,509 INFO: val Loss:0.161 | Acc:0.9239 | F1:0.9238
# 2022-05-06 02:52:32,437 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [12:47<00:00,  1.10s/it]
# 2022-05-06 03:05:19,684 INFO: Epoch:[003/100]
# 2022-05-06 03:05:19,685 INFO: Train Loss:0.085 | Acc:0.9534 | F1:0.9549
# 2022-05-06 03:06:11,106 INFO: val Loss:0.082 | Acc:0.9493 | F1:0.9443
# 2022-05-06 03:06:13,084 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [12:44<00:00,  1.09s/it]
# 2022-05-06 03:18:57,775 INFO: Epoch:[004/100]
# 2022-05-06 03:18:57,776 INFO: Train Loss:0.053 | Acc:0.9657 | F1:0.9666
# 2022-05-06 03:19:50,158 INFO: val Loss:0.023 | Acc:0.9832 | F1:0.9834
# 2022-05-06 03:19:52,005 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [12:51<00:00,  1.10s/it]
# 2022-05-06 03:32:43,214 INFO: Epoch:[005/100]
# 2022-05-06 03:32:43,215 INFO: Train Loss:0.050 | Acc:0.9720 | F1:0.9719
# 2022-05-06 03:33:35,442 INFO: val Loss:0.025 | Acc:0.9836 | F1:0.9853
# 100%|██████████| 700/700 [12:47<00:00,  1.10s/it]
# 2022-05-06 03:46:23,390 INFO: Epoch:[006/100]
# 2022-05-06 03:46:23,391 INFO: Train Loss:0.048 | Acc:0.9753 | F1:0.9765
# 2022-05-06 03:47:15,359 INFO: val Loss:0.012 | Acc:0.9939 | F1:0.9952
# 2022-05-06 03:47:17,297 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [12:47<00:00,  1.10s/it]
# 2022-05-06 04:00:04,456 INFO: Epoch:[007/100]
# 2022-05-06 04:00:04,457 INFO: Train Loss:0.033 | Acc:0.9812 | F1:0.9818
# 2022-05-06 04:01:05,474 INFO: val Loss:0.053 | Acc:0.9704 | F1:0.9742
# 100%|██████████| 700/700 [12:47<00:00,  1.10s/it]
# 2022-05-06 04:13:52,539 INFO: Epoch:[008/100]
# 2022-05-06 04:13:52,540 INFO: Train Loss:0.037 | Acc:0.9807 | F1:0.9808
# 2022-05-06 04:14:44,093 INFO: val Loss:0.017 | Acc:0.9882 | F1:0.9893
# 100%|██████████| 700/700 [12:50<00:00,  1.10s/it]
# 2022-05-06 04:27:34,626 INFO: Epoch:[009/100]
# 2022-05-06 04:27:34,626 INFO: Train Loss:0.021 | Acc:0.9862 | F1:0.9871
# 2022-05-06 04:28:27,160 INFO: val Loss:0.053 | Acc:0.9746 | F1:0.9794
# 100%|██████████| 700/700 [12:47<00:00,  1.10s/it]
# 2022-05-06 04:41:14,558 INFO: Epoch:[010/100]
# 2022-05-06 04:41:14,558 INFO: Train Loss:0.020 | Acc:0.9879 | F1:0.9887
# 2022-05-06 04:42:04,865 INFO: val Loss:0.032 | Acc:0.9832 | F1:0.9802
# 100%|██████████| 700/700 [12:49<00:00,  1.10s/it]
# 2022-05-06 04:54:54,001 INFO: Epoch:[011/100]
# 2022-05-06 04:54:54,002 INFO: Train Loss:0.023 | Acc:0.9869 | F1:0.9871
# 2022-05-06 04:55:46,429 INFO: val Loss:0.027 | Acc:0.9846 | F1:0.9852
# 2022-05-06 04:55:46,431 INFO:
# Best Val Epoch:6 | Val Loss:0.0123 | Val Acc:0.9939 | Val F1:0.9952
# 2022-05-06 04:55:46,432 INFO: Total Process time:150.613Minute
# 2022-05-06 04:55:46,458 INFO: {'exp_num': '2', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_cait_s36_384/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'cait_s36_384', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 2}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-06 04:55:47,566 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 700/700 [12:48<00:00,  1.10s/it]
# 2022-05-06 05:08:36,923 INFO: Epoch:[001/100]
# 2022-05-06 05:08:36,929 INFO: Train Loss:3.222 | Acc:0.2216 | F1:0.1570
# 2022-05-06 05:09:29,379 INFO: val Loss:1.497 | Acc:0.5534 | F1:0.4598
# 2022-05-06 05:09:30,778 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [12:55<00:00,  1.11s/it]
# 2022-05-06 05:22:25,929 INFO: Epoch:[002/100]
# 2022-05-06 05:22:25,930 INFO: Train Loss:0.599 | Acc:0.7832 | F1:0.7786
# 2022-05-06 05:23:18,658 INFO: val Loss:0.131 | Acc:0.9400 | F1:0.9380
# 2022-05-06 05:23:20,590 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [12:40<00:00,  1.09s/it]
# 2022-05-06 05:36:01,468 INFO: Epoch:[003/100]
# 2022-05-06 05:36:01,469 INFO: Train Loss:0.081 | Acc:0.9514 | F1:0.9521
# 2022-05-06 05:36:53,964 INFO: val Loss:0.059 | Acc:0.9671 | F1:0.9639
# 2022-05-06 05:36:55,897 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [12:53<00:00,  1.10s/it]
# 2022-05-06 05:49:49,348 INFO: Epoch:[004/100]
# 2022-05-06 05:49:49,349 INFO: Train Loss:0.048 | Acc:0.9705 | F1:0.9726
# 2022-05-06 05:50:41,405 INFO: val Loss:0.054 | Acc:0.9661 | F1:0.9720
# 2022-05-06 05:50:43,426 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [12:49<00:00,  1.10s/it]
# 2022-05-06 06:03:32,868 INFO: Epoch:[005/100]
# 2022-05-06 06:03:32,869 INFO: Train Loss:0.048 | Acc:0.9720 | F1:0.9732
# 2022-05-06 06:04:25,370 INFO: val Loss:0.032 | Acc:0.9789 | F1:0.9819
# 2022-05-06 06:04:27,164 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [12:48<00:00,  1.10s/it]
# 2022-05-06 06:17:15,643 INFO: Epoch:[006/100]
# 2022-05-06 06:17:15,644 INFO: Train Loss:0.044 | Acc:0.9731 | F1:0.9728
# 2022-05-06 06:18:08,909 INFO: val Loss:0.011 | Acc:0.9929 | F1:0.9932
# 2022-05-06 06:18:10,933 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [12:49<00:00,  1.10s/it]
# 2022-05-06 06:31:00,814 INFO: Epoch:[007/100]
# 2022-05-06 06:31:00,814 INFO: Train Loss:0.037 | Acc:0.9777 | F1:0.9787
# 2022-05-06 06:31:52,238 INFO: val Loss:0.067 | Acc:0.9825 | F1:0.9755
# 100%|██████████| 700/700 [12:55<00:00,  1.11s/it]
# 2022-05-06 06:44:48,141 INFO: Epoch:[008/100]
# 2022-05-06 06:44:48,142 INFO: Train Loss:0.033 | Acc:0.9813 | F1:0.9821
# 2022-05-06 06:45:40,246 INFO: val Loss:0.011 | Acc:0.9943 | F1:0.9955
# 2022-05-06 06:45:42,158 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [12:52<00:00,  1.10s/it]
# 2022-05-06 06:58:34,596 INFO: Epoch:[009/100]
# 2022-05-06 06:58:34,597 INFO: Train Loss:0.028 | Acc:0.9840 | F1:0.9846
# 2022-05-06 06:59:31,521 INFO: val Loss:0.012 | Acc:0.9936 | F1:0.9948
# 100%|██████████| 700/700 [12:40<00:00,  1.09s/it]
# 2022-05-06 07:12:11,900 INFO: Epoch:[010/100]
# 2022-05-06 07:12:11,901 INFO: Train Loss:0.026 | Acc:0.9862 | F1:0.9885
# 2022-05-06 07:13:03,961 INFO: val Loss:0.016 | Acc:0.9900 | F1:0.9915
# 100%|██████████| 700/700 [12:54<00:00,  1.11s/it]
# 2022-05-06 07:25:57,995 INFO: Epoch:[011/100]
# 2022-05-06 07:25:57,996 INFO: Train Loss:0.023 | Acc:0.9867 | F1:0.9872
# 2022-05-06 07:26:49,889 INFO: val Loss:0.016 | Acc:0.9904 | F1:0.9904
# 100%|██████████| 700/700 [12:54<00:00,  1.11s/it]
# 2022-05-06 07:39:44,287 INFO: Epoch:[012/100]
# 2022-05-06 07:39:44,288 INFO: Train Loss:0.021 | Acc:0.9887 | F1:0.9890
# 2022-05-06 07:40:35,817 INFO: val Loss:0.009 | Acc:0.9932 | F1:0.9921
# 2022-05-06 07:40:37,877 INFO: -----------------SAVE:12epoch----------------
# 100%|██████████| 700/700 [12:48<00:00,  1.10s/it]
# 2022-05-06 07:53:26,753 INFO: Epoch:[013/100]
# 2022-05-06 07:53:26,754 INFO: Train Loss:0.019 | Acc:0.9901 | F1:0.9910
# 2022-05-06 07:54:18,639 INFO: val Loss:0.029 | Acc:0.9821 | F1:0.9840
# 100%|██████████| 700/700 [12:47<00:00,  1.10s/it]
# 2022-05-06 08:07:06,416 INFO: Epoch:[014/100]
# 2022-05-06 08:07:06,416 INFO: Train Loss:0.019 | Acc:0.9888 | F1:0.9889
# 2022-05-06 08:07:58,730 INFO: val Loss:0.012 | Acc:0.9946 | F1:0.9953
# 100%|██████████| 700/700 [12:46<00:00,  1.10s/it]
# 2022-05-06 08:20:45,292 INFO: Epoch:[015/100]
# 2022-05-06 08:20:45,292 INFO: Train Loss:0.013 | Acc:0.9918 | F1:0.9928
# 2022-05-06 08:21:37,021 INFO: val Loss:0.044 | Acc:0.9882 | F1:0.9805
# 100%|██████████| 700/700 [12:44<00:00,  1.09s/it]
# 2022-05-06 08:34:21,238 INFO: Epoch:[016/100]
# 2022-05-06 08:34:21,238 INFO: Train Loss:0.023 | Acc:0.9890 | F1:0.9882
# 2022-05-06 08:35:13,603 INFO: val Loss:0.010 | Acc:0.9936 | F1:0.9939
# 100%|██████████| 700/700 [12:50<00:00,  1.10s/it]
# 2022-05-06 08:48:04,591 INFO: Epoch:[017/100]
# 2022-05-06 08:48:04,591 INFO: Train Loss:0.018 | Acc:0.9907 | F1:0.9904
# 2022-05-06 08:48:57,902 INFO: val Loss:0.007 | Acc:0.9939 | F1:0.9955
# 2022-05-06 08:48:59,894 INFO: -----------------SAVE:17epoch----------------
# 100%|██████████| 700/700 [12:55<00:00,  1.11s/it]
# 2022-05-06 09:01:55,287 INFO: Epoch:[018/100]
# 2022-05-06 09:01:55,288 INFO: Train Loss:0.019 | Acc:0.9912 | F1:0.9911
# 2022-05-06 09:02:47,121 INFO: val Loss:0.022 | Acc:0.9846 | F1:0.9856
# 100%|██████████| 700/700 [14:51<00:00,  1.27s/it]
# 2022-05-06 09:17:38,844 INFO: Epoch:[019/100]
# 2022-05-06 09:17:38,845 INFO: Train Loss:0.014 | Acc:0.9914 | F1:0.9923
# 2022-05-06 09:18:44,077 INFO: val Loss:0.006 | Acc:0.9957 | F1:0.9966
# 2022-05-06 09:18:46,211 INFO: -----------------SAVE:19epoch----------------
# 100%|██████████| 700/700 [15:05<00:00,  1.29s/it]
# 2022-05-06 09:33:51,299 INFO: Epoch:[020/100]
# 2022-05-06 09:33:51,300 INFO: Train Loss:0.013 | Acc:0.9921 | F1:0.9933
# 2022-05-06 09:34:58,927 INFO: val Loss:0.006 | Acc:0.9964 | F1:0.9972
# 100%|██████████| 700/700 [14:58<00:00,  1.28s/it]
# 2022-05-06 09:49:57,055 INFO: Epoch:[021/100]
# 2022-05-06 09:49:57,056 INFO: Train Loss:0.014 | Acc:0.9917 | F1:0.9927
# 2022-05-06 09:51:02,211 INFO: val Loss:0.007 | Acc:0.9918 | F1:0.9932
# 100%|██████████| 700/700 [15:00<00:00,  1.29s/it]
# 2022-05-06 10:06:03,216 INFO: Epoch:[022/100]
# 2022-05-06 10:06:03,217 INFO: Train Loss:0.013 | Acc:0.9929 | F1:0.9930
# 2022-05-06 10:07:07,595 INFO: val Loss:0.005 | Acc:0.9964 | F1:0.9972
# 2022-05-06 10:07:09,609 INFO: -----------------SAVE:22epoch----------------
# 100%|██████████| 700/700 [14:56<00:00,  1.28s/it]
# 2022-05-06 10:22:05,646 INFO: Epoch:[023/100]
# 2022-05-06 10:22:05,647 INFO: Train Loss:0.012 | Acc:0.9926 | F1:0.9927
# 2022-05-06 10:23:10,556 INFO: val Loss:0.006 | Acc:0.9932 | F1:0.9940
# 100%|██████████| 700/700 [14:58<00:00,  1.28s/it]
# 2022-05-06 10:38:09,123 INFO: Epoch:[024/100]
# 2022-05-06 10:38:09,124 INFO: Train Loss:0.014 | Acc:0.9918 | F1:0.9925
# 2022-05-06 10:39:14,287 INFO: val Loss:0.012 | Acc:0.9929 | F1:0.9941
# 100%|██████████| 700/700 [14:56<00:00,  1.28s/it]
# 2022-05-06 10:54:10,941 INFO: Epoch:[025/100]
# 2022-05-06 10:54:10,942 INFO: Train Loss:0.016 | Acc:0.9924 | F1:0.9935
# 2022-05-06 10:55:19,418 INFO: val Loss:0.010 | Acc:0.9932 | F1:0.9950
# 100%|██████████| 700/700 [14:58<00:00,  1.28s/it]
# 2022-05-06 11:10:18,118 INFO: Epoch:[026/100]
# 2022-05-06 11:10:18,119 INFO: Train Loss:0.011 | Acc:0.9939 | F1:0.9946
# 2022-05-06 11:11:23,835 INFO: val Loss:0.016 | Acc:0.9793 | F1:0.9842
# 100%|██████████| 700/700 [14:57<00:00,  1.28s/it]
# 2022-05-06 11:26:21,397 INFO: Epoch:[027/100]
# 2022-05-06 11:26:21,398 INFO: Train Loss:0.013 | Acc:0.9933 | F1:0.9942
# 2022-05-06 11:27:23,946 INFO: val Loss:0.008 | Acc:0.9932 | F1:0.9949
# 2022-05-06 11:27:23,948 INFO:
# Best Val Epoch:22 | Val Loss:0.0047 | Val Acc:0.9964 | Val F1:0.9972
# 2022-05-06 11:27:23,949 INFO: Total Process time:391.598Minute
# 2022-05-06 11:27:23,989 INFO: {'exp_num': '3', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_cait_s36_384/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'cait_s36_384', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 3}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-06 11:27:25,141 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 700/700 [15:24<00:00,  1.32s/it]
# 2022-05-06 11:42:50,301 INFO: Epoch:[001/100]
# 2022-05-06 11:42:50,301 INFO: Train Loss:3.227 | Acc:0.2223 | F1:0.1606
# 2022-05-06 11:44:01,367 INFO: val Loss:1.495 | Acc:0.5027 | F1:0.3975
# 2022-05-06 11:44:02,793 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [35:22<00:00,  3.03s/it]
# 2022-05-06 12:19:25,646 INFO: Epoch:[002/100]
# 2022-05-06 12:19:25,646 INFO: Train Loss:0.592 | Acc:0.7887 | F1:0.7837
# 2022-05-06 12:20:37,255 INFO: val Loss:0.172 | Acc:0.9243 | F1:0.9183
# 2022-05-06 12:20:39,343 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [20:49<00:00,  1.79s/it]
# 2022-05-06 12:41:29,273 INFO: Epoch:[003/100]
# 2022-05-06 12:41:29,274 INFO: Train Loss:0.080 | Acc:0.9539 | F1:0.9554
# 2022-05-06 12:42:30,857 INFO: val Loss:0.047 | Acc:0.9736 | F1:0.9764
# 2022-05-06 12:42:32,947 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [12:58<00:00,  1.11s/it]
# 2022-05-06 12:55:31,103 INFO: Epoch:[004/100]
# 2022-05-06 12:55:31,104 INFO: Train Loss:0.052 | Acc:0.9675 | F1:0.9670
# 2022-05-06 12:56:27,988 INFO: val Loss:0.021 | Acc:0.9864 | F1:0.9880
# 2022-05-06 12:56:30,020 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [13:14<00:00,  1.14s/it]
# 2022-05-06 13:09:44,701 INFO: Epoch:[005/100]
# 2022-05-06 13:09:44,701 INFO: Train Loss:0.048 | Acc:0.9716 | F1:0.9729
# 2022-05-06 13:10:47,411 INFO: val Loss:0.067 | Acc:0.9711 | F1:0.9753
# 100%|██████████| 700/700 [13:31<00:00,  1.16s/it]
# 2022-05-06 13:24:18,613 INFO: Epoch:[006/100]
# 2022-05-06 13:24:18,614 INFO: Train Loss:0.044 | Acc:0.9747 | F1:0.9751
# 2022-05-06 13:25:20,944 INFO: val Loss:0.022 | Acc:0.9796 | F1:0.9769
# 100%|██████████| 700/700 [13:24<00:00,  1.15s/it]
# 2022-05-06 13:38:45,737 INFO: Epoch:[007/100]
# 2022-05-06 13:38:45,738 INFO: Train Loss:0.037 | Acc:0.9779 | F1:0.9788
# 2022-05-06 13:39:49,126 INFO: val Loss:0.021 | Acc:0.9846 | F1:0.9860
# 100%|██████████| 700/700 [13:36<00:00,  1.17s/it]
# 2022-05-06 13:53:25,551 INFO: Epoch:[008/100]
# 2022-05-06 13:53:25,551 INFO: Train Loss:0.028 | Acc:0.9825 | F1:0.9836
# 2022-05-06 13:54:30,961 INFO: val Loss:0.014 | Acc:0.9893 | F1:0.9904
# 2022-05-06 13:54:32,973 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [13:27<00:00,  1.15s/it]
# 2022-05-06 14:08:00,895 INFO: Epoch:[009/100]
# 2022-05-06 14:08:00,896 INFO: Train Loss:0.031 | Acc:0.9843 | F1:0.9845
# 2022-05-06 14:09:04,641 INFO: val Loss:0.032 | Acc:0.9800 | F1:0.9706
# 100%|██████████| 700/700 [13:37<00:00,  1.17s/it]
# 2022-05-06 14:22:41,842 INFO: Epoch:[010/100]
# 2022-05-06 14:22:41,845 INFO: Train Loss:0.024 | Acc:0.9861 | F1:0.9867
# 2022-05-06 14:23:45,179 INFO: val Loss:0.015 | Acc:0.9879 | F1:0.9903
# 100%|██████████| 700/700 [13:27<00:00,  1.15s/it]
# 2022-05-06 14:37:12,243 INFO: Epoch:[011/100]
# 2022-05-06 14:37:12,243 INFO: Train Loss:0.023 | Acc:0.9864 | F1:0.9869
# 2022-05-06 14:38:13,278 INFO: val Loss:0.012 | Acc:0.9914 | F1:0.9927
# 2022-05-06 14:38:15,214 INFO: -----------------SAVE:11epoch----------------
# 100%|██████████| 700/700 [13:30<00:00,  1.16s/it]
# 2022-05-06 14:51:46,134 INFO: Epoch:[012/100]
# 2022-05-06 14:51:46,134 INFO: Train Loss:0.021 | Acc:0.9886 | F1:0.9892
# 2022-05-06 14:52:48,627 INFO: val Loss:0.041 | Acc:0.9818 | F1:0.9820
# 100%|██████████| 700/700 [13:30<00:00,  1.16s/it]
# 2022-05-06 15:06:18,732 INFO: Epoch:[013/100]
# 2022-05-06 15:06:18,733 INFO: Train Loss:0.020 | Acc:0.9876 | F1:0.9877
# 2022-05-06 15:07:21,990 INFO: val Loss:0.015 | Acc:0.9893 | F1:0.9870
# 100%|██████████| 700/700 [13:30<00:00,  1.16s/it]
# 2022-05-06 15:20:52,335 INFO: Epoch:[014/100]
# 2022-05-06 15:20:52,337 INFO: Train Loss:0.022 | Acc:0.9880 | F1:0.9880
# 2022-05-06 15:21:55,298 INFO: val Loss:0.009 | Acc:0.9925 | F1:0.9928
# 2022-05-06 15:21:57,296 INFO: -----------------SAVE:14epoch----------------
# 100%|██████████| 700/700 [13:36<00:00,  1.17s/it]
# 2022-05-06 15:35:33,646 INFO: Epoch:[015/100]
# 2022-05-06 15:35:33,647 INFO: Train Loss:0.017 | Acc:0.9897 | F1:0.9897
# 2022-05-06 15:36:36,351 INFO: val Loss:0.035 | Acc:0.9786 | F1:0.9800
# 100%|██████████| 700/700 [13:37<00:00,  1.17s/it]
# 2022-05-06 15:50:14,201 INFO: Epoch:[016/100]
# 2022-05-06 15:50:14,202 INFO: Train Loss:0.016 | Acc:0.9899 | F1:0.9912
# 2022-05-06 15:51:16,551 INFO: val Loss:0.013 | Acc:0.9921 | F1:0.9940
# 100%|██████████| 700/700 [13:34<00:00,  1.16s/it]
# 2022-05-06 16:04:51,133 INFO: Epoch:[017/100]
# 2022-05-06 16:04:51,134 INFO: Train Loss:0.015 | Acc:0.9912 | F1:0.9912
# 2022-05-06 16:05:54,483 INFO: val Loss:0.062 | Acc:0.9811 | F1:0.9730
# 100%|██████████| 700/700 [13:31<00:00,  1.16s/it]
# 2022-05-06 16:19:26,380 INFO: Epoch:[018/100]
# 2022-05-06 16:19:26,381 INFO: Train Loss:0.020 | Acc:0.9910 | F1:0.9911
# 2022-05-06 16:20:29,526 INFO: val Loss:0.007 | Acc:0.9943 | F1:0.9947
# 2022-05-06 16:20:31,576 INFO: -----------------SAVE:18epoch----------------
# 100%|██████████| 700/700 [13:30<00:00,  1.16s/it]
# 2022-05-06 16:34:02,379 INFO: Epoch:[019/100]
# 2022-05-06 16:34:02,379 INFO: Train Loss:0.015 | Acc:0.9909 | F1:0.9909
# 2022-05-06 16:35:05,913 INFO: val Loss:0.008 | Acc:0.9961 | F1:0.9967
# 100%|██████████| 700/700 [13:25<00:00,  1.15s/it]
# 2022-05-06 16:48:31,824 INFO: Epoch:[020/100]
# 2022-05-06 16:48:31,825 INFO: Train Loss:0.015 | Acc:0.9921 | F1:0.9932
# 2022-05-06 16:49:36,233 INFO: val Loss:0.009 | Acc:0.9932 | F1:0.9936
# 100%|██████████| 700/700 [13:31<00:00,  1.16s/it]
# 2022-05-06 17:03:07,740 INFO: Epoch:[021/100]
# 2022-05-06 17:03:07,740 INFO: Train Loss:0.015 | Acc:0.9915 | F1:0.9925
# 2022-05-06 17:04:17,432 INFO: val Loss:0.006 | Acc:0.9968 | F1:0.9974
# 2022-05-06 17:04:19,498 INFO: -----------------SAVE:21epoch----------------
# 100%|██████████| 700/700 [13:38<00:00,  1.17s/it]
# 2022-05-06 17:17:58,225 INFO: Epoch:[022/100]
# 2022-05-06 17:17:58,226 INFO: Train Loss:0.016 | Acc:0.9923 | F1:0.9935
# 2022-05-06 17:19:09,829 INFO: val Loss:0.003 | Acc:0.9971 | F1:0.9975
# 2022-05-06 17:19:11,830 INFO: -----------------SAVE:22epoch----------------
# 100%|██████████| 700/700 [13:34<00:00,  1.16s/it]
# 2022-05-06 17:32:46,066 INFO: Epoch:[023/100]
# 2022-05-06 17:32:46,067 INFO: Train Loss:0.012 | Acc:0.9936 | F1:0.9939
# 2022-05-06 17:33:49,412 INFO: val Loss:0.005 | Acc:0.9957 | F1:0.9957
# 100%|██████████| 700/700 [13:32<00:00,  1.16s/it]
# 2022-05-06 17:47:21,865 INFO: Epoch:[024/100]
# 2022-05-06 17:47:21,866 INFO: Train Loss:0.018 | Acc:0.9921 | F1:0.9919
# 2022-05-06 17:48:25,707 INFO: val Loss:0.012 | Acc:0.9918 | F1:0.9907
# 100%|██████████| 700/700 [13:28<00:00,  1.15s/it]
# 2022-05-06 18:01:53,909 INFO: Epoch:[025/100]
# 2022-05-06 18:01:53,910 INFO: Train Loss:0.014 | Acc:0.9919 | F1:0.9925
# 2022-05-06 18:02:57,829 INFO: val Loss:0.003 | Acc:0.9979 | F1:0.9982
# 100%|██████████| 700/700 [13:30<00:00,  1.16s/it]
# 2022-05-06 18:16:28,368 INFO: Epoch:[026/100]
# 2022-05-06 18:16:28,368 INFO: Train Loss:0.014 | Acc:0.9929 | F1:0.9938
# 2022-05-06 18:17:31,754 INFO: val Loss:0.002 | Acc:0.9986 | F1:0.9989
# 2022-05-06 18:17:33,861 INFO: -----------------SAVE:26epoch----------------
# 100%|██████████| 700/700 [13:24<00:00,  1.15s/it]
# 2022-05-06 18:30:57,930 INFO: Epoch:[027/100]
# 2022-05-06 18:30:57,930 INFO: Train Loss:0.016 | Acc:0.9931 | F1:0.9927
# 2022-05-06 18:32:00,670 INFO: val Loss:0.011 | Acc:0.9921 | F1:0.9921
# 100%|██████████| 700/700 [13:34<00:00,  1.16s/it]
# 2022-05-06 18:45:35,484 INFO: Epoch:[028/100]
# 2022-05-06 18:45:35,485 INFO: Train Loss:0.014 | Acc:0.9933 | F1:0.9934
# 2022-05-06 18:46:39,241 INFO: val Loss:0.005 | Acc:0.9968 | F1:0.9976
# 100%|██████████| 700/700 [13:33<00:00,  1.16s/it]
# 2022-05-06 19:00:12,378 INFO: Epoch:[029/100]
# 2022-05-06 19:00:12,378 INFO: Train Loss:0.010 | Acc:0.9938 | F1:0.9944
# 2022-05-06 19:01:15,488 INFO: val Loss:0.049 | Acc:0.9900 | F1:0.9899
# 100%|██████████| 700/700 [13:23<00:00,  1.15s/it]
# 2022-05-06 19:14:38,892 INFO: Epoch:[030/100]
# 2022-05-06 19:14:38,892 INFO: Train Loss:0.015 | Acc:0.9925 | F1:0.9935
# 2022-05-06 19:15:40,965 INFO: val Loss:0.011 | Acc:0.9914 | F1:0.9925
# 100%|██████████| 700/700 [13:30<00:00,  1.16s/it]
# 2022-05-06 19:29:11,818 INFO: Epoch:[031/100]
# 2022-05-06 19:29:11,819 INFO: Train Loss:0.012 | Acc:0.9937 | F1:0.9941
# 2022-05-06 19:30:14,157 INFO: val Loss:0.005 | Acc:0.9975 | F1:0.9976
# 2022-05-06 19:30:14,159 INFO:
# Best Val Epoch:26 | Val Loss:0.0017 | Val Acc:0.9986 | Val F1:0.9989
# 2022-05-06 19:30:14,160 INFO: Total Process time:482.809Minute
# 2022-05-06 19:30:14,183 INFO: {'exp_num': '4', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_cait_s36_384/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'cait_s36_384', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 5, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 4}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-06 19:30:15,345 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 700/700 [13:28<00:00,  1.16s/it]
# 2022-05-06 19:43:44,856 INFO: Epoch:[001/100]
# 2022-05-06 19:43:44,856 INFO: Train Loss:3.220 | Acc:0.2250 | F1:0.1626
# 2022-05-06 19:44:46,922 INFO: val Loss:1.529 | Acc:0.5434 | F1:0.4474
# 2022-05-06 19:44:48,493 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [13:25<00:00,  1.15s/it]
# 2022-05-06 19:58:13,512 INFO: Epoch:[002/100]
# 2022-05-06 19:58:13,513 INFO: Train Loss:0.596 | Acc:0.7868 | F1:0.7796
# 2022-05-06 19:59:16,023 INFO: val Loss:0.130 | Acc:0.9468 | F1:0.9417
# 2022-05-06 19:59:17,932 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [13:30<00:00,  1.16s/it]
# 2022-05-06 20:12:48,353 INFO: Epoch:[003/100]
# 2022-05-06 20:12:48,354 INFO: Train Loss:0.082 | Acc:0.9512 | F1:0.9525
# 2022-05-06 20:13:51,109 INFO: val Loss:0.095 | Acc:0.9332 | F1:0.9280
# 2022-05-06 20:13:53,123 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [13:31<00:00,  1.16s/it]
# 2022-05-06 20:27:24,820 INFO: Epoch:[004/100]
# 2022-05-06 20:27:24,821 INFO: Train Loss:0.051 | Acc:0.9688 | F1:0.9699
# 2022-05-06 20:28:27,586 INFO: val Loss:0.053 | Acc:0.9764 | F1:0.9763
# 2022-05-06 20:28:29,452 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [13:25<00:00,  1.15s/it]
# 2022-05-06 20:41:55,385 INFO: Epoch:[005/100]
# 2022-05-06 20:41:55,386 INFO: Train Loss:0.050 | Acc:0.9712 | F1:0.9712
# 2022-05-06 20:42:57,595 INFO: val Loss:0.043 | Acc:0.9682 | F1:0.9708
# 2022-05-06 20:42:59,563 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [13:32<00:00,  1.16s/it]
# 2022-05-06 20:56:32,576 INFO: Epoch:[006/100]
# 2022-05-06 20:56:32,577 INFO: Train Loss:0.043 | Acc:0.9706 | F1:0.9719
# 2022-05-06 20:57:34,653 INFO: val Loss:0.028 | Acc:0.9846 | F1:0.9859
# 2022-05-06 20:57:36,597 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [13:33<00:00,  1.16s/it]
# 2022-05-06 21:11:10,505 INFO: Epoch:[007/100]
# 2022-05-06 21:11:10,506 INFO: Train Loss:0.036 | Acc:0.9784 | F1:0.9788
# 2022-05-06 21:12:13,060 INFO: val Loss:0.027 | Acc:0.9861 | F1:0.9886
# 2022-05-06 21:12:15,163 INFO: -----------------SAVE:7epoch----------------
# 100%|██████████| 700/700 [13:21<00:00,  1.14s/it]
# 2022-05-06 21:25:36,478 INFO: Epoch:[008/100]
# 2022-05-06 21:25:36,479 INFO: Train Loss:0.029 | Acc:0.9835 | F1:0.9853
# 2022-05-06 21:26:39,775 INFO: val Loss:0.018 | Acc:0.9882 | F1:0.9878
# 2022-05-06 21:26:41,713 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [13:28<00:00,  1.15s/it]
# 2022-05-06 21:40:09,823 INFO: Epoch:[009/100]
# 2022-05-06 21:40:09,824 INFO: Train Loss:0.025 | Acc:0.9855 | F1:0.9859
# 2022-05-06 21:41:15,293 INFO: val Loss:0.093 | Acc:0.9736 | F1:0.9683
# 100%|██████████| 700/700 [13:29<00:00,  1.16s/it]
# 2022-05-06 21:54:44,535 INFO: Epoch:[010/100]
# 2022-05-06 21:54:44,535 INFO: Train Loss:0.029 | Acc:0.9848 | F1:0.9863
# 2022-05-06 21:55:55,278 INFO: val Loss:0.013 | Acc:0.9904 | F1:0.9897
# 2022-05-06 21:55:56,953 INFO: -----------------SAVE:10epoch----------------
# 100%|██████████| 700/700 [13:40<00:00,  1.17s/it]
# 2022-05-06 22:09:37,483 INFO: Epoch:[011/100]
# 2022-05-06 22:09:37,484 INFO: Train Loss:0.028 | Acc:0.9857 | F1:0.9853
# 2022-05-06 22:10:44,184 INFO: val Loss:0.003 | Acc:0.9971 | F1:0.9974
# 2022-05-06 22:10:46,211 INFO: -----------------SAVE:11epoch----------------
# 100%|██████████| 700/700 [13:45<00:00,  1.18s/it]
# 2022-05-06 22:24:31,562 INFO: Epoch:[012/100]
# 2022-05-06 22:24:31,563 INFO: Train Loss:0.023 | Acc:0.9882 | F1:0.9884
# 2022-05-06 22:25:36,211 INFO: val Loss:0.016 | Acc:0.9900 | F1:0.9879
# 100%|██████████| 700/700 [13:33<00:00,  1.16s/it]
# 2022-05-06 22:39:10,110 INFO: Epoch:[013/100]
# 2022-05-06 22:39:10,111 INFO: Train Loss:0.017 | Acc:0.9904 | F1:0.9901
# 2022-05-06 22:40:14,295 INFO: val Loss:0.006 | Acc:0.9954 | F1:0.9953
# 100%|██████████| 700/700 [13:32<00:00,  1.16s/it]
# 2022-05-06 22:53:46,598 INFO: Epoch:[014/100]
# 2022-05-06 22:53:46,599 INFO: Train Loss:0.019 | Acc:0.9899 | F1:0.9898
# 2022-05-06 22:54:49,370 INFO: val Loss:0.013 | Acc:0.9932 | F1:0.9906
# 100%|██████████| 700/700 [13:24<00:00,  1.15s/it]
# 2022-05-06 23:08:13,840 INFO: Epoch:[015/100]
# 2022-05-06 23:08:13,841 INFO: Train Loss:0.016 | Acc:0.9921 | F1:0.9919
# 2022-05-06 23:09:15,211 INFO: val Loss:0.005 | Acc:0.9957 | F1:0.9960
# 100%|██████████| 700/700 [13:32<00:00,  1.16s/it]
# 2022-05-06 23:22:47,701 INFO: Epoch:[016/100]
# 2022-05-06 23:22:47,702 INFO: Train Loss:0.018 | Acc:0.9907 | F1:0.9912
# 2022-05-06 23:23:51,001 INFO: val Loss:0.011 | Acc:0.9957 | F1:0.9958
# 2022-05-06 23:23:51,004 INFO:
# Best Val Epoch:11 | Val Loss:0.0033 | Val Acc:0.9971 | Val F1:0.9974
# 2022-05-06 23:23:51,005 INFO: Total Process time:233.586Minute

# %%
img_size = 384

test_transform = get_train_augmentation(img_size=img_size, ver=1)
test_dataset = Test_dataset(df_test, test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0)
# Out:
# Test Dataset size:2154

# %%
# models_path = ['./label_results/000', './label_results/001', './label_results/002', './label_results/003', './label_results/004']

# %%
ensemble = ensemble_5fold(models_path, test_loader, device)
# Out:
# 2022-05-06 23:23:52,234 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 34/34 [11:36<00:00, 20.48s/it]
# 2022-05-06 23:35:31,850 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 34/34 [11:35<00:00, 20.45s/it]
# 2022-05-06 23:47:10,229 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 34/34 [11:35<00:00, 20.46s/it]
# 2022-05-06 23:58:48,713 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 34/34 [09:11<00:00, 16.22s/it]
# 2022-05-07 00:08:02,341 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/deit/S36_384.pth)
# 100%|██████████| 34/34 [09:11<00:00, 16.21s/it]

# %%
f_pred = ensemble.argmax(axis=1).tolist()
f_pred
# Out:
# [62,
#  28,
#  72,
#  64,
#  63,
#  50,
#  14,
#  32,
#  40,
#  39,
#  0,
#  76,
#  85,
#  59,
#  62,
#  2,
#  25,
#  22,
#  21,
#  47,
#  66,
#  84,
#  0,
#  58,
#  51,
#  55,
#  51,
#  60,
#  40,
#  78,
#  55,
#  9,
#  59,
#  83,
#  84,
#  82,
#  40,
#  9,
#  37,
#  44,
#  45,
#  10,
#  60,
#  14,
#  44,
#  63,
#  68,
#  13,
#  84,
#  55,
#  9,
#  72,
#  31,
#  35,
#  84,
#  46,
#  20,
#  21,
#  38,
#  15,
#  72,
#  48,
#  18,
#  80,
#  13,
#  36,
#  72,
#  13,
#  53,
#  43,
#  25,
#  76,
#  32,
#  61,
#  41,
#  84,
#  9,
#  40,
#  9,
#  9,
#  50,
#  76,
#  57,
#  75,
#  72,
#  1,
#  84,
#  21,
#  40,
#  83,
#  36,
#  84,
#  9,
#  42,
#  55,
#  65,
#  72,
#  72,
#  45,
#  45,
#  9,
#  21,
#  52,
#  17,
#  76,
#  2,
#  85,
#  49,
#  72,
#  34,
#  36,
#  58,
#  69,
#  72,
#  84,
#  15,
#  28,
#  52,
#  15,
#  41,
#  55,
#  19,
#  45,
#  72,
#  77,
#  70,
#  61,
#  72,
#  54,
#  55,
#  28,
#  46,
#  50,
#  42,
#  15,
#  25,
#  57,
#  2,
#  52,
#  78,
#  72,
#  33,
#  7,
#  9,
#  84,
#  35,
#  23,
#  84,
#  85,
#  76,
#  84,
#  79,
#  72,
#  52,
#  83,
#  63,
#  67,
#  63,
#  33,
#  45,
#  57,
#  60,
#  57,
#  11,
#  21,
#  38,
#  49,
#  74,
#  83,
#  10,
#  21,
#  24,
#  56,
#  39,
#  9,
#  52,
#  55,
#  86,
#  15,
#  84,
#  40,
#  27,
#  3,
#  11,
#  51,
#  20,
#  62,
#  45,
#  79,
#  73,
#  54,
#  18,
#  84,
#  32,
#  52,
#  57,
#  81,
#  85,
#  84,
#  33,
#  72,
#  12,
#  58,
#  1,
#  52,
#  40,
#  47,
#  52,
#  33,
#  25,
#  41,
#  15,
#  55,
#  76,
#  48,
#  22,
#  18,
#  49,
#  72,
#  1,
#  65,
#  28,
#  63,
#  1,
#  15,
#  43,
#  51,
#  36,
#  9,
#  72,
#  52,
#  55,
#  81,
#  49,
#  80,
#  17,
#  72,
#  45,
#  31,
#  14,
#  45,
#  34,
#  85,
#  59,
#  74,
#  41,
#  63,
#  64,
#  79,
#  5,
#  72,
#  64,
#  4,
#  15,
#  44,
#  45,
#  45,
#  13,
#  80,
#  33,
#  31,
#  55,
#  33,
#  32,
#  41,
#  40,
#  76,
#  55,
#  44,
#  9,
#  21,
#  55,
#  77,
#  69,
#  9,
#  15,
#  47,
#  15,
#  72,
#  87,
#  48,
#  36,
#  72,
#  53,
#  52,
#  55,
#  30,
#  63,
#  63,
#  0,
#  22,
#  1,
#  38,
#  37,
#  9,
#  87,
#  63,
#  72,
#  72,
#  72,
#  58,
#  41,
#  80,
#  72,
#  57,
#  51,
#  68,
#  28,
#  36,
#  57,
#  55,
#  72,
#  3,
#  46,
#  76,
#  72,
#  59,
#  76,
#  76,
#  63,
#  9,
#  58,
#  46,
#  7,
#  40,
#  15,
#  55,
#  56,
#  50,
#  72,
#  58,
#  15,
#  55,
#  21,
#  19,
#  3,
#  63,
#  43,
#  58,
#  4,
#  76,
#  55,
#  42,
#  63,
#  55,
#  39,
#  44,
#  42,
#  33,
#  53,
#  24,
#  5,
#  9,
#  17,
#  21,
#  16,
#  9,
#  52,
#  2,
#  67,
#  70,
#  13,
#  38,
#  19,
#  72,
#  85,
#  74,
#  7,
#  9,
#  37,
#  33,
#  55,
#  9,
#  3,
#  33,
#  72,
#  77,
#  56,
#  14,
#  28,
#  46,
#  55,
#  74,
#  62,
#  15,
#  28,
#  42,
#  15,
#  32,
#  55,
#  40,
#  43,
#  1,
#  41,
#  16,
#  69,
#  5,
#  2,
#  35,
#  63,
#  78,
#  64,
#  72,
#  82,
#  2,
#  63,
#  50,
#  17,
#  40,
#  51,
#  9,
#  16,
#  52,
#  9,
#  1,
#  72,
#  40,
#  72,
#  32,
#  69,
#  42,
#  84,
#  42,
#  21,
#  19,
#  50,
#  82,
#  84,
#  39,
#  71,
#  1,
#  84,
#  9,
#  1,
#  63,
#  31,
#  79,
#  51,
#  21,
#  29,
#  47,
#  65,
#  72,
#  56,
#  72,
#  70,
#  21,
#  87,
#  62,
#  38,
#  77,
#  84,
#  1,
#  21,
#  63,
#  33,
#  59,
#  33,
#  22,
#  44,
#  9,
#  21,
#  60,
#  41,
#  24,
#  14,
#  13,
#  44,
#  59,
#  45,
#  53,
#  42,
#  63,
#  3,
#  56,
#  9,
#  76,
#  72,
#  60,
#  60,
#  48,
#  55,
#  22,
#  9,
#  55,
#  55,
#  9,
#  28,
#  34,
#  51,
#  20,
#  6,
#  7,
#  55,
#  33,
#  18,
#  70,
#  67,
#  7,
#  86,
#  56,
#  65,
#  46,
#  72,
#  4,
#  63,
#  38,
#  78,
#  68,
#  41,
#  15,
#  56,
#  72,
#  72,
#  72,
#  84,
#  9,
#  46,
#  40,
#  9,
#  64,
#  53,
#  76,
#  45,
#  52,
#  82,
#  9,
#  76,
#  15,
#  20,
#  15,
#  34,
#  33,
#  34,
#  28,
#  55,
#  86,
#  79,
#  49,
#  67,
#  9,
#  76,
#  29,
#  55,
#  28,
#  87,
#  72,
#  63,
#  33,
#  54,
#  9,
#  13,
#  47,
#  52,
#  81,
#  62,
#  55,
#  15,
#  87,
#  56,
#  39,
#  15,
#  40,
#  23,
#  9,
#  33,
#  28,
#  28,
#  33,
#  59,
#  33,
#  79,
#  33,
#  52,
#  11,
#  77,
#  86,
#  21,
#  27,
#  82,
#  49,
#  42,
#  63,
#  22,
#  72,
#  72,
#  72,
#  21,
#  40,
#  72,
#  55,
#  32,
#  9,
#  87,
#  84,
#  42,
#  23,
#  63,
#  86,
#  33,
#  40,
#  33,
#  34,
#  7,
#  50,
#  9,
#  52,
#  9,
#  70,
#  51,
#  42,
#  27,
#  9,
#  24,
#  33,
#  16,
#  52,
#  86,
#  24,
#  4,
#  9,
#  8,
#  87,
#  62,
#  0,
#  22,
#  42,
#  68,
#  33,
#  1,
#  40,
#  67,
#  55,
#  58,
#  80,
#  40,
#  11,
#  15,
#  23,
#  41,
#  52,
#  38,
#  72,
#  0,
#  21,
#  83,
#  9,
#  37,
#  15,
#  86,
#  75,
#  35,
#  21,
#  56,
#  29,
#  79,
#  58,
#  13,
#  18,
#  40,
#  72,
#  8,
#  21,
#  72,
#  15,
#  28,
#  73,
#  33,
#  66,
#  9,
#  33,
#  50,
#  3,
#  54,
#  51,
#  0,
#  76,
#  50,
#  9,
#  63,
#  40,
#  38,
#  65,
#  54,
#  8,
#  63,
#  63,
#  33,
#  28,
#  40,
#  42,
#  10,
#  56,
#  47,
#  28,
#  5,
#  33,
#  85,
#  63,
#  2,
#  10,
#  37,
#  32,
#  59,
#  1,
#  19,
#  55,
#  71,
#  8,
#  76,
#  48,
#  52,
#  58,
#  30,
#  24,
#  79,
#  19,
#  41,
#  33,
#  84,
#  15,
#  72,
#  56,
#  72,
#  82,
#  72,
#  50,
#  33,
#  52,
#  4,
#  33,
#  3,
#  54,
#  51,
#  33,
#  42,
#  21,
#  52,
#  17,
#  79,
#  33,
#  24,
#  48,
#  49,
#  63,
#  21,
#  3,
#  50,
#  48,
#  13,
#  45,
#  9,
#  44,
#  72,
#  17,
#  65,
#  84,
#  3,
#  52,
#  13,
#  55,
#  34,
#  10,
#  51,
#  3,
#  15,
#  25,
#  82,
#  45,
#  47,
#  74,
#  23,
#  75,
#  83,
#  34,
#  59,
#  48,
#  55,
#  0,
#  13,
#  72,
#  36,
#  55,
#  75,
#  9,
#  40,
#  68,
#  68,
#  57,
#  9,
#  85,
#  21,
#  67,
#  68,
#  84,
#  31,
#  72,
#  85,
#  55,
#  52,
#  87,
#  31,
#  66,
#  43,
#  64,
#  76,
#  52,
#  0,
#  39,
#  86,
#  9,
#  17,
#  17,
#  25,
#  68,
#  76,
#  55,
#  2,
#  61,
#  55,
#  54,
#  35,
#  9,
#  45,
#  55,
#  9,
#  15,
#  9,
#  31,
#  72,
#  19,
#  26,
#  9,
#  14,
#  84,
#  63,
#  16,
#  57,
#  21,
#  50,
#  34,
#  0,
#  55,
#  56,
#  61,
#  70,
#  36,
#  2,
#  65,
#  15,
#  65,
#  78,
#  55,
#  14,
#  72,
#  16,
#  84,
#  31,
#  72,
#  85,
#  5,
#  33,
#  45,
#  55,
#  20,
#  72,
#  67,
#  8,
#  84,
#  9,
#  21,
#  39,
#  52,
#  51,
#  47,
#  21,
#  60,
#  77,
#  40,
#  40,
#  33,
#  25,
#  15,
#  16,
#  72,
#  63,
#  57,
#  48,
#  40,
#  44,
#  72,
#  84,
#  40,
#  12,
#  37,
#  55,
#  54,
#  55,
#  12,
#  21,
#  71,
#  40,
#  55,
#  52,
#  14,
#  85,
#  38,
#  13,
#  58,
#  46,
#  62,
#  52,
#  87,
#  18,
#  39,
#  60,
#  44,
#  60,
#  65,
#  73,
#  33,
#  55,
#  66,
#  84,
#  44,
#  39,
#  4,
#  68,
#  9,
#  68,
#  63,
#  5,
#  18,
#  42,
#  16,
#  52,
#  65,
#  37,
#  19,
#  40,
#  24,
#  38,
#  58,
#  56,
#  2,
#  40,
#  39,
#  17,
#  87,
#  34,
#  17,
#  46,
#  63,
#  30,
#  56,
#  24,
#  15,
#  69,
#  15,
#  77,
#  84,
#  58,
#  50,
#  33,
#  33,
#  6,
#  58,
#  35,
#  9,
#  33,
#  21,
#  19,
#  0,
#  9,
#  33,
#  61,
#  53,
#  40,
#  57,
#  55,
#  40,
#  21,
#  59,
#  72,
#  54,
#  18,
#  28,
#  45,
#  55,
#  55,
#  47,
#  58,
#  15,
#  11,
#  9,
#  3,
#  82,
#  3,
#  38,
#  55,
#  ...]

# %%
train_y = pd.read_csv("./open/train_df_add_data.csv")

train_labels = train_y["label"]

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}

# %%
label_decoder = {val:key for key, val in label_unique.items()}

f_result = [label_decoder[result] for result in f_pred]

# %%
f_result
# Out:
# ['tile-glue_strip',
#  'grid-good',
#  'transistor-good',
#  'tile-gray_stroke',
#  'tile-good',
#  'pill-crack',
#  'capsule-faulty_imprint',
#  'hazelnut-cut',
#  'leather-good',
#  'leather-glue',
#  'bottle-broken_large',
#  'wood-good',
#  'zipper-rough',
#  'screw-thread_side',
#  'tile-glue_strip',
#  'bottle-contamination',
#  'grid-bent',
#  'carpet-hole',
#  'carpet-good',
#  'pill-color',
#  'tile-rough',
#  'zipper-good',
#  'bottle-broken_large',
#  'screw-scratch_neck',
#  'pill-faulty_imprint',
#  'screw-good',
#  'pill-faulty_imprint',
#  'screw-thread_top',
#  'leather-good',
#  'wood-liquid',
#  'screw-good',
#  'cable-good',
#  'screw-thread_side',
#  'zipper-fabric_interior',
#  'zipper-good',
#  'zipper-fabric_border',
#  'leather-good',
#  'cable-good',
#  'leather-cut',
#  'metal_nut-flip',
#  'metal_nut-good',
#  'cable-missing_cable',
#  'screw-thread_top',
#  'capsule-faulty_imprint',
#  'metal_nut-flip',
#  'tile-good',
#  'toothbrush-good',
#  'capsule-crack',
#  'zipper-good',
#  'screw-good',
#  'cable-good',
#  'transistor-good',
#  'hazelnut-crack',
#  'hazelnut-print',
#  'zipper-good',
#  'metal_nut-scratch',
#  'carpet-cut',
#  'carpet-good',
#  'leather-fold',
#  'capsule-good',
#  'transistor-good',
#  'pill-combined',
#  'capsule-squeeze',
#  'zipper-broken_teeth',
#  'capsule-crack',
#  'leather-color',
#  'transistor-good',
#  'capsule-crack',
#  'pill-pill_type',
#  'metal_nut-color',
#  'grid-bent',
#  'wood-good',
#  'hazelnut-cut',
#  'tile-crack',
#  'leather-poke',
#  'zipper-good',
#  'cable-good',
#  'leather-good',
#  'cable-good',
#  'cable-good',
#  'pill-crack',
#  'wood-good',
#  'screw-scratch_head',
#  'wood-combined',
#  'transistor-good',
#  'bottle-broken_small',
#  'zipper-good',
#  'carpet-good',
#  'leather-good',
#  'zipper-fabric_interior',
#  'leather-color',
#  'zipper-good',
#  'cable-good',
#  'metal_nut-bent',
#  'screw-good',
#  'tile-oil',
#  'transistor-good',
#  'transistor-good',
#  'metal_nut-good',
#  'metal_nut-good',
#  'cable-good',
#  'carpet-good',
#  'pill-good',
#  'capsule-scratch',
#  'wood-good',
#  'bottle-contamination',
#  'zipper-rough',
#  'pill-contamination',
#  'transistor-good',
#  'hazelnut-hole',
#  'leather-color',
#  'screw-scratch_neck',
#  'transistor-bent_lead',
#  'transistor-good',
#  'zipper-good',
#  'capsule-good',
#  'grid-good',
#  'pill-good',
#  'capsule-good',
#  'leather-poke',
#  'screw-good',
#  'carpet-color',
#  'metal_nut-good',
#  'transistor-good',
#  'wood-hole',
#  'transistor-cut_lead',
#  'tile-crack',
#  'transistor-good',
#  'pill-scratch',
#  'screw-good',
#  'grid-good',
#  'metal_nut-scratch',
#  'pill-crack',
#  'metal_nut-bent',
#  'capsule-good',
#  'grid-bent',
#  'screw-scratch_head',
#  'bottle-contamination',
#  'pill-good',
#  'wood-liquid',
#  'transistor-good',
#  'hazelnut-good',
#  'cable-cut_inner_insulation',
#  'cable-good',
#  'zipper-good',
#  'hazelnut-print',
#  'carpet-metal_contamination',
#  'zipper-good',
#  'zipper-rough',
#  'wood-good',
#  'zipper-good',
#  'wood-scratch',
#  'transistor-good',
#  'pill-good',
#  'zipper-fabric_interior',
#  'tile-good',
#  'toothbrush-defective',
#  'tile-good',
#  'hazelnut-good',
#  'metal_nut-good',
#  'screw-scratch_head',
#  'screw-thread_top',
#  'screw-scratch_head',
#  'cable-missing_wire',
#  'carpet-good',
#  'leather-fold',
#  'pill-contamination',
#  'wood-color',
#  'zipper-fabric_interior',
#  'cable-missing_cable',
#  'carpet-good',
#  'carpet-thread',
#  'screw-manipulated_front',
#  'leather-glue',
#  'cable-good',
#  'pill-good',
#  'screw-good',
#  'zipper-split_teeth',
#  'capsule-good',
#  'zipper-good',
#  'leather-good',
#  'grid-glue',
#  'bottle-good',
#  'cable-missing_wire',
#  'pill-faulty_imprint',
#  'carpet-cut',
#  'tile-glue_strip',
#  'metal_nut-good',
#  'wood-scratch',
#  'transistor-misplaced',
#  'pill-scratch',
#  'capsule-squeeze',
#  'zipper-good',
#  'hazelnut-cut',
#  'pill-good',
#  'screw-scratch_head',
#  'zipper-combined',
#  'zipper-rough',
#  'zipper-good',
#  'hazelnut-good',
#  'transistor-good',
#  'cable-poke_insulation',
#  'screw-scratch_neck',
#  'bottle-broken_small',
#  'pill-good',
#  'leather-good',
#  'pill-color',
#  'pill-good',
#  'hazelnut-good',
#  'grid-bent',
#  'leather-poke',
#  'capsule-good',
#  'screw-good',
#  'wood-good',
#  'pill-combined',
#  'carpet-hole',
#  'capsule-squeeze',
#  'pill-contamination',
#  'transistor-good',
#  'bottle-broken_small',
#  'tile-oil',
#  'grid-good',
#  'tile-good',
#  'bottle-broken_small',
#  'capsule-good',
#  'metal_nut-color',
#  'pill-faulty_imprint',
#  'leather-color',
#  'cable-good',
#  'transistor-good',
#  'pill-good',
#  'screw-good',
#  'zipper-combined',
#  'pill-contamination',
#  'zipper-broken_teeth',
#  'capsule-scratch',
#  'transistor-good',
#  'metal_nut-good',
#  'hazelnut-crack',
#  'capsule-faulty_imprint',
#  'metal_nut-good',
#  'hazelnut-hole',
#  'zipper-rough',
#  'screw-thread_side',
#  'wood-color',
#  'leather-poke',
#  'tile-good',
#  'tile-gray_stroke',
#  'wood-scratch',
#  'cable-cable_swap',
#  'transistor-good',
#  'tile-gray_stroke',
#  'cable-bent_wire',
#  'capsule-good',
#  'metal_nut-flip',
#  'metal_nut-good',
#  'metal_nut-good',
#  'capsule-crack',
#  'zipper-broken_teeth',
#  'hazelnut-good',
#  'hazelnut-crack',
#  'screw-good',
#  'hazelnut-good',
#  'hazelnut-cut',
#  'leather-poke',
#  'leather-good',
#  'wood-good',
#  'screw-good',
#  'metal_nut-flip',
#  'cable-good',
#  'carpet-good',
#  'screw-good',
#  'wood-hole',
#  'transistor-bent_lead',
#  'cable-good',
#  'capsule-good',
#  'pill-color',
#  'capsule-good',
#  'transistor-good',
#  'zipper-squeezed_teeth',
#  'pill-combined',
#  'leather-color',
#  'transistor-good',
#  'pill-pill_type',
#  'pill-good',
#  'screw-good',
#  'grid-thread',
#  'tile-good',
#  'tile-good',
#  'bottle-broken_large',
#  'carpet-hole',
#  'bottle-broken_small',
#  'leather-fold',
#  'leather-cut',
#  'cable-good',
#  'zipper-squeezed_teeth',
#  'tile-good',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'screw-scratch_neck',
#  'leather-poke',
#  'zipper-broken_teeth',
#  'transistor-good',
#  'screw-scratch_head',
#  'pill-faulty_imprint',
#  'toothbrush-good',
#  'grid-good',
#  'leather-color',
#  'screw-scratch_head',
#  'screw-good',
#  'transistor-good',
#  'bottle-good',
#  'metal_nut-scratch',
#  'wood-good',
#  'transistor-good',
#  'screw-thread_side',
#  'wood-good',
#  'wood-good',
#  'tile-good',
#  'cable-good',
#  'screw-scratch_neck',
#  'metal_nut-scratch',
#  'cable-cut_inner_insulation',
#  'leather-good',
#  'capsule-good',
#  'screw-good',
#  'screw-manipulated_front',
#  'pill-crack',
#  'transistor-good',
#  'screw-scratch_neck',
#  'capsule-good',
#  'screw-good',
#  'carpet-good',
#  'carpet-color',
#  'bottle-good',
#  'tile-good',
#  'metal_nut-color',
#  'screw-scratch_neck',
#  'cable-bent_wire',
#  'wood-good',
#  'screw-good',
#  'metal_nut-bent',
#  'tile-good',
#  'screw-good',
#  'leather-glue',
#  'metal_nut-flip',
#  'metal_nut-bent',
#  'hazelnut-good',
#  'pill-pill_type',
#  'carpet-thread',
#  'cable-cable_swap',
#  'cable-good',
#  'capsule-scratch',
#  'carpet-good',
#  'capsule-poke',
#  'cable-good',
#  'pill-good',
#  'bottle-contamination',
#  'toothbrush-defective',
#  'transistor-cut_lead',
#  'capsule-crack',
#  'leather-fold',
#  'carpet-color',
#  'transistor-good',
#  'zipper-rough',
#  'wood-color',
#  'cable-cut_inner_insulation',
#  'cable-good',
#  'leather-cut',
#  'hazelnut-good',
#  'screw-good',
#  'cable-good',
#  'bottle-good',
#  'hazelnut-good',
#  'transistor-good',
#  'wood-hole',
#  'screw-manipulated_front',
#  'capsule-faulty_imprint',
#  'grid-good',
#  'metal_nut-scratch',
#  'screw-good',
#  'wood-color',
#  'tile-glue_strip',
#  'capsule-good',
#  'grid-good',
#  'metal_nut-bent',
#  'capsule-good',
#  'hazelnut-cut',
#  'screw-good',
#  'leather-good',
#  'metal_nut-color',
#  'bottle-broken_small',
#  'leather-poke',
#  'capsule-poke',
#  'transistor-bent_lead',
#  'cable-cable_swap',
#  'bottle-contamination',
#  'hazelnut-print',
#  'tile-good',
#  'wood-liquid',
#  'tile-gray_stroke',
#  'transistor-good',
#  'zipper-fabric_border',
#  'bottle-contamination',
#  'tile-good',
#  'pill-crack',
#  'capsule-scratch',
#  'leather-good',
#  'pill-faulty_imprint',
#  'cable-good',
#  'capsule-poke',
#  'pill-good',
#  'cable-good',
#  'bottle-broken_small',
#  'transistor-good',
#  'leather-good',
#  'transistor-good',
#  'hazelnut-cut',
#  'transistor-bent_lead',
#  'metal_nut-bent',
#  'zipper-good',
#  'metal_nut-bent',
#  'carpet-good',
#  'carpet-color',
#  'pill-crack',
#  'zipper-fabric_border',
#  'zipper-good',
#  'leather-glue',
#  'transistor-damaged_case',
#  'bottle-broken_small',
#  'zipper-good',
#  'cable-good',
#  'bottle-broken_small',
#  'tile-good',
#  'hazelnut-crack',
#  'wood-scratch',
#  'pill-faulty_imprint',
#  'carpet-good',
#  'grid-metal_contamination',
#  'pill-color',
#  'tile-oil',
#  'transistor-good',
#  'screw-manipulated_front',
#  'transistor-good',
#  'transistor-cut_lead',
#  'carpet-good',
#  'zipper-squeezed_teeth',
#  'tile-glue_strip',
#  'leather-fold',
#  'wood-hole',
#  'zipper-good',
#  'bottle-broken_small',
#  'carpet-good',
#  'tile-good',
#  'hazelnut-good',
#  'screw-thread_side',
#  'hazelnut-good',
#  'carpet-hole',
#  'metal_nut-flip',
#  'cable-good',
#  'carpet-good',
#  'screw-thread_top',
#  'leather-poke',
#  'carpet-thread',
#  'capsule-faulty_imprint',
#  'capsule-crack',
#  'metal_nut-flip',
#  'screw-thread_side',
#  'metal_nut-good',
#  'pill-pill_type',
#  'metal_nut-bent',
#  'tile-good',
#  'bottle-good',
#  'screw-manipulated_front',
#  'cable-good',
#  'wood-good',
#  'transistor-good',
#  'screw-thread_top',
#  'screw-thread_top',
#  'pill-combined',
#  'screw-good',
#  'carpet-hole',
#  'cable-good',
#  'screw-good',
#  'screw-good',
#  'cable-good',
#  'grid-good',
#  'hazelnut-hole',
#  'pill-faulty_imprint',
#  'carpet-cut',
#  'cable-combined',
#  'cable-cut_inner_insulation',
#  'screw-good',
#  'hazelnut-good',
#  'capsule-squeeze',
#  'transistor-cut_lead',
#  'toothbrush-defective',
#  'cable-cut_inner_insulation',
#  'zipper-split_teeth',
#  'screw-manipulated_front',
#  'tile-oil',
#  'metal_nut-scratch',
#  'transistor-good',
#  'cable-bent_wire',
#  'tile-good',
#  'leather-fold',
#  'wood-liquid',
#  'toothbrush-good',
#  'leather-poke',
#  'capsule-good',
#  'screw-manipulated_front',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'zipper-good',
#  'cable-good',
#  'metal_nut-scratch',
#  'leather-good',
#  'cable-good',
#  'tile-gray_stroke',
#  'pill-pill_type',
#  'wood-good',
#  'metal_nut-good',
#  'pill-good',
#  'zipper-fabric_border',
#  'cable-good',
#  'wood-good',
#  'capsule-good',
#  'carpet-cut',
#  'capsule-good',
#  'hazelnut-hole',
#  'hazelnut-good',
#  'hazelnut-hole',
#  'grid-good',
#  'screw-good',
#  'zipper-split_teeth',
#  'wood-scratch',
#  'pill-contamination',
#  'toothbrush-defective',
#  'cable-good',
#  'wood-good',
#  'grid-metal_contamination',
#  'screw-good',
#  'grid-good',
#  'zipper-squeezed_teeth',
#  'transistor-good',
#  'tile-good',
#  'hazelnut-good',
#  'pill-scratch',
#  'cable-good',
#  'capsule-crack',
#  'pill-color',
#  'pill-good',
#  'zipper-combined',
#  'tile-glue_strip',
#  'screw-good',
#  'capsule-good',
#  'zipper-squeezed_teeth',
#  'screw-manipulated_front',
#  'leather-glue',
#  'capsule-good',
#  'leather-good',
#  'carpet-metal_contamination',
#  'cable-good',
#  'hazelnut-good',
#  'grid-good',
#  'grid-good',
#  'hazelnut-good',
#  'screw-thread_side',
#  'hazelnut-good',
#  'wood-scratch',
#  'hazelnut-good',
#  'pill-good',
#  'cable-missing_wire',
#  'wood-hole',
#  'zipper-split_teeth',
#  'carpet-good',
#  'grid-glue',
#  'zipper-fabric_border',
#  'pill-contamination',
#  'metal_nut-bent',
#  'tile-good',
#  'carpet-hole',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'carpet-good',
#  'leather-good',
#  'transistor-good',
#  'screw-good',
#  'hazelnut-cut',
#  'cable-good',
#  'zipper-squeezed_teeth',
#  'zipper-good',
#  'metal_nut-bent',
#  'carpet-metal_contamination',
#  'tile-good',
#  'zipper-split_teeth',
#  'hazelnut-good',
#  'leather-good',
#  'hazelnut-good',
#  'hazelnut-hole',
#  'cable-cut_inner_insulation',
#  'pill-crack',
#  'cable-good',
#  'pill-good',
#  'cable-good',
#  'transistor-cut_lead',
#  'pill-faulty_imprint',
#  'metal_nut-bent',
#  'grid-glue',
#  'cable-good',
#  'carpet-thread',
#  'hazelnut-good',
#  'capsule-poke',
#  'pill-good',
#  'zipper-split_teeth',
#  'carpet-thread',
#  'cable-bent_wire',
#  'cable-good',
#  'cable-cut_outer_insulation',
#  'zipper-squeezed_teeth',
#  'tile-glue_strip',
#  'bottle-broken_large',
#  'carpet-hole',
#  'metal_nut-bent',
#  'toothbrush-good',
#  'hazelnut-good',
#  'bottle-broken_small',
#  'leather-good',
#  'toothbrush-defective',
#  'screw-good',
#  'screw-scratch_neck',
#  'zipper-broken_teeth',
#  'leather-good',
#  'cable-missing_wire',
#  'capsule-good',
#  'carpet-metal_contamination',
#  'leather-poke',
#  'pill-good',
#  'leather-fold',
#  'transistor-good',
#  'bottle-broken_large',
#  'carpet-good',
#  'zipper-fabric_interior',
#  'cable-good',
#  'leather-cut',
#  'capsule-good',
#  'zipper-split_teeth',
#  'wood-combined',
#  'hazelnut-print',
#  'carpet-good',
#  'screw-manipulated_front',
#  'grid-metal_contamination',
#  'wood-scratch',
#  'screw-scratch_neck',
#  'capsule-crack',
#  'capsule-squeeze',
#  'leather-good',
#  'transistor-good',
#  'cable-cut_outer_insulation',
#  'carpet-good',
#  'transistor-good',
#  'capsule-good',
#  'grid-good',
#  'transistor-misplaced',
#  'hazelnut-good',
#  'tile-rough',
#  'cable-good',
#  'hazelnut-good',
#  'pill-crack',
#  'bottle-good',
#  'pill-scratch',
#  'pill-faulty_imprint',
#  'bottle-broken_large',
#  'wood-good',
#  'pill-crack',
#  'cable-good',
#  'tile-good',
#  'leather-good',
#  'leather-fold',
#  'tile-oil',
#  'pill-scratch',
#  'cable-cut_outer_insulation',
#  'tile-good',
#  'tile-good',
#  'hazelnut-good',
#  'grid-good',
#  'leather-good',
#  'metal_nut-bent',
#  'cable-missing_cable',
#  'screw-manipulated_front',
#  'pill-color',
#  'grid-good',
#  'cable-cable_swap',
#  'hazelnut-good',
#  'zipper-rough',
#  'tile-good',
#  'bottle-contamination',
#  'cable-missing_cable',
#  'leather-cut',
#  'hazelnut-cut',
#  'screw-thread_side',
#  'bottle-broken_small',
#  'carpet-color',
#  'screw-good',
#  'transistor-damaged_case',
#  'cable-cut_outer_insulation',
#  'wood-good',
#  'pill-combined',
#  'pill-good',
#  'screw-scratch_neck',
#  'grid-thread',
#  'carpet-thread',
#  'wood-scratch',
#  'carpet-color',
#  'leather-poke',
#  'hazelnut-good',
#  'zipper-good',
#  'capsule-good',
#  'transistor-good',
#  'screw-manipulated_front',
#  'transistor-good',
#  'zipper-fabric_border',
#  'transistor-good',
#  'pill-crack',
#  'hazelnut-good',
#  'pill-good',
#  'cable-bent_wire',
#  'hazelnut-good',
#  'bottle-good',
#  'pill-scratch',
#  'pill-faulty_imprint',
#  'hazelnut-good',
#  'metal_nut-bent',
#  'carpet-good',
#  'pill-good',
#  'capsule-scratch',
#  'wood-scratch',
#  'hazelnut-good',
#  'carpet-thread',
#  'pill-combined',
#  'pill-contamination',
#  'tile-good',
#  'carpet-good',
#  'bottle-good',
#  'pill-crack',
#  'pill-combined',
#  'capsule-crack',
#  'metal_nut-good',
#  'cable-good',
#  'metal_nut-flip',
#  'transistor-good',
#  'capsule-scratch',
#  'tile-oil',
#  'zipper-good',
#  'bottle-good',
#  'pill-good',
#  'capsule-crack',
#  'screw-good',
#  'hazelnut-hole',
#  'cable-missing_cable',
#  'pill-faulty_imprint',
#  'bottle-good',
#  'capsule-good',
#  'grid-bent',
#  'zipper-fabric_border',
#  'metal_nut-good',
#  'pill-color',
#  'wood-color',
#  'carpet-metal_contamination',
#  'wood-combined',
#  'zipper-fabric_interior',
#  'hazelnut-hole',
#  'screw-thread_side',
#  'pill-combined',
#  'screw-good',
#  'bottle-broken_large',
#  'capsule-crack',
#  'transistor-good',
#  'leather-color',
#  'screw-good',
#  'wood-combined',
#  'cable-good',
#  'leather-good',
#  'toothbrush-good',
#  'toothbrush-good',
#  'screw-scratch_head',
#  'cable-good',
#  'zipper-rough',
#  'carpet-good',
#  'toothbrush-defective',
#  'toothbrush-good',
#  'zipper-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'zipper-rough',
#  'screw-good',
#  'pill-good',
#  'zipper-squeezed_teeth',
#  'hazelnut-crack',
#  'tile-rough',
#  'metal_nut-color',
#  'tile-gray_stroke',
#  'wood-good',
#  'pill-good',
#  'bottle-broken_large',
#  'leather-glue',
#  'zipper-split_teeth',
#  'cable-good',
#  'capsule-scratch',
#  'capsule-scratch',
#  'grid-bent',
#  'toothbrush-good',
#  'wood-good',
#  'screw-good',
#  'bottle-contamination',
#  'tile-crack',
#  'screw-good',
#  'pill-scratch',
#  'hazelnut-print',
#  'cable-good',
#  'metal_nut-good',
#  'screw-good',
#  'cable-good',
#  'capsule-good',
#  'cable-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'carpet-color',
#  'grid-broken',
#  'cable-good',
#  'capsule-faulty_imprint',
#  'zipper-good',
#  'tile-good',
#  'capsule-poke',
#  'screw-scratch_head',
#  'carpet-good',
#  'pill-crack',
#  'hazelnut-hole',
#  'bottle-broken_large',
#  'screw-good',
#  'screw-manipulated_front',
#  'tile-crack',
#  'transistor-cut_lead',
#  'leather-color',
#  'bottle-contamination',
#  'tile-oil',
#  'capsule-good',
#  'tile-oil',
#  'wood-liquid',
#  'screw-good',
#  'capsule-faulty_imprint',
#  'transistor-good',
#  'capsule-poke',
#  'zipper-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'zipper-rough',
#  'cable-cable_swap',
#  'hazelnut-good',
#  'metal_nut-good',
#  'screw-good',
#  'carpet-cut',
#  'transistor-good',
#  'toothbrush-defective',
#  'cable-cut_outer_insulation',
#  'zipper-good',
#  'cable-good',
#  'carpet-good',
#  'leather-glue',
#  'pill-good',
#  'pill-faulty_imprint',
#  'pill-color',
#  'carpet-good',
#  'screw-thread_top',
#  'wood-hole',
#  'leather-good',
#  'leather-good',
#  'hazelnut-good',
#  'grid-bent',
#  'capsule-good',
#  'capsule-poke',
#  'transistor-good',
#  'tile-good',
#  'screw-scratch_head',
#  'pill-combined',
#  'leather-good',
#  'metal_nut-flip',
#  'transistor-good',
#  'zipper-good',
#  'leather-good',
#  'cable-poke_insulation',
#  'leather-cut',
#  'screw-good',
#  'pill-scratch',
#  'screw-good',
#  'cable-poke_insulation',
#  'carpet-good',
#  'transistor-damaged_case',
#  'leather-good',
#  'screw-good',
#  'pill-good',
#  'capsule-faulty_imprint',
#  'zipper-rough',
#  'leather-fold',
#  'capsule-crack',
#  'screw-scratch_neck',
#  'metal_nut-scratch',
#  'tile-glue_strip',
#  'pill-good',
#  'zipper-squeezed_teeth',
#  'capsule-squeeze',
#  'leather-glue',
#  'screw-thread_top',
#  'metal_nut-flip',
#  'screw-thread_top',
#  'tile-oil',
#  'transistor-misplaced',
#  'hazelnut-good',
#  'screw-good',
#  'tile-rough',
#  'zipper-good',
#  'metal_nut-flip',
#  'leather-glue',
#  'cable-bent_wire',
#  'toothbrush-good',
#  'cable-good',
#  'toothbrush-good',
#  'tile-good',
#  'cable-cable_swap',
#  'capsule-squeeze',
#  'metal_nut-bent',
#  'capsule-poke',
#  'pill-good',
#  'tile-oil',
#  'leather-cut',
#  'carpet-color',
#  'leather-good',
#  'carpet-thread',
#  'leather-fold',
#  'screw-scratch_neck',
#  'screw-manipulated_front',
#  'bottle-contamination',
#  'leather-good',
#  'leather-glue',
#  'capsule-scratch',
#  'zipper-squeezed_teeth',
#  'hazelnut-hole',
#  'capsule-scratch',
#  'metal_nut-scratch',
#  'tile-good',
#  'grid-thread',
#  'screw-manipulated_front',
#  'carpet-thread',
#  'capsule-good',
#  'transistor-bent_lead',
#  'capsule-good',
#  'wood-hole',
#  'zipper-good',
#  'screw-scratch_neck',
#  'pill-crack',
#  'hazelnut-good',
#  'hazelnut-good',
#  'cable-combined',
#  'screw-scratch_neck',
#  'hazelnut-print',
#  'cable-good',
#  'hazelnut-good',
#  'carpet-good',
#  'carpet-color',
#  'bottle-broken_large',
#  'cable-good',
#  'hazelnut-good',
#  'tile-crack',
#  'pill-pill_type',
#  'leather-good',
#  'screw-scratch_head',
#  'screw-good',
#  'leather-good',
#  'carpet-good',
#  'screw-thread_side',
#  'transistor-good',
#  'pill-scratch',
#  'capsule-squeeze',
#  'grid-good',
#  'metal_nut-good',
#  'screw-good',
#  'screw-good',
#  'pill-color',
#  'screw-scratch_neck',
#  'capsule-good',
#  'cable-missing_wire',
#  'cable-good',
#  'bottle-good',
#  'zipper-fabric_border',
#  'bottle-good',
#  'leather-fold',
#  'screw-good',
#  ...]

# %%
submission = pd.read_csv("./open/sample_submission.csv")

submission["label"] = f_result

submission
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1         grid-good
# 2         2   transistor-good
# 3         3  tile-gray_stroke
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]

# %%
submission.to_csv("./submission/label_result_add_0505_label_cait_s36_384.csv", index = False)
