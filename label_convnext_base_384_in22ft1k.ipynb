# %%
import os
import cv2
import time
import random
import logging
import easydict
import numpy as np
import pandas as pd
from tqdm import tqdm
from os.path import join as opj
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from PIL import Image
from natsort import natsorted

import timm
import torch
import torch.nn as nn
import torch_optimizer as optim
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, grad_scaler
from torchvision import transforms
from torch import Tensor
from torchvision.transforms import functional as F
import torch.cuda.amp as amp
from adamp import AdamP, SGDP

import warnings
warnings.filterwarnings('ignore')

# %%
DATA_DIR = './open'

train_df = pd.read_csv(os.path.join(DATA_DIR, 'train_df_add_data.csv'))
test_df = pd.read_csv(os.path.join(DATA_DIR, 'test_df.csv'))

print(train_df.head())
print(test_df.head())
print(train_df.shape)
print(test_df.shape)
# Out:
#    Unnamed: 0  file_name       class state            label  encoder_label
# 0           0  10000.png  transistor  good  transistor-good             72
# 1           1  10001.png     capsule  good     capsule-good             15
# 2           2  10002.png  transistor  good  transistor-good             72
# 3           3  10003.png        wood  good        wood-good             76
# 4           4  10004.png      bottle  good      bottle-good              3
#    index  file_name
# 0      0  20000.png
# 1      1  20001.png
# 2      2  20002.png
# 3      3  20003.png
# 4      4  20004.png
# (13997, 6)
# (2154, 2)

# %%
train_df['label'].value_counts()
# Out:
# hazelnut-good              391
# screw-good                 320
# carpet-good                280
# pill-good                  267
# grid-good                  264
#                           ...
# cable-missing_wire          80
# wood-liquid                 80
# transistor-damaged_case     80
# wood-color                  64
# toothbrush-good             60
# Name: label, Length: 88, dtype: int64

# %%
train_df['label'].unique()
# Out:
# array(['transistor-good', 'capsule-good', 'wood-good', 'bottle-good',
#        'screw-good', 'cable-bent_wire', 'carpet-hole', 'hazelnut-good',
#        'pill-pill_type', 'cable-good', 'metal_nut-scratch', 'pill-good',
#        'screw-thread_side', 'zipper-fabric_border', 'leather-good',
#        'pill-scratch', 'toothbrush-good', 'hazelnut-crack',
#        'screw-manipulated_front', 'zipper-good', 'tile-good',
#        'carpet-good', 'metal_nut-good', 'bottle-contamination',
#        'grid-good', 'zipper-split_teeth', 'pill-crack', 'wood-combined',
#        'pill-color', 'screw-thread_top', 'cable-missing_cable',
#        'capsule-squeeze', 'zipper-rough', 'capsule-crack', 'capsule-poke',
#        'metal_nut-flip', 'carpet-metal_contamination', 'metal_nut-color',
#        'transistor-bent_lead', 'zipper-fabric_interior', 'leather-fold',
#        'tile-glue_strip', 'screw-scratch_neck', 'screw-scratch_head',
#        'hazelnut-cut', 'bottle-broken_large', 'bottle-broken_small',
#        'leather-cut', 'cable-cut_outer_insulation',
#        'zipper-squeezed_teeth', 'toothbrush-defective',
#        'cable-cut_inner_insulation', 'pill-contamination',
#        'cable-missing_wire', 'carpet-thread', 'grid-broken',
#        'pill-faulty_imprint', 'hazelnut-hole', 'leather-glue',
#        'leather-poke', 'transistor-damaged_case', 'wood-scratch',
#        'tile-gray_stroke', 'capsule-faulty_imprint', 'grid-glue',
#        'zipper-combined', 'carpet-color', 'grid-bent', 'pill-combined',
#        'hazelnut-print', 'cable-combined', 'capsule-scratch',
#        'metal_nut-bent', 'zipper-broken_teeth', 'tile-oil',
#        'transistor-misplaced', 'grid-thread', 'grid-metal_contamination',
#        'carpet-cut', 'wood-color', 'cable-cable_swap', 'tile-crack',
#        'leather-color', 'cable-poke_insulation', 'transistor-cut_lead',
#        'wood-hole', 'tile-rough', 'wood-liquid'], dtype=object)

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  # Arrange GPU devices starting from 0
os.environ["CUDA_VISIBLE_DEVICES"]= "2,3"  # Set the GPUs 2 and 3 to use

# %%
class_num = len(train_df.encoder_label.unique())

# %%
args = easydict.EasyDict(
    {'exp_num':'0',
     
     # Path settings
     'data_path':'./open',
     'Kfold':5,
     'model_path':'label_results_convnext_base_384_in22ft1k/',
     'image_type':'train_1024', 
     'class_num' : class_num,

     # Model parameter settings
     'model_name':'convnext_base_384_in22ft1k',
     'drop_path_rate':0.2,
     
     # Training parameter settings
     ## Base Parameter
     'img_size':384,
     'batch_size':16,
     'epochs':100,
     'optimizer':'Lamb',
     'initial_lr':5e-4,
     'weight_decay':1e-3,

     ## Augmentation
     'aug_ver':2,

     ## Scheduler (OnecycleLR)
     'scheduler':'Reduce',
     'warm_epoch':3,
     'max_lr':1e-3,

     ### Cosine Annealing
     'min_lr':5e-5,
     'tmax':145,

     ## etc.
     'patience': 5,
     'clipping':None,

     # Hardware settings
     'amp':True,
     'multi_gpu':True,
     'logging':False,
     'num_workers':4,
     'seed':42
     
     
    })

# %%
# Warmup Learning rate scheduler
from torch.optim.lr_scheduler import _LRScheduler
class WarmUpLR(_LRScheduler):
    """warmup_training learning rate scheduler
    Args:
        optimizer: optimzier(e.g. SGD)
        total_iters: totoal_iters of warmup phase
    """
    def __init__(self, optimizer, total_iters, last_epoch=-1):
        
        self.total_iters = total_iters
        super().__init__(optimizer, last_epoch)

    def get_lr(self):
        """we will use the first m batches, and set the learning
        rate to base_lr * m / total_iters
        """
        return [base_lr * self.last_epoch / (self.total_iters + 1e-8) for base_lr in self.base_lrs]

# Logging
def get_root_logger(logger_name='basicsr',
                    log_level=logging.INFO,
                    log_file=None):

    logger = logging.getLogger(logger_name)
    # if the logger has been initialized, just return it
    if logger.hasHandlers():
        return logger

    format_str = '%(asctime)s %(levelname)s: %(message)s'
    logging.basicConfig(format=format_str, level=log_level)

    if log_file is not None:
        file_handler = logging.FileHandler(log_file, 'w')
        file_handler.setFormatter(logging.Formatter(format_str))
        file_handler.setLevel(log_level)
        logger.addHandler(file_handler)

    return logger

class AvgMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0
        self.losses = []

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        self.losses.append(val)

# %%
class RandomRotation(transforms.RandomRotation):
    def __init__(self, p: float, degrees: int):
        super(RandomRotation, self).__init__(degrees)
        self.p = p

    def forward(self, img):
        if torch.rand(1) < self.p:
            fill = self.fill
            if isinstance(img, Tensor):
                if isinstance(fill, (int, float)):
                    fill = [float(fill)] * F.get_image_num_channels(img)
                else:
                    fill = [float(f) for f in fill]
            angle = self.get_params(self.degrees)

            img = F.rotate(img, angle, self.resample, self.expand, self.center, fill)
        return img

# %%
class Train_Dataset(Dataset):
    def __init__(self, df, transform=None):
        self.img_path = df['file_name'].values
        self.target = df['encoder_label'].values 
        self.transform = transform

        print(f'Dataset size:{len(self.img_path)}')

    def __getitem__(self, idx):
        
        image = Image.open(opj('./open/train_add_data/', self.img_path[idx])).convert('RGB')
        image = self.transform(image)
        target = self.target[idx]

        return image, target

    def __len__(self):
        return len(self.img_path)

class Test_dataset(Dataset):
    def __init__(self, df, transform=None):
        self.img_path = df['file_name'].values
        self.transform = transform

        print(f'Test Dataset size:{len(self.img_path)}')

    def __getitem__(self, idx):

        image = Image.open(opj('./open/test/', self.img_path[idx])).convert('RGB')
        image = self.transform(image)

        return image

    def __len__(self):
        return len(self.img_path)

def get_loader(df, phase: str, batch_size, shuffle,
               num_workers, transform):
    if phase == 'test':
        dataset = Test_dataset(df, transform)
        data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory=True)
    else:
        dataset = Train_Dataset(df, transform)
        data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, 
                                 pin_memory=True,
                                 drop_last=False)
    return data_loader

def get_train_augmentation(img_size, ver):
    if ver==1: # for validset
        transform = transforms.Compose([
                transforms.Resize((img_size, img_size)),
                transforms.ToTensor(),
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])

    if ver == 2:

        transform = transforms.Compose([
                transforms.RandomHorizontalFlip(),
                transforms.RandomVerticalFlip(),
                transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
                transforms.RandomAffine((-20,20)),
                RandomRotation(0.5, degrees=5),
                transforms.Resize((img_size, img_size)),
                transforms.ToTensor(), 
                transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225]),
            ])
    
    
    return transform

# %%
class Network(nn.Module):
    def __init__(self, args):
        super().__init__()
        self.model_ft = timm.create_model( # timm ImageNet pre-trained 모델 load
            args.model_name,
            pretrained=True,
            num_classes = 88, drop_path_rate=args.drop_path_rate
        )

#         self.model_ft = coatnet_3()
#         num_ftrs = self.model_ft.fc.in_features
#         self.model_ft.fc = nn.Linear(num_ftrs, args.class_num)
        
    def forward(self, x):
        out = self.model_ft(x)
        return out

class Network_test(nn.Module):
    def __init__(self, encoder_name):
        super().__init__()
        self.model_ft = timm.create_model( # timm ImageNet pre-trained 모델 load
            encoder_name,
            pretrained=True,
            num_classes = 88, drop_path_rate=args.drop_path_rate
        )

#         self.model_ft = coatnet_3()
#         num_ftrs = self.model_ft.fc.in_features
#         self.model_ft.fc = nn.Linear(num_ftrs, args.class_num)

    def forward(self, x):
        out = self.model_ft(x)
        return out

# %%
# # weighted crossentropy loss를 위한 weight 계산 함수

class_num = train_df.groupby(["encoder_label"])["encoder_label"].count().tolist()
class_weight = torch.tensor(np.max(class_num) / class_num).to("cuda", dtype=torch.float)
print(f"class_weight: {class_weight}")
# Out:
# class_weight: tensor([2.4437, 2.2216, 2.2216, 1.8708, 3.4911, 4.0729, 4.0729, 3.4911, 4.8875,
#         1.7455, 4.0729, 4.8875, 4.8875, 2.0365, 2.2216, 1.7854, 2.2216, 2.0365,
#         2.4437, 2.4437, 2.7153, 1.3964, 2.7153, 2.7153, 2.4437, 4.0729, 4.0729,
#         4.0729, 1.4811, 4.0729, 4.0729, 2.7153, 2.7153, 1.0000, 2.7153, 2.7153,
#         2.4437, 2.4437, 2.7153, 2.4437, 1.5959, 2.7153, 1.8798, 2.2216, 2.0365,
#         1.7773, 2.0365, 1.8798, 2.7153, 2.2216, 1.8798, 2.4437, 1.4644, 4.8875,
#         2.0365, 1.2219, 2.0365, 2.0365, 1.8798, 2.0365, 2.0365, 2.7153, 2.7153,
#         1.7000, 3.0547, 2.7153, 3.0547, 1.6292, 6.5167, 4.8875, 4.8875, 4.8875,
#         1.8357, 4.8875, 6.1094, 4.0729, 1.5830, 4.8875, 4.8875, 2.2216, 2.4437,
#         3.0547, 2.7153, 3.0547, 1.6292, 2.7153, 2.7153, 3.0547],
#        device='cuda:0')

# %%
from collections import defaultdict
from itertools import chain
from torch.optim import Optimizer
import torch
import warnings

class Lookahead(Optimizer):
    def __init__(self, optimizer, k=5, alpha=0.5):
        self.optimizer = optimizer
        self.k = k
        self.alpha = alpha
        self.param_groups = self.optimizer.param_groups
        self.state = defaultdict(dict)
        self.fast_state = self.optimizer.state
        for group in self.param_groups:
            group["counter"] = 0
    
    def update(self, group):
        for fast in group["params"]:
            param_state = self.state[fast]
            if "slow_param" not in param_state:
                param_state["slow_param"] = torch.zeros_like(fast.data)
                param_state["slow_param"].copy_(fast.data)
            slow = param_state["slow_param"]
            slow += (fast.data - slow) * self.alpha
            fast.data.copy_(slow)
    
    def update_lookahead(self):
        for group in self.param_groups:
            self.update(group)

    def step(self, closure=None):
        loss = self.optimizer.step(closure)
        for group in self.param_groups:
            if group["counter"] == 0:
                self.update(group)
            group["counter"] += 1
            if group["counter"] >= self.k:
                group["counter"] = 0
        return loss

    def state_dict(self):
        fast_state_dict = self.optimizer.state_dict()
        slow_state = {
            (id(k) if isinstance(k, torch.Tensor) else k): v
            for k, v in self.state.items()
        }
        fast_state = fast_state_dict["state"]
        param_groups = fast_state_dict["param_groups"]
        return {
            "fast_state": fast_state,
            "slow_state": slow_state,
            "param_groups": param_groups,
        }

    def load_state_dict(self, state_dict):
        slow_state_dict = {
            "state": state_dict["slow_state"],
            "param_groups": state_dict["param_groups"],
        }
        fast_state_dict = {
            "state": state_dict["fast_state"],
            "param_groups": state_dict["param_groups"],
        }
        super(Lookahead, self).load_state_dict(slow_state_dict)
        self.optimizer.load_state_dict(fast_state_dict)
        self.fast_state = self.optimizer.state

    def add_param_group(self, param_group):
        param_group["counter"] = 0
        self.optimizer.add_param_group(param_group)

# %%
class FocalLoss(nn.Module):
    """
    https://dacon.io/competitions/official/235585/codeshare/1796
    """

    def __init__(self, gamma=2.0, eps=1e-7):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        # print(self.gamma)
        self.eps = eps
        self.ce = nn.CrossEntropyLoss(reduction="none")

    def forward(self, input, target):
        logp = self.ce(input, target)
        p = torch.exp(-logp)
        loss = (1 - p) ** self.gamma * logp
        return loss.mean()

# %%
class Trainer():
    def __init__(self, args, save_path):
        '''
        args: arguments
        save_path: Model 가중치 저장 경로
        '''
        super(Trainer, self).__init__()
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Logging
        log_file = os.path.join(save_path, 'log.log')
        self.logger = get_root_logger(logger_name='IR', log_level=logging.INFO, log_file=log_file)
        self.logger.info(args)
        # self.logger.info(args.tag)

        # Train, Valid Set load
        ############################################################################
        if args.step == 0 :
            df_train = pd.read_csv(opj(args.data_path, 'train_df_add_data.csv'))
        else :
            df_train = pd.read_csv(opj(args.data_path, f'train_{args.step}step.csv'))

#         if args.image_type is not None:
#             df_train['img_path'] = df_train['img_path'].apply(lambda x:x.replace('train_imgs', args.image_type))
#             df_train['img_path'] = df_train['img_path'].apply(lambda x:x.replace('test_imgs', 'test_1024'))

        kf = StratifiedKFold(n_splits=args.Kfold, shuffle=True, random_state=args.seed)
        for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(df_train)), y=df_train['encoder_label'])):
            df_train.loc[val_idx, 'fold'] = fold
        val_idx = list(df_train[df_train['fold'] == int(args.fold)].index)

        df_val = df_train[df_train['fold'] == args.fold].reset_index(drop=True)
        df_train = df_train[df_train['fold'] != args.fold].reset_index(drop=True)

        # Augmentation
        self.train_transform = get_train_augmentation(img_size=args.img_size, ver=args.aug_ver)
        self.test_transform = get_train_augmentation(img_size=args.img_size, ver=1)

        # TrainLoader
        self.train_loader = get_loader(df_train, phase='train', batch_size=args.batch_size, shuffle=True,
                                       num_workers=args.num_workers, transform=self.train_transform)
        self.val_loader = get_loader(df_val, phase='train', batch_size=args.batch_size, shuffle=False,
                                       num_workers=args.num_workers, transform=self.test_transform)

        # Network
        self.model = Network(args).to(self.device)

        # Loss
#         self.criterion = nn.CrossEntropyLoss(weight=class_weight)
        self.criterion = FocalLoss()
#         self.criterion = CutMixCrossEntropyLoss(True)
        
        # Optimizer & Scheduler
#         self.optimizer = Lookahead(torch.optim.Adam(self.model.parameters(), lr=args.initial_lr), k=5, alpha=0.5)
        self.optimizer = optim.Lamb(self.model.parameters(), lr=args.initial_lr)
        
        iter_per_epoch = len(self.train_loader)
        self.warmup_scheduler = WarmUpLR(self.optimizer, iter_per_epoch * args.warm_epoch)

        if args.scheduler == 'step':
            self.scheduler = torch.optim.lr_scheduler.MultiStepLR(self.optimizer, milestones=args.milestone, gamma=args.lr_factor, verbose=True)
        elif args.scheduler == 'cos':
            tmax = args.tmax # half-cycle 
            self.scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(self.optimizer, T_max = tmax, eta_min=args.min_lr, verbose=True)
        elif args.scheduler == 'cycle':
            self.scheduler = torch.optim.lr_scheduler.OneCycleLR(self.optimizer, max_lr=args.max_lr, steps_per_epoch=iter_per_epoch, epochs=args.epochs)
        else:
            self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(self.optimizer, patience=3, factor=0.2, mode="max", verbose=True)
            
        if args.multi_gpu:
            self.model = nn.DataParallel(self.model).to(self.device)

        # Train / Validate
        best_loss = np.inf
        best_acc = 0
        best_epoch = 0
        early_stopping = 0
        start = time.time()
        for epoch in range(1, args.epochs+1):
            self.epoch = epoch

            if args.scheduler == 'cos':
                if epoch > args.warm_epoch:
                    self.scheduler.step()

            # Training
            train_loss, train_acc, train_f1 = self.training(args)

            # Model weight in Multi_GPU or Single GPU
            state_dict= self.model.module.state_dict() if args.multi_gpu else self.model.state_dict()

            # Validation
            val_loss, val_acc, val_f1 = self.validate(args, phase='val')

            # Save models
            if val_loss < best_loss:
                early_stopping = 0
                best_epoch = epoch
                best_loss = val_loss
                best_acc = val_acc
                best_f1 = val_f1

                torch.save({'epoch':epoch,
                            'state_dict':state_dict,
                            'optimizer': self.optimizer.state_dict(),
                            'scheduler': self.scheduler.state_dict(),
                    }, os.path.join(save_path, 'best_model.pth'))
                self.logger.info(f'-----------------SAVE:{best_epoch}epoch----------------')
            else:
                early_stopping += 1

            # Early Stopping
            if early_stopping == args.patience:
                break

        self.logger.info(f'\nBest Val Epoch:{best_epoch} | Val Loss:{best_loss:.4f} | Val Acc:{best_acc:.4f} | Val F1:{best_f1:.4f}')
        end = time.time()
        self.logger.info(f'Total Process time:{(end - start) / 60:.3f}Minute')

    # Training
    def training(self, args):
        self.model.train()
        train_loss = AvgMeter()
        train_acc = 0
        preds_list = []
        targets_list = []

        scaler = grad_scaler.GradScaler()
        
        for i, (images, targets) in enumerate(tqdm(self.train_loader)):
            images = torch.tensor(images, device=self.device, dtype=torch.float32)
            targets = torch.tensor(targets, device=self.device, dtype=torch.long)
            
            if self.epoch <= args.warm_epoch:
                self.warmup_scheduler.step()

            self.model.zero_grad(set_to_none=True)
    
            if args.amp:
                with autocast():
                    preds = self.model(images)
                    loss = self.criterion(preds, targets)
                    
                scaler.scale(loss).backward()

                # Gradient Clipping
                if args.clipping is not None:
                    scaler.unscale_(self.optimizer)
                    torch.nn.utils.clip_grad_norm_(self.model.parameters(), args.clipping)

                scaler.step(self.optimizer)
                scaler.update()

            else:
                preds = self.model(images)
                loss = self.criterion(preds, targets)
                loss.backward()
                nn.utils.clip_grad_norm_(self.model.parameters(), args.clipping)
                self.optimizer.step()

            if args.scheduler == 'cycle':
                if self.epoch > args.warm_epoch:
                    self.scheduler.step()

            # Metric
            train_acc += (preds.argmax(dim=1) == targets).sum().item()
            preds_list.extend(preds.argmax(dim=1).cpu().detach().numpy())
            targets_list.extend(targets.cpu().detach().numpy())
            # log
            train_loss.update(loss.item(), n=images.size(0))

        train_acc /= len(self.train_loader.dataset)
        train_f1 = f1_score(np.array(targets_list), np.array(preds_list), average='macro')

        self.logger.info(f'Epoch:[{self.epoch:03d}/{args.epochs:03d}]')
        self.logger.info(f'Train Loss:{train_loss.avg:.3f} | Acc:{train_acc:.4f} | F1:{train_f1:.4f}')
        return train_loss.avg, train_acc, train_f1
            
    # Validation or Dev
    def validate(self, args, phase='val'):
        self.model.eval()
        with torch.no_grad():
            val_loss = AvgMeter()
            val_acc = 0
            preds_list = []
            targets_list = []

            for i, (images, targets) in enumerate(self.val_loader):
                images = torch.tensor(images, device=self.device, dtype=torch.float32)
                targets = torch.tensor(targets, device=self.device, dtype=torch.long)

                preds = self.model(images)
                loss = self.criterion(preds, targets)

                # Metric
                val_acc += (preds.argmax(dim=1) == targets).sum().item()
                preds_list.extend(preds.argmax(dim=1).cpu().detach().numpy())
                targets_list.extend(targets.cpu().detach().numpy())

                # log
                val_loss.update(loss.item(), n=images.size(0))
            val_acc /= len(self.val_loader.dataset)
            val_f1 = f1_score(np.array(targets_list), np.array(preds_list), average='macro')

            self.logger.info(f'{phase} Loss:{val_loss.avg:.3f} | Acc:{val_acc:.4f} | F1:{val_f1:.4f}')
        return val_loss.avg, val_acc, val_f1

# %%
def main(args):
    print('<---- Training Params ---->')
    
    # Random Seed
    seed = args.seed
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = True

    save_path = os.path.join(args.model_path, (args.exp_num).zfill(3))
    
    # Create model directory
    os.makedirs(save_path, exist_ok=True)
    Trainer(args, save_path)

    return save_path

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print('Device:', device)
print('Current cuda device:', torch.cuda.current_device())
print('Count of using GPUs:', torch.cuda.device_count())
# Out:
# Device: cuda
# Current cuda device: 0
# Count of using GPUs: 2

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
sub = pd.read_csv('./open/sample_submission.csv')
df_train = pd.read_csv('./open/train_df_add_data.csv')
df_test = pd.read_csv('./open/test_df.csv')

# %%
# ! pip install ttach
import ttach as tta

# %%
def predict(encoder_name, test_loader, device, model_path):
    model = Network_test(encoder_name).to(device)
    model.load_state_dict(torch.load(opj(model_path, 'best_model.pth'))['state_dict'])
#     model.eval()
    tta_model = tta.ClassificationTTAWrapper(model, tta.aliases.d4_transform())
    tta_model.eval()
    
    preds_list = []
    with torch.no_grad():
        for images in tqdm(test_loader):
            images = torch.as_tensor(images, device=device, dtype=torch.float32)
            preds = tta_model(images)
            preds = torch.softmax(preds, dim=1)
            preds_list.extend(preds.cpu().tolist())

    return np.array(preds_list)

def ensemble_5fold(model_path_list, test_loader, device):
    predict_list = []
    for model_path in model_path_list:
        prediction = predict(encoder_name= 'convnext_base_384_in22ft1k', test_loader = test_loader, device = device, model_path = model_path)
        predict_list.append(prediction)
    ensemble = (predict_list[0] + predict_list[1] + predict_list[2] + predict_list[3] + predict_list[4])/len(predict_list)

    return ensemble

# %%
args.step = 0
models_path = []
for s_fold in range(5): # 5fold
    args.fold = s_fold
    args.exp_num = str(s_fold)
    save_path = main(args)
    models_path.append(save_path)
# Out:
# 2022-05-05 12:55:44,365 INFO: {'exp_num': '0', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_convnext_base_384_in22ft1k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'convnext_base_384_in22ft1k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 3, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 0}
# <---- Training Params ---->
# Dataset size:11197
# Dataset size:2800
# 2022-05-05 12:55:45,910 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth" to /root/.cache/torch/hub/checkpoints/convnext_base_22k_1k_384.pth
# 100%|██████████| 700/700 [06:58<00:00,  1.67it/s]
# 2022-05-05 13:03:00,048 INFO: Epoch:[001/100]
# 2022-05-05 13:03:00,049 INFO: Train Loss:3.291 | Acc:0.2081 | F1:0.1314
# 2022-05-05 13:03:46,507 INFO: val Loss:1.438 | Acc:0.4375 | F1:0.3012
# 2022-05-05 13:03:48,065 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [06:54<00:00,  1.69it/s]
# 2022-05-05 13:10:42,411 INFO: Epoch:[002/100]
# 2022-05-05 13:10:42,412 INFO: Train Loss:0.960 | Acc:0.5919 | F1:0.5592
# 2022-05-05 13:11:32,557 INFO: val Loss:0.320 | Acc:0.8125 | F1:0.7735
# 2022-05-05 13:11:34,956 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [06:52<00:00,  1.70it/s]
# 2022-05-05 13:18:27,500 INFO: Epoch:[003/100]
# 2022-05-05 13:18:27,501 INFO: Train Loss:0.244 | Acc:0.8653 | F1:0.8614
# 2022-05-05 13:19:13,590 INFO: val Loss:0.100 | Acc:0.9343 | F1:0.9365
# 2022-05-05 13:19:15,979 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [06:41<00:00,  1.74it/s]
# 2022-05-05 13:25:57,238 INFO: Epoch:[004/100]
# 2022-05-05 13:25:57,239 INFO: Train Loss:0.082 | Acc:0.9442 | F1:0.9429
# 2022-05-05 13:26:43,679 INFO: val Loss:0.015 | Acc:0.9832 | F1:0.9841
# 2022-05-05 13:26:45,969 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [06:56<00:00,  1.68it/s]
# 2022-05-05 13:33:42,785 INFO: Epoch:[005/100]
# 2022-05-05 13:33:42,786 INFO: Train Loss:0.050 | Acc:0.9645 | F1:0.9651
# 2022-05-05 13:34:28,784 INFO: val Loss:0.016 | Acc:0.9875 | F1:0.9852
# 100%|██████████| 700/700 [06:49<00:00,  1.71it/s]
# 2022-05-05 13:41:18,696 INFO: Epoch:[006/100]
# 2022-05-05 13:41:18,697 INFO: Train Loss:0.040 | Acc:0.9748 | F1:0.9747
# 2022-05-05 13:42:05,371 INFO: val Loss:0.005 | Acc:0.9954 | F1:0.9959
# 2022-05-05 13:42:07,617 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [06:55<00:00,  1.68it/s]
# 2022-05-05 13:49:03,281 INFO: Epoch:[007/100]
# 2022-05-05 13:49:03,281 INFO: Train Loss:0.031 | Acc:0.9780 | F1:0.9792
# 2022-05-05 13:49:50,131 INFO: val Loss:0.009 | Acc:0.9925 | F1:0.9925
# 100%|██████████| 700/700 [06:40<00:00,  1.75it/s]
# 2022-05-05 13:56:30,308 INFO: Epoch:[008/100]
# 2022-05-05 13:56:30,309 INFO: Train Loss:0.029 | Acc:0.9824 | F1:0.9829
# 2022-05-05 13:57:16,869 INFO: val Loss:0.004 | Acc:0.9975 | F1:0.9974
# 2022-05-05 13:57:19,089 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [06:47<00:00,  1.72it/s]
# 2022-05-05 14:04:06,864 INFO: Epoch:[009/100]
# 2022-05-05 14:04:06,865 INFO: Train Loss:0.025 | Acc:0.9860 | F1:0.9865
# 2022-05-05 14:04:53,437 INFO: val Loss:0.012 | Acc:0.9886 | F1:0.9896
# 100%|██████████| 700/700 [06:55<00:00,  1.68it/s]
# 2022-05-05 14:11:48,978 INFO: Epoch:[010/100]
# 2022-05-05 14:11:48,979 INFO: Train Loss:0.022 | Acc:0.9854 | F1:0.9857
# 2022-05-05 14:12:36,276 INFO: val Loss:0.001 | Acc:0.9993 | F1:0.9993
# 2022-05-05 14:12:38,545 INFO: -----------------SAVE:10epoch----------------
# 100%|██████████| 700/700 [06:53<00:00,  1.69it/s]
# 2022-05-05 14:19:32,144 INFO: Epoch:[011/100]
# 2022-05-05 14:19:32,145 INFO: Train Loss:0.021 | Acc:0.9883 | F1:0.9875
# 2022-05-05 14:20:17,955 INFO: val Loss:0.019 | Acc:0.9918 | F1:0.9910
# 100%|██████████| 700/700 [06:54<00:00,  1.69it/s]
# 2022-05-05 14:27:12,569 INFO: Epoch:[012/100]
# 2022-05-05 14:27:12,570 INFO: Train Loss:0.015 | Acc:0.9896 | F1:0.9898
# 2022-05-05 14:27:58,847 INFO: val Loss:0.088 | Acc:0.9818 | F1:0.9740
# 100%|██████████| 700/700 [06:51<00:00,  1.70it/s]
# 2022-05-05 14:34:50,254 INFO: Epoch:[013/100]
# 2022-05-05 14:34:50,255 INFO: Train Loss:0.018 | Acc:0.9902 | F1:0.9899
# 2022-05-05 14:35:36,401 INFO: val Loss:0.003 | Acc:0.9968 | F1:0.9973
# 100%|██████████| 700/700 [06:46<00:00,  1.72it/s]
# 2022-05-05 14:42:23,227 INFO: Epoch:[014/100]
# 2022-05-05 14:42:23,227 INFO: Train Loss:0.017 | Acc:0.9903 | F1:0.9913
# 2022-05-05 14:43:10,675 INFO: val Loss:0.001 | Acc:0.9982 | F1:0.9978
# 100%|██████████| 700/700 [06:45<00:00,  1.73it/s]
# 2022-05-05 14:49:56,291 INFO: Epoch:[015/100]
# 2022-05-05 14:49:56,292 INFO: Train Loss:0.015 | Acc:0.9927 | F1:0.9929
# 2022-05-05 14:50:41,753 INFO: val Loss:0.003 | Acc:0.9964 | F1:0.9966
# 2022-05-05 14:50:41,755 INFO:
# Best Val Epoch:10 | Val Loss:0.0009 | Val Acc:0.9993 | Val F1:0.9993
# 2022-05-05 14:50:41,756 INFO: Total Process time:114.675Minute
# 2022-05-05 14:50:41,765 INFO: {'exp_num': '1', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_convnext_base_384_in22ft1k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'convnext_base_384_in22ft1k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 3, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 1}
# <---- Training Params ---->
# Dataset size:11197
# Dataset size:2800
# 2022-05-05 14:50:43,264 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 700/700 [06:55<00:00,  1.69it/s]
# 2022-05-05 14:57:39,081 INFO: Epoch:[001/100]
# 2022-05-05 14:57:39,082 INFO: Train Loss:3.312 | Acc:0.2010 | F1:0.1252
# 2022-05-05 14:58:25,675 INFO: val Loss:1.454 | Acc:0.4200 | F1:0.2764
# 2022-05-05 14:58:27,318 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [06:49<00:00,  1.71it/s]
# 2022-05-05 15:05:17,051 INFO: Epoch:[002/100]
# 2022-05-05 15:05:17,052 INFO: Train Loss:0.971 | Acc:0.5789 | F1:0.5472
# 2022-05-05 15:06:04,003 INFO: val Loss:0.330 | Acc:0.8107 | F1:0.7825
# 2022-05-05 15:06:06,322 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [06:44<00:00,  1.73it/s]
# 2022-05-05 15:12:50,574 INFO: Epoch:[003/100]
# 2022-05-05 15:12:50,575 INFO: Train Loss:0.245 | Acc:0.8634 | F1:0.8586
# 2022-05-05 15:13:37,869 INFO: val Loss:0.070 | Acc:0.9443 | F1:0.9427
# 2022-05-05 15:13:40,205 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [06:47<00:00,  1.72it/s]
# 2022-05-05 15:20:27,902 INFO: Epoch:[004/100]
# 2022-05-05 15:20:27,902 INFO: Train Loss:0.078 | Acc:0.9465 | F1:0.9458
# 2022-05-05 15:21:15,813 INFO: val Loss:0.063 | Acc:0.9643 | F1:0.9675
# 2022-05-05 15:21:18,069 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [06:50<00:00,  1.71it/s]
# 2022-05-05 15:28:08,352 INFO: Epoch:[005/100]
# 2022-05-05 15:28:08,353 INFO: Train Loss:0.050 | Acc:0.9647 | F1:0.9641
# 2022-05-05 15:28:58,574 INFO: val Loss:0.013 | Acc:0.9911 | F1:0.9919
# 2022-05-05 15:29:00,956 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [06:58<00:00,  1.67it/s]
# 2022-05-05 15:35:59,238 INFO: Epoch:[006/100]
# 2022-05-05 15:35:59,239 INFO: Train Loss:0.038 | Acc:0.9732 | F1:0.9728
# 2022-05-05 15:36:46,168 INFO: val Loss:0.011 | Acc:0.9918 | F1:0.9934
# 2022-05-05 15:36:48,536 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [06:52<00:00,  1.70it/s]
# 2022-05-05 15:43:41,523 INFO: Epoch:[007/100]
# 2022-05-05 15:43:41,523 INFO: Train Loss:0.031 | Acc:0.9789 | F1:0.9792
# 2022-05-05 15:44:29,468 INFO: val Loss:0.012 | Acc:0.9911 | F1:0.9901
# 100%|██████████| 700/700 [06:44<00:00,  1.73it/s]
# 2022-05-05 15:51:13,713 INFO: Epoch:[008/100]
# 2022-05-05 15:51:13,714 INFO: Train Loss:0.028 | Acc:0.9814 | F1:0.9817
# 2022-05-05 15:52:00,276 INFO: val Loss:0.005 | Acc:0.9961 | F1:0.9959
# 2022-05-05 15:52:02,535 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [06:50<00:00,  1.71it/s]
# 2022-05-05 15:58:52,803 INFO: Epoch:[009/100]
# 2022-05-05 15:58:52,804 INFO: Train Loss:0.024 | Acc:0.9838 | F1:0.9837
# 2022-05-05 15:59:42,080 INFO: val Loss:0.009 | Acc:0.9950 | F1:0.9949
# 100%|██████████| 700/700 [06:51<00:00,  1.70it/s]
# 2022-05-05 16:06:33,112 INFO: Epoch:[010/100]
# 2022-05-05 16:06:33,113 INFO: Train Loss:0.023 | Acc:0.9873 | F1:0.9877
# 2022-05-05 16:07:18,928 INFO: val Loss:0.005 | Acc:0.9954 | F1:0.9962
# 2022-05-05 16:07:21,263 INFO: -----------------SAVE:10epoch----------------
# 100%|██████████| 700/700 [06:44<00:00,  1.73it/s]
# 2022-05-05 16:14:05,894 INFO: Epoch:[011/100]
# 2022-05-05 16:14:05,894 INFO: Train Loss:0.019 | Acc:0.9886 | F1:0.9883
# 2022-05-05 16:14:54,484 INFO: val Loss:0.004 | Acc:0.9968 | F1:0.9965
# 2022-05-05 16:14:56,509 INFO: -----------------SAVE:11epoch----------------
# 100%|██████████| 700/700 [06:54<00:00,  1.69it/s]
# 2022-05-05 16:21:51,302 INFO: Epoch:[012/100]
# 2022-05-05 16:21:51,303 INFO: Train Loss:0.017 | Acc:0.9892 | F1:0.9890
# 2022-05-05 16:22:38,740 INFO: val Loss:0.011 | Acc:0.9943 | F1:0.9945
# 100%|██████████| 700/700 [06:53<00:00,  1.69it/s]
# 2022-05-05 16:29:31,813 INFO: Epoch:[013/100]
# 2022-05-05 16:29:31,814 INFO: Train Loss:0.019 | Acc:0.9894 | F1:0.9905
# 2022-05-05 16:30:17,720 INFO: val Loss:0.008 | Acc:0.9954 | F1:0.9964
# 100%|██████████| 700/700 [06:50<00:00,  1.71it/s]
# 2022-05-05 16:37:08,229 INFO: Epoch:[014/100]
# 2022-05-05 16:37:08,230 INFO: Train Loss:0.015 | Acc:0.9897 | F1:0.9903
# 2022-05-05 16:37:55,949 INFO: val Loss:0.004 | Acc:0.9964 | F1:0.9961
# 2022-05-05 16:37:58,316 INFO: -----------------SAVE:14epoch----------------
# 100%|██████████| 700/700 [07:00<00:00,  1.67it/s]
# 2022-05-05 16:44:58,675 INFO: Epoch:[015/100]
# 2022-05-05 16:44:58,676 INFO: Train Loss:0.018 | Acc:0.9907 | F1:0.9907
# 2022-05-05 16:45:45,387 INFO: val Loss:0.007 | Acc:0.9957 | F1:0.9961
# 100%|██████████| 700/700 [06:47<00:00,  1.72it/s]
# 2022-05-05 16:52:33,115 INFO: Epoch:[016/100]
# 2022-05-05 16:52:33,116 INFO: Train Loss:0.017 | Acc:0.9917 | F1:0.9913
# 2022-05-05 16:53:19,303 INFO: val Loss:0.007 | Acc:0.9943 | F1:0.9943
# 100%|██████████| 700/700 [06:48<00:00,  1.71it/s]
# 2022-05-05 17:00:07,989 INFO: Epoch:[017/100]
# 2022-05-05 17:00:07,990 INFO: Train Loss:0.015 | Acc:0.9921 | F1:0.9927
# 2022-05-05 17:00:54,063 INFO: val Loss:0.006 | Acc:0.9975 | F1:0.9977
# 100%|██████████| 700/700 [06:51<00:00,  1.70it/s]
# 2022-05-05 17:07:45,100 INFO: Epoch:[018/100]
# 2022-05-05 17:07:45,101 INFO: Train Loss:0.015 | Acc:0.9928 | F1:0.9936
# 2022-05-05 17:08:30,304 INFO: val Loss:0.001 | Acc:0.9989 | F1:0.9988
# 2022-05-05 17:08:32,521 INFO: -----------------SAVE:18epoch----------------
# 100%|██████████| 700/700 [06:59<00:00,  1.67it/s]
# 2022-05-05 17:15:32,292 INFO: Epoch:[019/100]
# 2022-05-05 17:15:32,293 INFO: Train Loss:0.014 | Acc:0.9929 | F1:0.9936
# 2022-05-05 17:16:22,970 INFO: val Loss:0.015 | Acc:0.9907 | F1:0.9883
# 100%|██████████| 700/700 [07:07<00:00,  1.64it/s]
# 2022-05-05 17:23:30,956 INFO: Epoch:[020/100]
# 2022-05-05 17:23:30,957 INFO: Train Loss:0.014 | Acc:0.9927 | F1:0.9923
# 2022-05-05 17:24:21,676 INFO: val Loss:0.006 | Acc:0.9961 | F1:0.9959
# 100%|██████████| 700/700 [07:09<00:00,  1.63it/s]
# 2022-05-05 17:31:31,273 INFO: Epoch:[021/100]
# 2022-05-05 17:31:31,274 INFO: Train Loss:0.014 | Acc:0.9930 | F1:0.9935
# 2022-05-05 17:32:21,721 INFO: val Loss:0.001 | Acc:0.9993 | F1:0.9991
# 100%|██████████| 700/700 [07:13<00:00,  1.62it/s]
# 2022-05-05 17:39:34,974 INFO: Epoch:[022/100]
# 2022-05-05 17:39:34,975 INFO: Train Loss:0.015 | Acc:0.9921 | F1:0.9924
# 2022-05-05 17:40:25,066 INFO: val Loss:0.001 | Acc:0.9989 | F1:0.9989
# 2022-05-05 17:40:27,201 INFO: -----------------SAVE:22epoch----------------
# 100%|██████████| 700/700 [07:02<00:00,  1.66it/s]
# 2022-05-05 17:47:30,097 INFO: Epoch:[023/100]
# 2022-05-05 17:47:30,098 INFO: Train Loss:0.012 | Acc:0.9935 | F1:0.9937
# 2022-05-05 17:48:16,391 INFO: val Loss:0.025 | Acc:0.9882 | F1:0.9798
# 100%|██████████| 700/700 [06:49<00:00,  1.71it/s]
# 2022-05-05 17:55:05,735 INFO: Epoch:[024/100]
# 2022-05-05 17:55:05,735 INFO: Train Loss:0.010 | Acc:0.9942 | F1:0.9948
# 2022-05-05 17:55:52,744 INFO: val Loss:0.005 | Acc:0.9968 | F1:0.9969
# 100%|██████████| 700/700 [06:57<00:00,  1.68it/s]
# 2022-05-05 18:02:50,367 INFO: Epoch:[025/100]
# 2022-05-05 18:02:50,368 INFO: Train Loss:0.013 | Acc:0.9936 | F1:0.9937
# 2022-05-05 18:03:40,083 INFO: val Loss:0.009 | Acc:0.9950 | F1:0.9957
# 100%|██████████| 700/700 [07:16<00:00,  1.60it/s]
# 2022-05-05 18:10:56,425 INFO: Epoch:[026/100]
# 2022-05-05 18:10:56,426 INFO: Train Loss:0.010 | Acc:0.9939 | F1:0.9940
# 2022-05-05 18:11:47,104 INFO: val Loss:0.001 | Acc:0.9996 | F1:0.9994
# 100%|██████████| 700/700 [07:07<00:00,  1.64it/s]
# 2022-05-05 18:18:54,600 INFO: Epoch:[027/100]
# 2022-05-05 18:18:54,600 INFO: Train Loss:0.010 | Acc:0.9941 | F1:0.9940
# 2022-05-05 18:19:44,604 INFO: val Loss:0.002 | Acc:0.9996 | F1:0.9997
# 2022-05-05 18:19:44,606 INFO:
# Best Val Epoch:22 | Val Loss:0.0009 | Val Acc:0.9989 | Val F1:0.9989
# 2022-05-05 18:19:44,607 INFO: Total Process time:209.013Minute
# 2022-05-05 18:19:44,618 INFO: {'exp_num': '2', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_convnext_base_384_in22ft1k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'convnext_base_384_in22ft1k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 3, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 2}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-05 18:19:45,987 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 700/700 [07:00<00:00,  1.66it/s]
# 2022-05-05 18:26:47,339 INFO: Epoch:[001/100]
# 2022-05-05 18:26:47,340 INFO: Train Loss:3.322 | Acc:0.2000 | F1:0.1284
# 2022-05-05 18:27:36,929 INFO: val Loss:1.470 | Acc:0.4319 | F1:0.2850
# 2022-05-05 18:27:38,528 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [07:11<00:00,  1.62it/s]
# 2022-05-05 18:34:49,938 INFO: Epoch:[002/100]
# 2022-05-05 18:34:49,939 INFO: Train Loss:0.962 | Acc:0.5864 | F1:0.5528
# 2022-05-05 18:35:40,663 INFO: val Loss:0.308 | Acc:0.8192 | F1:0.8140
# 2022-05-05 18:35:42,979 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [07:12<00:00,  1.62it/s]
# 2022-05-05 18:42:55,597 INFO: Epoch:[003/100]
# 2022-05-05 18:42:55,598 INFO: Train Loss:0.247 | Acc:0.8636 | F1:0.8611
# 2022-05-05 18:43:45,839 INFO: val Loss:0.056 | Acc:0.9639 | F1:0.9665
# 2022-05-05 18:43:48,127 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-05 18:51:06,779 INFO: Epoch:[004/100]
# 2022-05-05 18:51:06,780 INFO: Train Loss:0.080 | Acc:0.9459 | F1:0.9453
# 2022-05-05 18:51:57,568 INFO: val Loss:0.040 | Acc:0.9689 | F1:0.9691
# 2022-05-05 18:51:59,817 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [07:12<00:00,  1.62it/s]
# 2022-05-05 18:59:12,677 INFO: Epoch:[005/100]
# 2022-05-05 18:59:12,678 INFO: Train Loss:0.052 | Acc:0.9637 | F1:0.9646
# 2022-05-05 19:00:02,399 INFO: val Loss:0.048 | Acc:0.9643 | F1:0.9555
# 100%|██████████| 700/700 [07:16<00:00,  1.60it/s]
# 2022-05-05 19:07:18,716 INFO: Epoch:[006/100]
# 2022-05-05 19:07:18,716 INFO: Train Loss:0.039 | Acc:0.9736 | F1:0.9738
# 2022-05-05 19:08:08,598 INFO: val Loss:0.007 | Acc:0.9911 | F1:0.9900
# 2022-05-05 19:08:10,923 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [07:16<00:00,  1.60it/s]
# 2022-05-05 19:15:27,558 INFO: Epoch:[007/100]
# 2022-05-05 19:15:27,559 INFO: Train Loss:0.032 | Acc:0.9791 | F1:0.9802
# 2022-05-05 19:16:20,154 INFO: val Loss:0.016 | Acc:0.9907 | F1:0.9918
# 100%|██████████| 700/700 [07:01<00:00,  1.66it/s]
# 2022-05-05 19:23:21,824 INFO: Epoch:[008/100]
# 2022-05-05 19:23:21,824 INFO: Train Loss:0.029 | Acc:0.9824 | F1:0.9824
# 2022-05-05 19:24:13,221 INFO: val Loss:0.011 | Acc:0.9929 | F1:0.9935
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-05 19:31:39,007 INFO: Epoch:[009/100]
# 2022-05-05 19:31:39,007 INFO: Train Loss:0.022 | Acc:0.9850 | F1:0.9850
# 2022-05-05 19:32:33,489 INFO: val Loss:0.022 | Acc:0.9893 | F1:0.9903
# 100%|██████████| 700/700 [07:22<00:00,  1.58it/s]
# 2022-05-05 19:39:56,242 INFO: Epoch:[010/100]
# 2022-05-05 19:39:56,243 INFO: Train Loss:0.023 | Acc:0.9855 | F1:0.9855
# 2022-05-05 19:40:48,839 INFO: val Loss:0.009 | Acc:0.9932 | F1:0.9943
# 100%|██████████| 700/700 [07:14<00:00,  1.61it/s]
# 2022-05-05 19:48:03,540 INFO: Epoch:[011/100]
# 2022-05-05 19:48:03,540 INFO: Train Loss:0.019 | Acc:0.9869 | F1:0.9869
# 2022-05-05 19:48:54,343 INFO: val Loss:0.023 | Acc:0.9893 | F1:0.9908
# 2022-05-05 19:48:54,345 INFO:
# Best Val Epoch:6 | Val Loss:0.0075 | Val Acc:0.9911 | Val F1:0.9900
# 2022-05-05 19:48:54,346 INFO: Total Process time:89.130Minute
# 2022-05-05 19:48:54,366 INFO: {'exp_num': '3', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_convnext_base_384_in22ft1k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'convnext_base_384_in22ft1k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 3, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 3}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-05 19:48:55,844 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 700/700 [07:19<00:00,  1.59it/s]
# 2022-05-05 19:56:16,208 INFO: Epoch:[001/100]
# 2022-05-05 19:56:16,209 INFO: Train Loss:3.318 | Acc:0.2001 | F1:0.1297
# 2022-05-05 19:57:12,562 INFO: val Loss:1.471 | Acc:0.4030 | F1:0.2719
# 2022-05-05 19:57:14,152 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [07:15<00:00,  1.61it/s]
# 2022-05-05 20:04:29,944 INFO: Epoch:[002/100]
# 2022-05-05 20:04:29,945 INFO: Train Loss:0.973 | Acc:0.5853 | F1:0.5523
# 2022-05-05 20:05:21,316 INFO: val Loss:0.344 | Acc:0.8207 | F1:0.8090
# 2022-05-05 20:05:23,747 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [07:23<00:00,  1.58it/s]
# 2022-05-05 20:12:47,590 INFO: Epoch:[003/100]
# 2022-05-05 20:12:47,591 INFO: Train Loss:0.247 | Acc:0.8619 | F1:0.8603
# 2022-05-05 20:13:39,253 INFO: val Loss:0.068 | Acc:0.9418 | F1:0.9369
# 2022-05-05 20:13:41,626 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [07:12<00:00,  1.62it/s]
# 2022-05-05 20:20:54,507 INFO: Epoch:[004/100]
# 2022-05-05 20:20:54,508 INFO: Train Loss:0.083 | Acc:0.9450 | F1:0.9435
# 2022-05-05 20:21:45,983 INFO: val Loss:0.026 | Acc:0.9796 | F1:0.9788
# 2022-05-05 20:21:48,453 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [07:12<00:00,  1.62it/s]
# 2022-05-05 20:29:00,773 INFO: Epoch:[005/100]
# 2022-05-05 20:29:00,774 INFO: Train Loss:0.053 | Acc:0.9654 | F1:0.9655
# 2022-05-05 20:29:52,420 INFO: val Loss:0.020 | Acc:0.9836 | F1:0.9760
# 2022-05-05 20:29:54,696 INFO: -----------------SAVE:5epoch----------------
# 100%|██████████| 700/700 [07:14<00:00,  1.61it/s]
# 2022-05-05 20:37:09,645 INFO: Epoch:[006/100]
# 2022-05-05 20:37:09,645 INFO: Train Loss:0.037 | Acc:0.9745 | F1:0.9742
# 2022-05-05 20:38:00,088 INFO: val Loss:0.016 | Acc:0.9879 | F1:0.9910
# 2022-05-05 20:38:02,390 INFO: -----------------SAVE:6epoch----------------
# 100%|██████████| 700/700 [07:10<00:00,  1.62it/s]
# 2022-05-05 20:45:13,246 INFO: Epoch:[007/100]
# 2022-05-05 20:45:13,247 INFO: Train Loss:0.032 | Acc:0.9796 | F1:0.9806
# 2022-05-05 20:46:03,995 INFO: val Loss:0.006 | Acc:0.9961 | F1:0.9967
# 2022-05-05 20:46:06,338 INFO: -----------------SAVE:7epoch----------------
# 100%|██████████| 700/700 [07:25<00:00,  1.57it/s]
# 2022-05-05 20:53:32,119 INFO: Epoch:[008/100]
# 2022-05-05 20:53:32,120 INFO: Train Loss:0.028 | Acc:0.9827 | F1:0.9831
# 2022-05-05 20:54:22,975 INFO: val Loss:0.021 | Acc:0.9911 | F1:0.9912
# 100%|██████████| 700/700 [07:19<00:00,  1.59it/s]
# 2022-05-05 21:01:42,904 INFO: Epoch:[009/100]
# 2022-05-05 21:01:42,914 INFO: Train Loss:0.022 | Acc:0.9846 | F1:0.9845
# 2022-05-05 21:02:33,503 INFO: val Loss:0.007 | Acc:0.9929 | F1:0.9917
# 100%|██████████| 700/700 [07:10<00:00,  1.62it/s]
# 2022-05-05 21:09:44,489 INFO: Epoch:[010/100]
# 2022-05-05 21:09:44,490 INFO: Train Loss:0.021 | Acc:0.9868 | F1:0.9870
# 2022-05-05 21:10:35,531 INFO: val Loss:0.003 | Acc:0.9971 | F1:0.9975
# 2022-05-05 21:10:37,858 INFO: -----------------SAVE:10epoch----------------
# 100%|██████████| 700/700 [07:30<00:00,  1.55it/s]
# 2022-05-05 21:18:08,348 INFO: Epoch:[011/100]
# 2022-05-05 21:18:08,348 INFO: Train Loss:0.022 | Acc:0.9876 | F1:0.9885
# 2022-05-05 21:18:58,178 INFO: val Loss:0.006 | Acc:0.9946 | F1:0.9947
# 100%|██████████| 700/700 [06:44<00:00,  1.73it/s]
# 2022-05-05 21:25:42,692 INFO: Epoch:[012/100]
# 2022-05-05 21:25:42,693 INFO: Train Loss:0.017 | Acc:0.9877 | F1:0.9873
# 2022-05-05 21:26:23,254 INFO: val Loss:0.009 | Acc:0.9957 | F1:0.9966
# 100%|██████████| 700/700 [06:01<00:00,  1.93it/s]
# 2022-05-05 21:32:25,037 INFO: Epoch:[013/100]
# 2022-05-05 21:32:25,038 INFO: Train Loss:0.018 | Acc:0.9890 | F1:0.9889
# 2022-05-05 21:33:04,263 INFO: val Loss:0.015 | Acc:0.9893 | F1:0.9914
# 100%|██████████| 700/700 [06:05<00:00,  1.91it/s]
# 2022-05-05 21:39:10,008 INFO: Epoch:[014/100]
# 2022-05-05 21:39:10,009 INFO: Train Loss:0.015 | Acc:0.9897 | F1:0.9898
# 2022-05-05 21:39:51,100 INFO: val Loss:0.001 | Acc:0.9989 | F1:0.9989
# 2022-05-05 21:39:53,459 INFO: -----------------SAVE:14epoch----------------
# 100%|██████████| 700/700 [06:05<00:00,  1.92it/s]
# 2022-05-05 21:45:58,845 INFO: Epoch:[015/100]
# 2022-05-05 21:45:58,846 INFO: Train Loss:0.017 | Acc:0.9905 | F1:0.9905
# 2022-05-05 21:46:38,865 INFO: val Loss:0.002 | Acc:0.9968 | F1:0.9967
# 100%|██████████| 700/700 [06:07<00:00,  1.91it/s]
# 2022-05-05 21:52:46,175 INFO: Epoch:[016/100]
# 2022-05-05 21:52:46,176 INFO: Train Loss:0.014 | Acc:0.9912 | F1:0.9908
# 2022-05-05 21:53:25,558 INFO: val Loss:0.003 | Acc:0.9964 | F1:0.9969
# 100%|██████████| 700/700 [06:19<00:00,  1.85it/s]
# 2022-05-05 21:59:44,784 INFO: Epoch:[017/100]
# 2022-05-05 21:59:44,785 INFO: Train Loss:0.013 | Acc:0.9924 | F1:0.9933
# 2022-05-05 22:00:27,455 INFO: val Loss:0.005 | Acc:0.9954 | F1:0.9961
# 100%|██████████| 700/700 [06:25<00:00,  1.81it/s]
# 2022-05-05 22:06:53,387 INFO: Epoch:[018/100]
# 2022-05-05 22:06:53,388 INFO: Train Loss:0.012 | Acc:0.9931 | F1:0.9934
# 2022-05-05 22:07:36,088 INFO: val Loss:0.015 | Acc:0.9943 | F1:0.9950
# 100%|██████████| 700/700 [06:24<00:00,  1.82it/s]
# 2022-05-05 22:14:00,924 INFO: Epoch:[019/100]
# 2022-05-05 22:14:00,925 INFO: Train Loss:0.012 | Acc:0.9929 | F1:0.9928
# 2022-05-05 22:14:43,422 INFO: val Loss:0.000 | Acc:0.9996 | F1:0.9997
# 2022-05-05 22:14:45,663 INFO: -----------------SAVE:19epoch----------------
# 100%|██████████| 700/700 [06:23<00:00,  1.83it/s]
# 2022-05-05 22:21:08,925 INFO: Epoch:[020/100]
# 2022-05-05 22:21:08,926 INFO: Train Loss:0.014 | Acc:0.9921 | F1:0.9929
# 2022-05-05 22:21:54,146 INFO: val Loss:0.005 | Acc:0.9971 | F1:0.9976
# 100%|██████████| 700/700 [06:24<00:00,  1.82it/s]
# 2022-05-05 22:28:18,882 INFO: Epoch:[021/100]
# 2022-05-05 22:28:18,883 INFO: Train Loss:0.012 | Acc:0.9929 | F1:0.9933
# 2022-05-05 22:29:01,370 INFO: val Loss:0.001 | Acc:0.9989 | F1:0.9988
# 100%|██████████| 700/700 [06:27<00:00,  1.81it/s]
# 2022-05-05 22:35:29,001 INFO: Epoch:[022/100]
# 2022-05-05 22:35:29,002 INFO: Train Loss:0.013 | Acc:0.9926 | F1:0.9924
# 2022-05-05 22:36:11,662 INFO: val Loss:0.003 | Acc:0.9979 | F1:0.9979
# 100%|██████████| 700/700 [06:28<00:00,  1.80it/s]
# 2022-05-05 22:42:40,074 INFO: Epoch:[023/100]
# 2022-05-05 22:42:40,075 INFO: Train Loss:0.017 | Acc:0.9918 | F1:0.9925
# 2022-05-05 22:43:22,810 INFO: val Loss:0.000 | Acc:0.9993 | F1:0.9990
# 100%|██████████| 700/700 [06:25<00:00,  1.82it/s]
# 2022-05-05 22:49:48,222 INFO: Epoch:[024/100]
# 2022-05-05 22:49:48,222 INFO: Train Loss:0.011 | Acc:0.9933 | F1:0.9938
# 2022-05-05 22:50:31,184 INFO: val Loss:0.010 | Acc:0.9950 | F1:0.9948
# 2022-05-05 22:50:31,186 INFO:
# Best Val Epoch:19 | Val Loss:0.0001 | Val Acc:0.9996 | Val F1:0.9997
# 2022-05-05 22:50:31,188 INFO: Total Process time:181.580Minute
# 2022-05-05 22:50:31,207 INFO: {'exp_num': '4', 'data_path': './open', 'Kfold': 5, 'model_path': 'label_results_convnext_base_384_in22ft1k/', 'image_type': 'train_1024', 'class_num': 88, 'model_name': 'convnext_base_384_in22ft1k', 'drop_path_rate': 0.2, 'img_size': 384, 'batch_size': 16, 'epochs': 100, 'optimizer': 'Lamb', 'initial_lr': 0.0005, 'weight_decay': 0.001, 'aug_ver': 2, 'scheduler': 'Reduce', 'warm_epoch': 3, 'max_lr': 0.001, 'min_lr': 5e-05, 'tmax': 145, 'patience': 5, 'clipping': None, 'amp': True, 'multi_gpu': True, 'logging': False, 'num_workers': 4, 'seed': 42, 'step': 0, 'fold': 4}
# <---- Training Params ---->
# Dataset size:11198
# Dataset size:2799
# 2022-05-05 22:50:32,567 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 700/700 [04:30<00:00,  2.59it/s]
# 2022-05-05 22:55:03,689 INFO: Epoch:[001/100]
# 2022-05-05 22:55:03,690 INFO: Train Loss:3.291 | Acc:0.2043 | F1:0.1321
# 2022-05-05 22:55:34,065 INFO: val Loss:1.455 | Acc:0.4051 | F1:0.2650
# 2022-05-05 22:55:35,463 INFO: -----------------SAVE:1epoch----------------
# 100%|██████████| 700/700 [04:11<00:00,  2.78it/s]
# 2022-05-05 22:59:47,223 INFO: Epoch:[002/100]
# 2022-05-05 22:59:47,224 INFO: Train Loss:0.961 | Acc:0.5865 | F1:0.5564
# 2022-05-05 23:00:17,653 INFO: val Loss:0.301 | Acc:0.8253 | F1:0.8114
# 2022-05-05 23:00:19,755 INFO: -----------------SAVE:2epoch----------------
# 100%|██████████| 700/700 [04:05<00:00,  2.85it/s]
# 2022-05-05 23:04:25,622 INFO: Epoch:[003/100]
# 2022-05-05 23:04:25,622 INFO: Train Loss:0.241 | Acc:0.8684 | F1:0.8677
# 2022-05-05 23:04:55,568 INFO: val Loss:0.052 | Acc:0.9600 | F1:0.9589
# 2022-05-05 23:04:57,614 INFO: -----------------SAVE:3epoch----------------
# 100%|██████████| 700/700 [04:07<00:00,  2.83it/s]
# 2022-05-05 23:09:05,316 INFO: Epoch:[004/100]
# 2022-05-05 23:09:05,317 INFO: Train Loss:0.079 | Acc:0.9447 | F1:0.9449
# 2022-05-05 23:09:36,158 INFO: val Loss:0.012 | Acc:0.9864 | F1:0.9856
# 2022-05-05 23:09:38,260 INFO: -----------------SAVE:4epoch----------------
# 100%|██████████| 700/700 [04:14<00:00,  2.75it/s]
# 2022-05-05 23:13:52,948 INFO: Epoch:[005/100]
# 2022-05-05 23:13:52,949 INFO: Train Loss:0.048 | Acc:0.9648 | F1:0.9638
# 2022-05-05 23:14:23,590 INFO: val Loss:0.017 | Acc:0.9854 | F1:0.9852
# 100%|██████████| 700/700 [04:09<00:00,  2.81it/s]
# 2022-05-05 23:18:32,948 INFO: Epoch:[006/100]
# 2022-05-05 23:18:32,949 INFO: Train Loss:0.042 | Acc:0.9701 | F1:0.9687
# 2022-05-05 23:19:04,112 INFO: val Loss:0.021 | Acc:0.9893 | F1:0.9876
# 100%|██████████| 700/700 [04:14<00:00,  2.75it/s]
# 2022-05-05 23:23:19,086 INFO: Epoch:[007/100]
# 2022-05-05 23:23:19,086 INFO: Train Loss:0.027 | Acc:0.9813 | F1:0.9815
# 2022-05-05 23:23:49,994 INFO: val Loss:0.016 | Acc:0.9871 | F1:0.9858
# 100%|██████████| 700/700 [04:06<00:00,  2.84it/s]
# 2022-05-05 23:27:56,912 INFO: Epoch:[008/100]
# 2022-05-05 23:27:56,913 INFO: Train Loss:0.026 | Acc:0.9820 | F1:0.9828
# 2022-05-05 23:28:27,229 INFO: val Loss:0.006 | Acc:0.9957 | F1:0.9960
# 2022-05-05 23:28:29,049 INFO: -----------------SAVE:8epoch----------------
# 100%|██████████| 700/700 [04:32<00:00,  2.57it/s]
# 2022-05-05 23:33:01,964 INFO: Epoch:[009/100]
# 2022-05-05 23:33:01,965 INFO: Train Loss:0.025 | Acc:0.9854 | F1:0.9856
# 2022-05-05 23:33:43,048 INFO: val Loss:0.018 | Acc:0.9911 | F1:0.9936
# 100%|██████████| 700/700 [07:18<00:00,  1.60it/s]
# 2022-05-05 23:41:01,622 INFO: Epoch:[010/100]
# 2022-05-05 23:41:01,623 INFO: Train Loss:0.024 | Acc:0.9847 | F1:0.9855
# 2022-05-05 23:41:54,179 INFO: val Loss:0.006 | Acc:0.9964 | F1:0.9969
# 2022-05-05 23:41:56,434 INFO: -----------------SAVE:10epoch----------------
# 100%|██████████| 700/700 [08:51<00:00,  1.32it/s]
# 2022-05-05 23:50:47,531 INFO: Epoch:[011/100]
# 2022-05-05 23:50:47,532 INFO: Train Loss:0.019 | Acc:0.9877 | F1:0.9883
# 2022-05-05 23:51:39,352 INFO: val Loss:0.016 | Acc:0.9918 | F1:0.9916
# 100%|██████████| 700/700 [08:50<00:00,  1.32it/s]
# 2022-05-06 00:00:30,001 INFO: Epoch:[012/100]
# 2022-05-06 00:00:30,002 INFO: Train Loss:0.021 | Acc:0.9872 | F1:0.9862
# 2022-05-06 00:01:22,290 INFO: val Loss:0.011 | Acc:0.9925 | F1:0.9903
# 100%|██████████| 700/700 [08:36<00:00,  1.35it/s]
# 2022-05-06 00:09:59,060 INFO: Epoch:[013/100]
# 2022-05-06 00:09:59,061 INFO: Train Loss:0.017 | Acc:0.9896 | F1:0.9900
# 2022-05-06 00:10:51,194 INFO: val Loss:0.004 | Acc:0.9957 | F1:0.9962
# 2022-05-06 00:10:53,339 INFO: -----------------SAVE:13epoch----------------
# 100%|██████████| 700/700 [08:52<00:00,  1.31it/s]
# 2022-05-06 00:19:45,766 INFO: Epoch:[014/100]
# 2022-05-06 00:19:45,766 INFO: Train Loss:0.016 | Acc:0.9895 | F1:0.9898
# 2022-05-06 00:20:37,817 INFO: val Loss:0.004 | Acc:0.9968 | F1:0.9970
# 100%|██████████| 700/700 [08:57<00:00,  1.30it/s]
# 2022-05-06 00:29:35,314 INFO: Epoch:[015/100]
# 2022-05-06 00:29:35,315 INFO: Train Loss:0.016 | Acc:0.9893 | F1:0.9897
# 2022-05-06 00:30:30,061 INFO: val Loss:0.001 | Acc:0.9993 | F1:0.9994
# 2022-05-06 00:30:32,253 INFO: -----------------SAVE:15epoch----------------
# 100%|██████████| 700/700 [08:37<00:00,  1.35it/s]
# 2022-05-06 00:39:09,427 INFO: Epoch:[016/100]
# 2022-05-06 00:39:09,428 INFO: Train Loss:0.014 | Acc:0.9908 | F1:0.9910
# 2022-05-06 00:40:02,009 INFO: val Loss:0.002 | Acc:0.9993 | F1:0.9993
# 100%|██████████| 700/700 [08:57<00:00,  1.30it/s]
# 2022-05-06 00:48:59,234 INFO: Epoch:[017/100]
# 2022-05-06 00:48:59,235 INFO: Train Loss:0.014 | Acc:0.9909 | F1:0.9906
# 2022-05-06 00:49:51,418 INFO: val Loss:0.006 | Acc:0.9961 | F1:0.9959
# 100%|██████████| 700/700 [08:56<00:00,  1.31it/s]
# 2022-05-06 00:58:47,679 INFO: Epoch:[018/100]
# 2022-05-06 00:58:47,679 INFO: Train Loss:0.015 | Acc:0.9908 | F1:0.9914
# 2022-05-06 00:59:38,799 INFO: val Loss:0.002 | Acc:0.9989 | F1:0.9989
# 100%|██████████| 700/700 [08:30<00:00,  1.37it/s]
# 2022-05-06 01:08:09,077 INFO: Epoch:[019/100]
# 2022-05-06 01:08:09,078 INFO: Train Loss:0.012 | Acc:0.9930 | F1:0.9931
# 2022-05-06 01:09:00,933 INFO: val Loss:0.010 | Acc:0.9911 | F1:0.9892
# 100%|██████████| 700/700 [08:55<00:00,  1.31it/s]
# 2022-05-06 01:17:56,298 INFO: Epoch:[020/100]
# 2022-05-06 01:17:56,298 INFO: Train Loss:0.014 | Acc:0.9915 | F1:0.9919
# 2022-05-06 01:18:47,847 INFO: val Loss:0.003 | Acc:0.9971 | F1:0.9977
# 2022-05-06 01:18:47,849 INFO:
# Best Val Epoch:15 | Val Loss:0.0010 | Val Acc:0.9993 | Val F1:0.9994
# 2022-05-06 01:18:47,849 INFO: Total Process time:148.243Minute

# %%
img_size = 384

test_transform = get_train_augmentation(img_size=img_size, ver=1)
test_dataset = Test_dataset(df_test, test_transform)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=0)
# Out:
# Test Dataset size:2154

# %%
# models_path = ['./label_results_vit_base_resnet50_384/000', './label_results_vit_base_resnet50_384/001', './label_results_vit_base_resnet50_384/002', './label_results_vit_base_resnet50_384/003', './label_results_vit_base_resnet50_384/004']

# %%
ensemble = ensemble_5fold(models_path, test_loader, device)
# Out:
# 2022-05-06 01:18:49,190 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 34/34 [10:00<00:00, 17.66s/it]
# 2022-05-06 01:28:52,436 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 34/34 [09:42<00:00, 17.14s/it]
# 2022-05-06 01:38:38,131 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 34/34 [09:59<00:00, 17.64s/it]
# 2022-05-06 01:48:40,826 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 34/34 [09:54<00:00, 17.48s/it]
# 2022-05-06 01:58:38,085 INFO: Loading pretrained weights from url (https://dl.fbaipublicfiles.com/convnext/convnext_base_22k_1k_384.pth)
# 100%|██████████| 34/34 [09:37<00:00, 16.98s/it]

# %%
f_pred = ensemble.argmax(axis=1).tolist()
f_pred
# Out:
# [62,
#  28,
#  72,
#  64,
#  63,
#  50,
#  14,
#  32,
#  40,
#  39,
#  0,
#  76,
#  85,
#  59,
#  62,
#  2,
#  25,
#  22,
#  21,
#  47,
#  66,
#  84,
#  0,
#  58,
#  51,
#  55,
#  51,
#  60,
#  40,
#  39,
#  55,
#  9,
#  59,
#  83,
#  84,
#  82,
#  40,
#  9,
#  37,
#  44,
#  45,
#  10,
#  60,
#  14,
#  44,
#  63,
#  68,
#  15,
#  84,
#  55,
#  9,
#  72,
#  31,
#  35,
#  84,
#  46,
#  20,
#  21,
#  38,
#  15,
#  72,
#  48,
#  18,
#  80,
#  13,
#  36,
#  72,
#  13,
#  53,
#  43,
#  25,
#  76,
#  32,
#  63,
#  41,
#  84,
#  9,
#  40,
#  9,
#  9,
#  50,
#  76,
#  57,
#  75,
#  72,
#  0,
#  84,
#  22,
#  40,
#  83,
#  36,
#  84,
#  9,
#  42,
#  55,
#  65,
#  69,
#  72,
#  45,
#  45,
#  9,
#  21,
#  52,
#  17,
#  76,
#  2,
#  85,
#  49,
#  72,
#  34,
#  36,
#  58,
#  69,
#  72,
#  84,
#  15,
#  28,
#  52,
#  13,
#  41,
#  55,
#  19,
#  45,
#  72,
#  77,
#  70,
#  61,
#  72,
#  54,
#  55,
#  28,
#  46,
#  50,
#  42,
#  15,
#  25,
#  57,
#  2,
#  52,
#  78,
#  73,
#  33,
#  7,
#  9,
#  84,
#  35,
#  23,
#  84,
#  85,
#  76,
#  84,
#  79,
#  72,
#  52,
#  83,
#  63,
#  68,
#  63,
#  33,
#  45,
#  57,
#  60,
#  57,
#  11,
#  21,
#  38,
#  49,
#  74,
#  83,
#  10,
#  21,
#  24,
#  56,
#  39,
#  9,
#  52,
#  55,
#  86,
#  15,
#  84,
#  40,
#  27,
#  3,
#  11,
#  51,
#  20,
#  62,
#  45,
#  79,
#  28,
#  52,
#  18,
#  84,
#  32,
#  52,
#  57,
#  81,
#  85,
#  84,
#  33,
#  72,
#  9,
#  58,
#  1,
#  52,
#  40,
#  52,
#  52,
#  33,
#  25,
#  41,
#  15,
#  55,
#  76,
#  48,
#  20,
#  18,
#  49,
#  72,
#  1,
#  65,
#  28,
#  63,
#  1,
#  15,
#  45,
#  51,
#  36,
#  9,
#  71,
#  52,
#  55,
#  81,
#  49,
#  80,
#  17,
#  72,
#  45,
#  31,
#  14,
#  45,
#  34,
#  85,
#  59,
#  74,
#  41,
#  63,
#  64,
#  79,
#  5,
#  72,
#  64,
#  4,
#  15,
#  44,
#  45,
#  45,
#  16,
#  80,
#  33,
#  31,
#  55,
#  33,
#  32,
#  41,
#  40,
#  76,
#  55,
#  44,
#  9,
#  21,
#  55,
#  77,
#  72,
#  9,
#  15,
#  47,
#  15,
#  73,
#  87,
#  47,
#  36,
#  72,
#  53,
#  52,
#  55,
#  30,
#  63,
#  63,
#  0,
#  22,
#  1,
#  38,
#  37,
#  9,
#  87,
#  63,
#  72,
#  72,
#  72,
#  58,
#  41,
#  80,
#  72,
#  57,
#  51,
#  68,
#  28,
#  36,
#  56,
#  55,
#  72,
#  3,
#  46,
#  76,
#  72,
#  59,
#  76,
#  76,
#  63,
#  9,
#  58,
#  46,
#  7,
#  40,
#  15,
#  55,
#  56,
#  50,
#  72,
#  58,
#  15,
#  55,
#  21,
#  19,
#  3,
#  63,
#  43,
#  58,
#  4,
#  76,
#  55,
#  42,
#  63,
#  55,
#  39,
#  44,
#  42,
#  33,
#  53,
#  24,
#  5,
#  9,
#  17,
#  21,
#  16,
#  9,
#  52,
#  3,
#  67,
#  70,
#  13,
#  38,
#  19,
#  72,
#  85,
#  74,
#  7,
#  5,
#  37,
#  33,
#  55,
#  9,
#  3,
#  33,
#  72,
#  77,
#  56,
#  14,
#  28,
#  46,
#  55,
#  74,
#  62,
#  15,
#  28,
#  42,
#  15,
#  32,
#  55,
#  40,
#  43,
#  1,
#  37,
#  16,
#  72,
#  5,
#  2,
#  35,
#  63,
#  78,
#  64,
#  72,
#  81,
#  2,
#  63,
#  50,
#  17,
#  40,
#  52,
#  9,
#  16,
#  52,
#  9,
#  1,
#  72,
#  40,
#  72,
#  32,
#  69,
#  46,
#  84,
#  42,
#  21,
#  19,
#  50,
#  82,
#  84,
#  37,
#  71,
#  1,
#  84,
#  9,
#  1,
#  63,
#  31,
#  79,
#  51,
#  21,
#  29,
#  47,
#  65,
#  72,
#  56,
#  69,
#  70,
#  24,
#  80,
#  62,
#  38,
#  77,
#  84,
#  1,
#  21,
#  63,
#  33,
#  59,
#  33,
#  22,
#  44,
#  9,
#  21,
#  60,
#  41,
#  24,
#  14,
#  13,
#  44,
#  59,
#  45,
#  53,
#  42,
#  63,
#  3,
#  56,
#  9,
#  76,
#  72,
#  60,
#  60,
#  48,
#  59,
#  22,
#  9,
#  55,
#  55,
#  9,
#  28,
#  34,
#  51,
#  20,
#  12,
#  7,
#  55,
#  33,
#  18,
#  70,
#  67,
#  7,
#  86,
#  56,
#  65,
#  46,
#  72,
#  4,
#  63,
#  38,
#  78,
#  68,
#  41,
#  16,
#  56,
#  72,
#  72,
#  72,
#  84,
#  9,
#  46,
#  40,
#  9,
#  64,
#  53,
#  76,
#  45,
#  52,
#  81,
#  11,
#  76,
#  13,
#  20,
#  13,
#  34,
#  33,
#  34,
#  28,
#  55,
#  86,
#  79,
#  49,
#  67,
#  9,
#  76,
#  29,
#  55,
#  28,
#  80,
#  72,
#  63,
#  33,
#  54,
#  9,
#  13,
#  47,
#  52,
#  81,
#  62,
#  55,
#  15,
#  80,
#  56,
#  39,
#  14,
#  40,
#  23,
#  9,
#  33,
#  28,
#  28,
#  33,
#  59,
#  33,
#  79,
#  33,
#  52,
#  11,
#  77,
#  86,
#  21,
#  27,
#  82,
#  49,
#  42,
#  63,
#  22,
#  72,
#  72,
#  72,
#  21,
#  40,
#  72,
#  55,
#  32,
#  9,
#  80,
#  84,
#  42,
#  23,
#  63,
#  80,
#  33,
#  40,
#  33,
#  34,
#  7,
#  50,
#  9,
#  52,
#  9,
#  70,
#  51,
#  42,
#  27,
#  9,
#  19,
#  33,
#  16,
#  52,
#  86,
#  24,
#  4,
#  11,
#  8,
#  87,
#  62,
#  0,
#  22,
#  42,
#  68,
#  33,
#  1,
#  40,
#  67,
#  55,
#  58,
#  80,
#  40,
#  11,
#  15,
#  23,
#  41,
#  52,
#  38,
#  72,
#  0,
#  21,
#  83,
#  9,
#  37,
#  15,
#  86,
#  77,
#  35,
#  21,
#  56,
#  29,
#  76,
#  58,
#  13,
#  15,
#  40,
#  72,
#  8,
#  21,
#  72,
#  15,
#  28,
#  73,
#  33,
#  66,
#  9,
#  33,
#  50,
#  3,
#  54,
#  51,
#  0,
#  76,
#  54,
#  9,
#  63,
#  40,
#  38,
#  65,
#  52,
#  8,
#  63,
#  63,
#  33,
#  28,
#  40,
#  43,
#  10,
#  56,
#  47,
#  28,
#  5,
#  33,
#  85,
#  63,
#  2,
#  10,
#  41,
#  32,
#  59,
#  1,
#  19,
#  55,
#  71,
#  8,
#  76,
#  48,
#  52,
#  58,
#  30,
#  24,
#  79,
#  19,
#  41,
#  33,
#  84,
#  15,
#  72,
#  56,
#  72,
#  82,
#  72,
#  50,
#  33,
#  52,
#  4,
#  33,
#  3,
#  52,
#  49,
#  33,
#  42,
#  21,
#  52,
#  14,
#  79,
#  33,
#  24,
#  47,
#  49,
#  63,
#  21,
#  3,
#  50,
#  48,
#  13,
#  45,
#  9,
#  44,
#  72,
#  17,
#  65,
#  84,
#  3,
#  52,
#  17,
#  55,
#  34,
#  10,
#  54,
#  3,
#  15,
#  25,
#  82,
#  45,
#  47,
#  74,
#  23,
#  75,
#  83,
#  34,
#  59,
#  48,
#  55,
#  0,
#  13,
#  72,
#  36,
#  55,
#  75,
#  9,
#  40,
#  68,
#  68,
#  57,
#  8,
#  85,
#  21,
#  67,
#  68,
#  84,
#  31,
#  72,
#  85,
#  55,
#  52,
#  87,
#  31,
#  66,
#  43,
#  64,
#  76,
#  52,
#  0,
#  39,
#  86,
#  9,
#  14,
#  17,
#  25,
#  68,
#  76,
#  55,
#  2,
#  61,
#  55,
#  54,
#  35,
#  9,
#  45,
#  55,
#  9,
#  15,
#  9,
#  31,
#  72,
#  19,
#  25,
#  9,
#  14,
#  84,
#  63,
#  16,
#  57,
#  21,
#  50,
#  34,
#  0,
#  55,
#  56,
#  61,
#  72,
#  36,
#  2,
#  65,
#  15,
#  65,
#  78,
#  55,
#  14,
#  72,
#  16,
#  84,
#  31,
#  72,
#  85,
#  5,
#  33,
#  45,
#  55,
#  20,
#  72,
#  67,
#  8,
#  84,
#  9,
#  21,
#  37,
#  52,
#  51,
#  52,
#  21,
#  60,
#  77,
#  40,
#  40,
#  33,
#  25,
#  15,
#  16,
#  72,
#  63,
#  57,
#  48,
#  40,
#  44,
#  72,
#  84,
#  40,
#  9,
#  37,
#  55,
#  54,
#  55,
#  12,
#  21,
#  71,
#  40,
#  55,
#  52,
#  14,
#  80,
#  38,
#  13,
#  58,
#  46,
#  62,
#  52,
#  80,
#  18,
#  39,
#  60,
#  44,
#  60,
#  65,
#  28,
#  33,
#  55,
#  66,
#  84,
#  44,
#  39,
#  4,
#  68,
#  9,
#  68,
#  63,
#  5,
#  18,
#  42,
#  16,
#  52,
#  65,
#  37,
#  19,
#  40,
#  24,
#  38,
#  58,
#  56,
#  2,
#  40,
#  39,
#  17,
#  87,
#  34,
#  17,
#  46,
#  63,
#  30,
#  56,
#  24,
#  13,
#  72,
#  15,
#  77,
#  84,
#  58,
#  50,
#  34,
#  33,
#  12,
#  58,
#  35,
#  9,
#  33,
#  21,
#  19,
#  0,
#  9,
#  33,
#  63,
#  53,
#  40,
#  57,
#  55,
#  40,
#  21,
#  59,
#  72,
#  54,
#  18,
#  28,
#  45,
#  55,
#  55,
#  47,
#  58,
#  15,
#  11,
#  9,
#  3,
#  82,
#  3,
#  38,
#  55,
#  ...]

# %%
train_y = pd.read_csv("./open/train_df_add_data.csv")

train_labels = train_y["label"]

label_unique = sorted(np.unique(train_labels))
label_unique = {key:value for key,value in zip(label_unique, range(len(label_unique)))}

# %%
label_decoder = {val:key for key, val in label_unique.items()}

f_result = [label_decoder[result] for result in f_pred]

# %%
f_result
# Out:
# ['tile-glue_strip',
#  'grid-good',
#  'transistor-good',
#  'tile-gray_stroke',
#  'tile-good',
#  'pill-crack',
#  'capsule-faulty_imprint',
#  'hazelnut-cut',
#  'leather-good',
#  'leather-glue',
#  'bottle-broken_large',
#  'wood-good',
#  'zipper-rough',
#  'screw-thread_side',
#  'tile-glue_strip',
#  'bottle-contamination',
#  'grid-bent',
#  'carpet-hole',
#  'carpet-good',
#  'pill-color',
#  'tile-rough',
#  'zipper-good',
#  'bottle-broken_large',
#  'screw-scratch_neck',
#  'pill-faulty_imprint',
#  'screw-good',
#  'pill-faulty_imprint',
#  'screw-thread_top',
#  'leather-good',
#  'leather-glue',
#  'screw-good',
#  'cable-good',
#  'screw-thread_side',
#  'zipper-fabric_interior',
#  'zipper-good',
#  'zipper-fabric_border',
#  'leather-good',
#  'cable-good',
#  'leather-cut',
#  'metal_nut-flip',
#  'metal_nut-good',
#  'cable-missing_cable',
#  'screw-thread_top',
#  'capsule-faulty_imprint',
#  'metal_nut-flip',
#  'tile-good',
#  'toothbrush-good',
#  'capsule-good',
#  'zipper-good',
#  'screw-good',
#  'cable-good',
#  'transistor-good',
#  'hazelnut-crack',
#  'hazelnut-print',
#  'zipper-good',
#  'metal_nut-scratch',
#  'carpet-cut',
#  'carpet-good',
#  'leather-fold',
#  'capsule-good',
#  'transistor-good',
#  'pill-combined',
#  'capsule-squeeze',
#  'zipper-broken_teeth',
#  'capsule-crack',
#  'leather-color',
#  'transistor-good',
#  'capsule-crack',
#  'pill-pill_type',
#  'metal_nut-color',
#  'grid-bent',
#  'wood-good',
#  'hazelnut-cut',
#  'tile-good',
#  'leather-poke',
#  'zipper-good',
#  'cable-good',
#  'leather-good',
#  'cable-good',
#  'cable-good',
#  'pill-crack',
#  'wood-good',
#  'screw-scratch_head',
#  'wood-combined',
#  'transistor-good',
#  'bottle-broken_large',
#  'zipper-good',
#  'carpet-hole',
#  'leather-good',
#  'zipper-fabric_interior',
#  'leather-color',
#  'zipper-good',
#  'cable-good',
#  'metal_nut-bent',
#  'screw-good',
#  'tile-oil',
#  'transistor-bent_lead',
#  'transistor-good',
#  'metal_nut-good',
#  'metal_nut-good',
#  'cable-good',
#  'carpet-good',
#  'pill-good',
#  'capsule-scratch',
#  'wood-good',
#  'bottle-contamination',
#  'zipper-rough',
#  'pill-contamination',
#  'transistor-good',
#  'hazelnut-hole',
#  'leather-color',
#  'screw-scratch_neck',
#  'transistor-bent_lead',
#  'transistor-good',
#  'zipper-good',
#  'capsule-good',
#  'grid-good',
#  'pill-good',
#  'capsule-crack',
#  'leather-poke',
#  'screw-good',
#  'carpet-color',
#  'metal_nut-good',
#  'transistor-good',
#  'wood-hole',
#  'transistor-cut_lead',
#  'tile-crack',
#  'transistor-good',
#  'pill-scratch',
#  'screw-good',
#  'grid-good',
#  'metal_nut-scratch',
#  'pill-crack',
#  'metal_nut-bent',
#  'capsule-good',
#  'grid-bent',
#  'screw-scratch_head',
#  'bottle-contamination',
#  'pill-good',
#  'wood-liquid',
#  'transistor-misplaced',
#  'hazelnut-good',
#  'cable-cut_inner_insulation',
#  'cable-good',
#  'zipper-good',
#  'hazelnut-print',
#  'carpet-metal_contamination',
#  'zipper-good',
#  'zipper-rough',
#  'wood-good',
#  'zipper-good',
#  'wood-scratch',
#  'transistor-good',
#  'pill-good',
#  'zipper-fabric_interior',
#  'tile-good',
#  'toothbrush-good',
#  'tile-good',
#  'hazelnut-good',
#  'metal_nut-good',
#  'screw-scratch_head',
#  'screw-thread_top',
#  'screw-scratch_head',
#  'cable-missing_wire',
#  'carpet-good',
#  'leather-fold',
#  'pill-contamination',
#  'wood-color',
#  'zipper-fabric_interior',
#  'cable-missing_cable',
#  'carpet-good',
#  'carpet-thread',
#  'screw-manipulated_front',
#  'leather-glue',
#  'cable-good',
#  'pill-good',
#  'screw-good',
#  'zipper-split_teeth',
#  'capsule-good',
#  'zipper-good',
#  'leather-good',
#  'grid-glue',
#  'bottle-good',
#  'cable-missing_wire',
#  'pill-faulty_imprint',
#  'carpet-cut',
#  'tile-glue_strip',
#  'metal_nut-good',
#  'wood-scratch',
#  'grid-good',
#  'pill-good',
#  'capsule-squeeze',
#  'zipper-good',
#  'hazelnut-cut',
#  'pill-good',
#  'screw-scratch_head',
#  'zipper-combined',
#  'zipper-rough',
#  'zipper-good',
#  'hazelnut-good',
#  'transistor-good',
#  'cable-good',
#  'screw-scratch_neck',
#  'bottle-broken_small',
#  'pill-good',
#  'leather-good',
#  'pill-good',
#  'pill-good',
#  'hazelnut-good',
#  'grid-bent',
#  'leather-poke',
#  'capsule-good',
#  'screw-good',
#  'wood-good',
#  'pill-combined',
#  'carpet-cut',
#  'capsule-squeeze',
#  'pill-contamination',
#  'transistor-good',
#  'bottle-broken_small',
#  'tile-oil',
#  'grid-good',
#  'tile-good',
#  'bottle-broken_small',
#  'capsule-good',
#  'metal_nut-good',
#  'pill-faulty_imprint',
#  'leather-color',
#  'cable-good',
#  'transistor-damaged_case',
#  'pill-good',
#  'screw-good',
#  'zipper-combined',
#  'pill-contamination',
#  'zipper-broken_teeth',
#  'capsule-scratch',
#  'transistor-good',
#  'metal_nut-good',
#  'hazelnut-crack',
#  'capsule-faulty_imprint',
#  'metal_nut-good',
#  'hazelnut-hole',
#  'zipper-rough',
#  'screw-thread_side',
#  'wood-color',
#  'leather-poke',
#  'tile-good',
#  'tile-gray_stroke',
#  'wood-scratch',
#  'cable-cable_swap',
#  'transistor-good',
#  'tile-gray_stroke',
#  'cable-bent_wire',
#  'capsule-good',
#  'metal_nut-flip',
#  'metal_nut-good',
#  'metal_nut-good',
#  'capsule-poke',
#  'zipper-broken_teeth',
#  'hazelnut-good',
#  'hazelnut-crack',
#  'screw-good',
#  'hazelnut-good',
#  'hazelnut-cut',
#  'leather-poke',
#  'leather-good',
#  'wood-good',
#  'screw-good',
#  'metal_nut-flip',
#  'cable-good',
#  'carpet-good',
#  'screw-good',
#  'wood-hole',
#  'transistor-good',
#  'cable-good',
#  'capsule-good',
#  'pill-color',
#  'capsule-good',
#  'transistor-misplaced',
#  'zipper-squeezed_teeth',
#  'pill-color',
#  'leather-color',
#  'transistor-good',
#  'pill-pill_type',
#  'pill-good',
#  'screw-good',
#  'grid-thread',
#  'tile-good',
#  'tile-good',
#  'bottle-broken_large',
#  'carpet-hole',
#  'bottle-broken_small',
#  'leather-fold',
#  'leather-cut',
#  'cable-good',
#  'zipper-squeezed_teeth',
#  'tile-good',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'screw-scratch_neck',
#  'leather-poke',
#  'zipper-broken_teeth',
#  'transistor-good',
#  'screw-scratch_head',
#  'pill-faulty_imprint',
#  'toothbrush-good',
#  'grid-good',
#  'leather-color',
#  'screw-manipulated_front',
#  'screw-good',
#  'transistor-good',
#  'bottle-good',
#  'metal_nut-scratch',
#  'wood-good',
#  'transistor-good',
#  'screw-thread_side',
#  'wood-good',
#  'wood-good',
#  'tile-good',
#  'cable-good',
#  'screw-scratch_neck',
#  'metal_nut-scratch',
#  'cable-cut_inner_insulation',
#  'leather-good',
#  'capsule-good',
#  'screw-good',
#  'screw-manipulated_front',
#  'pill-crack',
#  'transistor-good',
#  'screw-scratch_neck',
#  'capsule-good',
#  'screw-good',
#  'carpet-good',
#  'carpet-color',
#  'bottle-good',
#  'tile-good',
#  'metal_nut-color',
#  'screw-scratch_neck',
#  'cable-bent_wire',
#  'wood-good',
#  'screw-good',
#  'metal_nut-bent',
#  'tile-good',
#  'screw-good',
#  'leather-glue',
#  'metal_nut-flip',
#  'metal_nut-bent',
#  'hazelnut-good',
#  'pill-pill_type',
#  'carpet-thread',
#  'cable-cable_swap',
#  'cable-good',
#  'capsule-scratch',
#  'carpet-good',
#  'capsule-poke',
#  'cable-good',
#  'pill-good',
#  'bottle-good',
#  'toothbrush-defective',
#  'transistor-cut_lead',
#  'capsule-crack',
#  'leather-fold',
#  'carpet-color',
#  'transistor-good',
#  'zipper-rough',
#  'wood-color',
#  'cable-cut_inner_insulation',
#  'cable-cable_swap',
#  'leather-cut',
#  'hazelnut-good',
#  'screw-good',
#  'cable-good',
#  'bottle-good',
#  'hazelnut-good',
#  'transistor-good',
#  'wood-hole',
#  'screw-manipulated_front',
#  'capsule-faulty_imprint',
#  'grid-good',
#  'metal_nut-scratch',
#  'screw-good',
#  'wood-color',
#  'tile-glue_strip',
#  'capsule-good',
#  'grid-good',
#  'metal_nut-bent',
#  'capsule-good',
#  'hazelnut-cut',
#  'screw-good',
#  'leather-good',
#  'metal_nut-color',
#  'bottle-broken_small',
#  'leather-cut',
#  'capsule-poke',
#  'transistor-good',
#  'cable-cable_swap',
#  'bottle-contamination',
#  'hazelnut-print',
#  'tile-good',
#  'wood-liquid',
#  'tile-gray_stroke',
#  'transistor-good',
#  'zipper-combined',
#  'bottle-contamination',
#  'tile-good',
#  'pill-crack',
#  'capsule-scratch',
#  'leather-good',
#  'pill-good',
#  'cable-good',
#  'capsule-poke',
#  'pill-good',
#  'cable-good',
#  'bottle-broken_small',
#  'transistor-good',
#  'leather-good',
#  'transistor-good',
#  'hazelnut-cut',
#  'transistor-bent_lead',
#  'metal_nut-scratch',
#  'zipper-good',
#  'metal_nut-bent',
#  'carpet-good',
#  'carpet-color',
#  'pill-crack',
#  'zipper-fabric_border',
#  'zipper-good',
#  'leather-cut',
#  'transistor-damaged_case',
#  'bottle-broken_small',
#  'zipper-good',
#  'cable-good',
#  'bottle-broken_small',
#  'tile-good',
#  'hazelnut-crack',
#  'wood-scratch',
#  'pill-faulty_imprint',
#  'carpet-good',
#  'grid-metal_contamination',
#  'pill-color',
#  'tile-oil',
#  'transistor-good',
#  'screw-manipulated_front',
#  'transistor-bent_lead',
#  'transistor-cut_lead',
#  'carpet-thread',
#  'zipper-broken_teeth',
#  'tile-glue_strip',
#  'leather-fold',
#  'wood-hole',
#  'zipper-good',
#  'bottle-broken_small',
#  'carpet-good',
#  'tile-good',
#  'hazelnut-good',
#  'screw-thread_side',
#  'hazelnut-good',
#  'carpet-hole',
#  'metal_nut-flip',
#  'cable-good',
#  'carpet-good',
#  'screw-thread_top',
#  'leather-poke',
#  'carpet-thread',
#  'capsule-faulty_imprint',
#  'capsule-crack',
#  'metal_nut-flip',
#  'screw-thread_side',
#  'metal_nut-good',
#  'pill-pill_type',
#  'metal_nut-bent',
#  'tile-good',
#  'bottle-good',
#  'screw-manipulated_front',
#  'cable-good',
#  'wood-good',
#  'transistor-good',
#  'screw-thread_top',
#  'screw-thread_top',
#  'pill-combined',
#  'screw-thread_side',
#  'carpet-hole',
#  'cable-good',
#  'screw-good',
#  'screw-good',
#  'cable-good',
#  'grid-good',
#  'hazelnut-hole',
#  'pill-faulty_imprint',
#  'carpet-cut',
#  'cable-poke_insulation',
#  'cable-cut_inner_insulation',
#  'screw-good',
#  'hazelnut-good',
#  'capsule-squeeze',
#  'transistor-cut_lead',
#  'toothbrush-defective',
#  'cable-cut_inner_insulation',
#  'zipper-split_teeth',
#  'screw-manipulated_front',
#  'tile-oil',
#  'metal_nut-scratch',
#  'transistor-good',
#  'cable-bent_wire',
#  'tile-good',
#  'leather-fold',
#  'wood-liquid',
#  'toothbrush-good',
#  'leather-poke',
#  'capsule-poke',
#  'screw-manipulated_front',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'zipper-good',
#  'cable-good',
#  'metal_nut-scratch',
#  'leather-good',
#  'cable-good',
#  'tile-gray_stroke',
#  'pill-pill_type',
#  'wood-good',
#  'metal_nut-good',
#  'pill-good',
#  'zipper-combined',
#  'cable-missing_wire',
#  'wood-good',
#  'capsule-crack',
#  'carpet-cut',
#  'capsule-crack',
#  'hazelnut-hole',
#  'hazelnut-good',
#  'hazelnut-hole',
#  'grid-good',
#  'screw-good',
#  'zipper-split_teeth',
#  'wood-scratch',
#  'pill-contamination',
#  'toothbrush-defective',
#  'cable-good',
#  'wood-good',
#  'grid-metal_contamination',
#  'screw-good',
#  'grid-good',
#  'zipper-broken_teeth',
#  'transistor-good',
#  'tile-good',
#  'hazelnut-good',
#  'pill-scratch',
#  'cable-good',
#  'capsule-crack',
#  'pill-color',
#  'pill-good',
#  'zipper-combined',
#  'tile-glue_strip',
#  'screw-good',
#  'capsule-good',
#  'zipper-broken_teeth',
#  'screw-manipulated_front',
#  'leather-glue',
#  'capsule-faulty_imprint',
#  'leather-good',
#  'carpet-metal_contamination',
#  'cable-good',
#  'hazelnut-good',
#  'grid-good',
#  'grid-good',
#  'hazelnut-good',
#  'screw-thread_side',
#  'hazelnut-good',
#  'wood-scratch',
#  'hazelnut-good',
#  'pill-good',
#  'cable-missing_wire',
#  'wood-hole',
#  'zipper-split_teeth',
#  'carpet-good',
#  'grid-glue',
#  'zipper-fabric_border',
#  'pill-contamination',
#  'metal_nut-bent',
#  'tile-good',
#  'carpet-hole',
#  'transistor-good',
#  'transistor-good',
#  'transistor-good',
#  'carpet-good',
#  'leather-good',
#  'transistor-good',
#  'screw-good',
#  'hazelnut-cut',
#  'cable-good',
#  'zipper-broken_teeth',
#  'zipper-good',
#  'metal_nut-bent',
#  'carpet-metal_contamination',
#  'tile-good',
#  'zipper-broken_teeth',
#  'hazelnut-good',
#  'leather-good',
#  'hazelnut-good',
#  'hazelnut-hole',
#  'cable-cut_inner_insulation',
#  'pill-crack',
#  'cable-good',
#  'pill-good',
#  'cable-good',
#  'transistor-cut_lead',
#  'pill-faulty_imprint',
#  'metal_nut-bent',
#  'grid-glue',
#  'cable-good',
#  'carpet-color',
#  'hazelnut-good',
#  'capsule-poke',
#  'pill-good',
#  'zipper-split_teeth',
#  'carpet-thread',
#  'cable-bent_wire',
#  'cable-missing_wire',
#  'cable-cut_outer_insulation',
#  'zipper-squeezed_teeth',
#  'tile-glue_strip',
#  'bottle-broken_large',
#  'carpet-hole',
#  'metal_nut-bent',
#  'toothbrush-good',
#  'hazelnut-good',
#  'bottle-broken_small',
#  'leather-good',
#  'toothbrush-defective',
#  'screw-good',
#  'screw-scratch_neck',
#  'zipper-broken_teeth',
#  'leather-good',
#  'cable-missing_wire',
#  'capsule-good',
#  'carpet-metal_contamination',
#  'leather-poke',
#  'pill-good',
#  'leather-fold',
#  'transistor-good',
#  'bottle-broken_large',
#  'carpet-good',
#  'zipper-fabric_interior',
#  'cable-good',
#  'leather-cut',
#  'capsule-good',
#  'zipper-split_teeth',
#  'wood-hole',
#  'hazelnut-print',
#  'carpet-good',
#  'screw-manipulated_front',
#  'grid-metal_contamination',
#  'wood-good',
#  'screw-scratch_neck',
#  'capsule-crack',
#  'capsule-good',
#  'leather-good',
#  'transistor-good',
#  'cable-cut_outer_insulation',
#  'carpet-good',
#  'transistor-good',
#  'capsule-good',
#  'grid-good',
#  'transistor-misplaced',
#  'hazelnut-good',
#  'tile-rough',
#  'cable-good',
#  'hazelnut-good',
#  'pill-crack',
#  'bottle-good',
#  'pill-scratch',
#  'pill-faulty_imprint',
#  'bottle-broken_large',
#  'wood-good',
#  'pill-scratch',
#  'cable-good',
#  'tile-good',
#  'leather-good',
#  'leather-fold',
#  'tile-oil',
#  'pill-good',
#  'cable-cut_outer_insulation',
#  'tile-good',
#  'tile-good',
#  'hazelnut-good',
#  'grid-good',
#  'leather-good',
#  'metal_nut-color',
#  'cable-missing_cable',
#  'screw-manipulated_front',
#  'pill-color',
#  'grid-good',
#  'cable-cable_swap',
#  'hazelnut-good',
#  'zipper-rough',
#  'tile-good',
#  'bottle-contamination',
#  'cable-missing_cable',
#  'leather-poke',
#  'hazelnut-cut',
#  'screw-thread_side',
#  'bottle-broken_small',
#  'carpet-color',
#  'screw-good',
#  'transistor-damaged_case',
#  'cable-cut_outer_insulation',
#  'wood-good',
#  'pill-combined',
#  'pill-good',
#  'screw-scratch_neck',
#  'grid-thread',
#  'carpet-thread',
#  'wood-scratch',
#  'carpet-color',
#  'leather-poke',
#  'hazelnut-good',
#  'zipper-good',
#  'capsule-good',
#  'transistor-good',
#  'screw-manipulated_front',
#  'transistor-good',
#  'zipper-fabric_border',
#  'transistor-good',
#  'pill-crack',
#  'hazelnut-good',
#  'pill-good',
#  'cable-bent_wire',
#  'hazelnut-good',
#  'bottle-good',
#  'pill-good',
#  'pill-contamination',
#  'hazelnut-good',
#  'metal_nut-bent',
#  'carpet-good',
#  'pill-good',
#  'capsule-faulty_imprint',
#  'wood-scratch',
#  'hazelnut-good',
#  'carpet-thread',
#  'pill-color',
#  'pill-contamination',
#  'tile-good',
#  'carpet-good',
#  'bottle-good',
#  'pill-crack',
#  'pill-combined',
#  'capsule-crack',
#  'metal_nut-good',
#  'cable-good',
#  'metal_nut-flip',
#  'transistor-good',
#  'capsule-scratch',
#  'tile-oil',
#  'zipper-good',
#  'bottle-good',
#  'pill-good',
#  'capsule-scratch',
#  'screw-good',
#  'hazelnut-hole',
#  'cable-missing_cable',
#  'pill-scratch',
#  'bottle-good',
#  'capsule-good',
#  'grid-bent',
#  'zipper-fabric_border',
#  'metal_nut-good',
#  'pill-color',
#  'wood-color',
#  'carpet-metal_contamination',
#  'wood-combined',
#  'zipper-fabric_interior',
#  'hazelnut-hole',
#  'screw-thread_side',
#  'pill-combined',
#  'screw-good',
#  'bottle-broken_large',
#  'capsule-crack',
#  'transistor-good',
#  'leather-color',
#  'screw-good',
#  'wood-combined',
#  'cable-good',
#  'leather-good',
#  'toothbrush-good',
#  'toothbrush-good',
#  'screw-scratch_head',
#  'cable-cut_outer_insulation',
#  'zipper-rough',
#  'carpet-good',
#  'toothbrush-defective',
#  'toothbrush-good',
#  'zipper-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'zipper-rough',
#  'screw-good',
#  'pill-good',
#  'zipper-squeezed_teeth',
#  'hazelnut-crack',
#  'tile-rough',
#  'metal_nut-color',
#  'tile-gray_stroke',
#  'wood-good',
#  'pill-good',
#  'bottle-broken_large',
#  'leather-glue',
#  'zipper-split_teeth',
#  'cable-good',
#  'capsule-faulty_imprint',
#  'capsule-scratch',
#  'grid-bent',
#  'toothbrush-good',
#  'wood-good',
#  'screw-good',
#  'bottle-contamination',
#  'tile-crack',
#  'screw-good',
#  'pill-scratch',
#  'hazelnut-print',
#  'cable-good',
#  'metal_nut-good',
#  'screw-good',
#  'cable-good',
#  'capsule-good',
#  'cable-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'carpet-color',
#  'grid-bent',
#  'cable-good',
#  'capsule-faulty_imprint',
#  'zipper-good',
#  'tile-good',
#  'capsule-poke',
#  'screw-scratch_head',
#  'carpet-good',
#  'pill-crack',
#  'hazelnut-hole',
#  'bottle-broken_large',
#  'screw-good',
#  'screw-manipulated_front',
#  'tile-crack',
#  'transistor-good',
#  'leather-color',
#  'bottle-contamination',
#  'tile-oil',
#  'capsule-good',
#  'tile-oil',
#  'wood-liquid',
#  'screw-good',
#  'capsule-faulty_imprint',
#  'transistor-good',
#  'capsule-poke',
#  'zipper-good',
#  'hazelnut-crack',
#  'transistor-good',
#  'zipper-rough',
#  'cable-cable_swap',
#  'hazelnut-good',
#  'metal_nut-good',
#  'screw-good',
#  'carpet-cut',
#  'transistor-good',
#  'toothbrush-defective',
#  'cable-cut_outer_insulation',
#  'zipper-good',
#  'cable-good',
#  'carpet-good',
#  'leather-cut',
#  'pill-good',
#  'pill-faulty_imprint',
#  'pill-good',
#  'carpet-good',
#  'screw-thread_top',
#  'wood-hole',
#  'leather-good',
#  'leather-good',
#  'hazelnut-good',
#  'grid-bent',
#  'capsule-good',
#  'capsule-poke',
#  'transistor-good',
#  'tile-good',
#  'screw-scratch_head',
#  'pill-combined',
#  'leather-good',
#  'metal_nut-flip',
#  'transistor-good',
#  'zipper-good',
#  'leather-good',
#  'cable-good',
#  'leather-cut',
#  'screw-good',
#  'pill-scratch',
#  'screw-good',
#  'cable-poke_insulation',
#  'carpet-good',
#  'transistor-damaged_case',
#  'leather-good',
#  'screw-good',
#  'pill-good',
#  'capsule-faulty_imprint',
#  'zipper-broken_teeth',
#  'leather-fold',
#  'capsule-crack',
#  'screw-scratch_neck',
#  'metal_nut-scratch',
#  'tile-glue_strip',
#  'pill-good',
#  'zipper-broken_teeth',
#  'capsule-squeeze',
#  'leather-glue',
#  'screw-thread_top',
#  'metal_nut-flip',
#  'screw-thread_top',
#  'tile-oil',
#  'grid-good',
#  'hazelnut-good',
#  'screw-good',
#  'tile-rough',
#  'zipper-good',
#  'metal_nut-flip',
#  'leather-glue',
#  'cable-bent_wire',
#  'toothbrush-good',
#  'cable-good',
#  'toothbrush-good',
#  'tile-good',
#  'cable-cable_swap',
#  'capsule-squeeze',
#  'metal_nut-bent',
#  'capsule-poke',
#  'pill-good',
#  'tile-oil',
#  'leather-cut',
#  'carpet-color',
#  'leather-good',
#  'carpet-thread',
#  'leather-fold',
#  'screw-scratch_neck',
#  'screw-manipulated_front',
#  'bottle-contamination',
#  'leather-good',
#  'leather-glue',
#  'capsule-scratch',
#  'zipper-squeezed_teeth',
#  'hazelnut-hole',
#  'capsule-scratch',
#  'metal_nut-scratch',
#  'tile-good',
#  'grid-thread',
#  'screw-manipulated_front',
#  'carpet-thread',
#  'capsule-crack',
#  'transistor-good',
#  'capsule-good',
#  'wood-hole',
#  'zipper-good',
#  'screw-scratch_neck',
#  'pill-crack',
#  'hazelnut-hole',
#  'hazelnut-good',
#  'cable-poke_insulation',
#  'screw-scratch_neck',
#  'hazelnut-print',
#  'cable-good',
#  'hazelnut-good',
#  'carpet-good',
#  'carpet-color',
#  'bottle-broken_large',
#  'cable-good',
#  'hazelnut-good',
#  'tile-good',
#  'pill-pill_type',
#  'leather-good',
#  'screw-scratch_head',
#  'screw-good',
#  'leather-good',
#  'carpet-good',
#  'screw-thread_side',
#  'transistor-good',
#  'pill-scratch',
#  'capsule-squeeze',
#  'grid-good',
#  'metal_nut-good',
#  'screw-good',
#  'screw-good',
#  'pill-color',
#  'screw-scratch_neck',
#  'capsule-good',
#  'cable-missing_wire',
#  'cable-good',
#  'bottle-good',
#  'zipper-fabric_border',
#  'bottle-good',
#  'leather-fold',
#  'screw-good',
#  ...]

# %%
submission = pd.read_csv("./open/sample_submission.csv")

submission["label"] = f_result

submission
# Out:
#       index             label
# 0         0   tile-glue_strip
# 1         1         grid-good
# 2         2   transistor-good
# 3         3  tile-gray_stroke
# 4         4         tile-good
# ...     ...               ...
# 2149   2149  tile-gray_stroke
# 2150   2150        screw-good
# 2151   2151         grid-good
# 2152   2152        cable-good
# 2153   2153       zipper-good
#
# [2154 rows x 2 columns]

# %%
submission.to_csv("./submission/label_result_add_0505_convnext_base_384_in22ft1k_tta.csv", index = False)
